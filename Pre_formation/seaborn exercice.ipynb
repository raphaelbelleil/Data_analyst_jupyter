# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
prets = pd.read_csv('https://raw.githubusercontent.com/benjaminmrl/data-4452741/main/prets_final.csv')

prets.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#    taux_interet  taux_endettement  cout_total  benefices risque
# 0         1.168             30.80    271212.0     131.99    Non
# 1         3.701              4.52     15360.0      23.69    Non
# 2         1.173             23.50    374355.0     182.97    Non
# 3         0.972             29.50    132609.6      53.71    Non
# 4         1.014             34.80    105485.4      44.57    Non

# %%
sns.countplot(data=prets, x='type')
plt.ylabel("Nombre de prêts")
plt.xlabel("Type de prêts")
plt.figure(figsize=(10,6))

# %%
#sns.countplot(data=prets, x='type')
#plt.ylabel("Nombre de prêts")
#plt.xlabel("Type de prêts")
#plt.figure(figsize=(10,6))

#type_agreg1 = prets['type'].value_counts().reset_index()

# ne marche pas car agrégation, il faudrait avoir la colonne nombre de prêts
#nombre_prets = type_agreg1['type'].tolist()
#for i in range (2) :
#     plt.text(i, nombre_prets[i], nombre_prets[i])
#plt.show()

# %%
prets_immobilier = prets.loc[(prets['type']=='immobilier'),:]
sns.scatterplot(data=prets_immobilier, x='revenu', y='benefices', hue='ville')
# Out:
# <AxesSubplot:xlabel='revenu', ylabel='benefices'>

# %%
sns.histplot(prets['benefices'])
# Out:
# <AxesSubplot:xlabel='benefices', ylabel='Count'>

# %%
sns.kdeplot(prets['benefices'])
# Out:
# <AxesSubplot:xlabel='benefices', ylabel='Density'>

# %%
sns.barplot(data=prets, x='ville', y='benefices', ci=None, estimator=np.sum, hue='type')
# Out:
# <AxesSubplot:xlabel='ville', ylabel='benefices'>
