# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import scipy.stats as st
import datetime as dt

import warnings

# %%
warnings.simplefilter("ignore")

# %%
# fonctions issues du projet précédent
from fonctions import *

# %%
folder = 'D:/Data_Analyst_Projet/Projet 6/Donnees python/'

# %%
cus=pd.read_csv(folder+'customers_2.csv')
cus
# Out:
#      client_id sex  birth  age
# 0       c_4410   f   1967   56
# 1       c_7839   f   1975   48
# 2       c_1699   f   1984   39
# 3       c_5961   f   1962   61
# 4       c_5320   m   1943   80
# ...        ...  ..    ...  ...
# 8616    c_7920   m   1956   67
# 8617    c_7403   f   1970   53
# 8618    c_5119   m   1974   49
# 8619    c_5643   f   1968   55
# 8620      c_84   f   1982   41
#
# [8621 rows x 4 columns]

# %%
stat_var(cus['age'])
# Out:
# Voici un tableau présentant les résultats des tests de représentativité, de forme et de normalité de l'échantillon
#                           echantillon_base echantillon_base_IQR  \
# moyenne                            44.7244              44.7244
# moyenne_min                         40.252               40.252
# moyenne_max                        49.1968              49.1968
# test_moyenne_10_pourcents             True                 True
# mediane                               44.0                 44.0
# mode                                    19                   19
# moyenne_tronquee                   44.1491              44.1491
# ecart_type                          16.918               16.918
# CV                                  0.3783               0.3783
# IQR                                   26.0                 26.0
# outlier_max_iqr                       96.0                 96.0
# outlier_min_iqr                          0                    0
# nb_outlier_iqr                           0                    0
# outlier_max_zscore                      94                   94
# outlier_min_zscore                       0                    0
# nb_outlier_zscore                        0                    0
# skewness                            0.3608               0.3608
# skewness_pvalue                        0.0                  0.0
# kurtosis                           -0.6367              -0.6367
# kurtosis_pvalue                        0.0                  0.0
# ks_pvalue                              0.0                  0.0
# shapiro_pvalue                         0.0                  0.0
#
#                           echantillon_base_zscore echantillon_base_log  \
# moyenne                                   44.7244               3.7239
# moyenne_min                                40.252               3.3515
# moyenne_max                               49.1968               4.0963
# test_moyenne_10_pourcents                    True                 True
# mediane                                      44.0               3.7842
# mode                                           19               2.9444
# moyenne_tronquee                          44.1491               3.7302
# ecart_type                                 16.918               0.4016
# CV                                         0.3783               0.1079
# IQR                                          26.0               0.6091
# outlier_max_iqr                              96.0             4.956701
# outlier_min_iqr                                 0             2.520337
# nb_outlier_iqr                                  0                    0
# outlier_max_zscore                             94             4.543295
# outlier_min_zscore                              0             2.519082
# nb_outlier_zscore                               0                    0
# skewness                                   0.3608              -0.3032
# skewness_pvalue                               0.0                  0.0
# kurtosis                                  -0.6367              -0.8259
# kurtosis_pvalue                               0.0                  0.0
# ks_pvalue                                     0.0                  0.0
# shapiro_pvalue                                0.0                  0.0
#
#                             log_IQR log_zscore echantillon_base_sqrt  \
# moyenne                      3.7239     3.7239                6.5643
# moyenne_min                  3.3515     3.3515                5.9079
# moyenne_max                  4.0963     4.0963                7.2207
# test_moyenne_10_pourcents      True       True                  True
# mediane                      3.7842     3.7842                6.6332
# mode                         2.9444     2.9444                4.3589
# moyenne_tronquee             3.7302     3.7302                6.5523
# ecart_type                   0.4016     0.4016                1.2785
# CV                           0.1079     0.1079                0.1948
# IQR                          0.6091     0.6091                1.9821
# outlier_max_iqr            4.956701   4.956701             10.522984
# outlier_min_iqr            2.520337   2.520337              2.594614
# nb_outlier_iqr                    0          0                     0
# outlier_max_zscore         4.543295   4.543295               9.69536
# outlier_min_zscore         2.519082   2.519082              2.729004
# nb_outlier_zscore                 0          0                     0
# skewness                    -0.3032    -0.3032                0.0264
# skewness_pvalue                 0.0        0.0                0.3169
# kurtosis                    -0.8259    -0.8259               -0.8641
# kurtosis_pvalue                 0.0        0.0                   0.0
# ks_pvalue                       0.0        0.0                   0.0
# shapiro_pvalue                  0.0        0.0                   0.0
#
#                             sqrt_IQR sqrt_zscore
# moyenne                       6.5643      6.5643
# moyenne_min                   5.9079      5.9079
# moyenne_max                   7.2207      7.2207
# test_moyenne_10_pourcents       True        True
# mediane                       6.6332      6.6332
# mode                          4.3589      4.3589
# moyenne_tronquee              6.5523      6.5523
# ecart_type                    1.2785      1.2785
# CV                            0.1948      0.1948
# IQR                           1.9821      1.9821
# outlier_max_iqr            10.522984   10.522984
# outlier_min_iqr             2.594614    2.594614
# nb_outlier_iqr                     0           0
# outlier_max_zscore           9.69536     9.69536
# outlier_min_zscore          2.729004    2.729004
# nb_outlier_zscore                  0           0
# skewness                      0.0264      0.0264
# skewness_pvalue               0.3169      0.3169
# kurtosis                     -0.8641     -0.8641
# kurtosis_pvalue                  0.0         0.0
# ks_pvalue                        0.0         0.0
# shapiro_pvalue                   0.0         0.0
