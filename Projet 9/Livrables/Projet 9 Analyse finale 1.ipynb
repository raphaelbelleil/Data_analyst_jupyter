# %% [markdown]
# # Analyse

# %% [markdown]
# Nous allons maintenant créer des clusters parmis les pays.
#
# Nous procéderons d'abord à une classification hiérarchique, puis nous formerons des clusters à l'aide de la méthode du Kmeans et nous ferons une ACP afin de visualiser les pays sur 2 et 3 dimensions.
#
# Nous utiliserons les données avec imputation par KNN.
#
# Pour la première itération, je garde les 4 outliers, toutes les variables et je réalise une ACP.
#
# Pour la deuxième itération, j'enlèverai les 4 outliers, certaines variables et je modifierai le nombre de clusters.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

import warnings

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %%
from factor_analyzer import calculate_kmo
from factor_analyzer import calculate_bartlett_sphericity

# %%
import plotly.express as px

# %%
folder = 'D:/Data_Analyst_Projet/Projet 9/Donnees/fichier analyse/'

# %%
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_row', 150)

# %%
warnings.simplefilter('ignore')

# %% [markdown]
# ## Import fichiers

# %%
df = pd.read_csv(folder+'pays_knn.csv')
df.head()
# Out:
#              pays  exportation_volaille  importation_volaille   production  \
# 0  Afrique du Sud             63,000.00            514,000.00 1,667,000.00
# 1         Albanie                  0.00             38,000.00    13,000.00
# 2         Algérie                  0.00              2,000.00   275,000.00
# 3       Allemagne            646,000.00            842,000.00 1,514,000.00
# 4          Angola                  0.00            277,000.00    42,000.00
#
#    volaille_consommée  taux_dependance  taux_autosuffisance  \
# 0        2,035,000.00             0.24                 0.76
# 1           47,000.00             0.81                 0.28
# 2          264,000.00             0.01                 0.99
# 3        1,609,000.00             0.48                 0.50
# 4          315,000.00             0.87                 0.13
#
#    proportion_volaille_nourriture  proportion_animaux_nourriture  \
# 0                            0.06                           0.12
# 1                            0.01                           0.05
# 2                            0.01                           0.03
# 3                            0.02                           0.10
# 4                            0.02                           0.07
#
#      population  accroissement_population_moyen_par_annee  \
# 0 57,009,756.00                                674,990.00
# 1  2,884,169.00                                -12,973.84
# 2 41,389,189.00                                588,745.95
# 3 82,658,409.00                                 90,712.42
# 4 29,816,766.00                                758,648.11
#
#    taux_accroissement_population_moyen  lpi                  pib  \
# 0                                 0.01 3.57   381,448,814,653.46
# 1                                -0.00 2.56    13,019,689,336.69
# 2                                 0.01 2.52   170,097,014,589.13
# 3                                 0.00 4.13 3,690,849,152,517.65
# 4                                 0.03 2.24    68,972,769,395.63
#
#    taux_droit_douane  quantite_conteneurs_par_annee  taux_population_urbaine  \
# 0               4.44                   4,563,618.00                     0.66
# 1               1.43                     118,270.00                     0.60
# 2               9.28                   1,725,238.00                     0.72
# 3               1.81                  15,169,595.00                     0.77
# 4               8.52                     570,200.00                     0.65
#
#    stabilite_politique  pib_par_habitant  classement_consommation
# 0                -0.28          6,690.94                    10.00
# 1                 0.38          4,514.19                   101.50
# 2                -0.92          4,109.70                    51.50
# 3                 0.59         44,651.83                    15.00
# 4                -0.33          2,313.22                    48.50

# %%
df.shape
# Out:
# (132, 20)

# %%
# on garde uniquement les données numériques pour l'analyse 
X = df.drop(columns='pays')

# %%
# pays dans une variable array
pays = df['pays'].values

# %%
# indicateur dans une variable array
variables = X.columns.values

# %% [markdown]
# ## Classification hiérarchique

# %% [markdown]
# Les différences entre les individus peut se calculer avec la distance euclidienne :
# la racine de la somme des différences au carré.
#
# Lors d'une classification hiérarchique, au départ il y a autant de clusters que d'individus.
#
# Ensuite, on regroupe 2 à 2 les individus qui ont la plus petite distance euclidienne, jusqu'à qu'il y est un seul cluster.

# %%
# Centrage et réduction pour s'assurer que chaque variable à le même poids sur la classification
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# La méthode de classification hiérarchique s'effectue avec peu de données (50 ou moins).
#
# Nous allons donc prendre un échantillon aléatoire et effectuer le mélange plusieurs fois.

# %%
# df standardisé
df_X_scaled = pd.DataFrame(X_scaled, columns=variables, index=pays)
df_X_scaled.head()
# Out:
#                 exportation_volaille  importation_volaille  production  \
# Afrique du Sud                 -0.14                  1.97        0.27
# Albanie                        -0.26                 -0.35       -0.32
# Algérie                        -0.26                 -0.52       -0.23
# Allemagne                       0.99                  3.57        0.22
# Angola                         -0.26                  0.82       -0.31
#
#                 volaille_consommée  taux_dependance  taux_autosuffisance  \
# Afrique du Sud                0.51            -0.34                 0.21
# Albanie                      -0.33             0.80                -0.76
# Algérie                      -0.23            -0.82                 0.69
# Allemagne                     0.33             0.15                -0.31
# Angola                       -0.21             0.93                -1.05
#
#                 proportion_volaille_nourriture  proportion_animaux_nourriture  \
# Afrique du Sud                            1.41                           0.51
# Albanie                                  -0.84                          -1.18
# Algérie                                  -1.06                          -1.54
# Allemagne                                -0.50                           0.09
# Angola                                   -0.60                          -0.66
#
#                 population  accroissement_population_moyen_par_annee  \
# Afrique du Sud        0.04                                      0.12
# Albanie              -0.27                                     -0.31
# Algérie              -0.05                                      0.07
# Allemagne             0.19                                     -0.25
# Angola               -0.12                                      0.18
#
#                 taux_accroissement_population_moyen   lpi   pib  \
# Afrique du Sud                                 0.24  1.12 -0.10
# Albanie                                       -1.54 -0.83 -0.28
# Algérie                                        0.49 -0.90 -0.20
# Allemagne                                     -0.93  2.20  1.49
# Angola                                         1.71 -1.44 -0.25
#
#                 taux_droit_douane  quantite_conteneurs_par_annee  \
# Afrique du Sud              -0.16                          -0.04
# Albanie                     -0.90                          -0.26
# Algérie                      1.03                          -0.18
# Allemagne                   -0.80                           0.48
# Angola                       0.84                          -0.24
#
#                 cout_production_volaille  taux_population_urbaine  \
# Afrique du Sud                     -0.27                     0.12
# Albanie                            -0.18                    -0.13
# Algérie                             0.00                     0.42
# Allemagne                          -1.21                     0.66
# Angola                             -0.00                     0.08
#
#                 stabilite_politique  pib_par_habitant
# Afrique du Sud                -0.32             -0.50
# Albanie                        0.43             -0.60
# Algérie                       -1.04             -0.62
# Allemagne                      0.67              1.34
# Angola                        -0.37             -0.71

# %%
# faire random sample echantillon de 30 pays
# faire plusieurs itération pour valider les clusters
echantillon = df_X_scaled.sample(50)


# mesure les liens entre les clusters avec la méthode de ward
# chaque fois que 2 clusters sont regroupés, cherche à minimiser l'inertie intraclasse

Z = linkage(echantillon, 'ward')


# création du dendogramme
plt.figure(figsize=(10,10))
dendrogram(Z, p=echantillon.shape[0], truncate_mode='lastp', distance_sort='ascending',
           orientation='right', labels=echantillon.index)
plt.title("Dendrogramme, Classification ascendante hiérarchique des pays")
plt.xlabel('Distance')
plt.show();

# %%
Z
# Out:
# array([[16.        , 30.        ,  0.9116356 ,  2.        ],
#        [ 4.        ,  9.        ,  1.12485256,  2.        ],
#        [41.        , 48.        ,  1.16792146,  2.        ],
#        [15.        , 49.        ,  1.21523457,  2.        ],
#        [ 5.        , 40.        ,  1.51690541,  2.        ],
#        [ 7.        , 12.        ,  1.5801096 ,  2.        ],
#        [13.        , 26.        ,  1.61875093,  2.        ],
#        [39.        , 46.        ,  1.66490295,  2.        ],
#        [28.        , 44.        ,  1.76989115,  2.        ],
#        [11.        , 51.        ,  1.86642249,  3.        ],
#        [35.        , 37.        ,  1.87835221,  2.        ],
#        [27.        , 54.        ,  1.89597495,  3.        ],
#        [33.        , 45.        ,  1.97487792,  2.        ],
#        [38.        , 53.        ,  1.97519795,  3.        ],
#        [21.        , 50.        ,  2.00982445,  3.        ],
#        [ 1.        , 34.        ,  2.08942175,  2.        ],
#        [ 0.        , 58.        ,  2.29647098,  3.        ],
#        [ 8.        , 25.        ,  2.3877391 ,  2.        ],
#        [23.        , 65.        ,  2.66014239,  3.        ],
#        [59.        , 63.        ,  2.67715981,  6.        ],
#        [36.        , 57.        ,  2.74161355,  3.        ],
#        [ 2.        , 20.        ,  2.87398427,  2.        ],
#        [32.        , 64.        ,  2.89419268,  4.        ],
#        [14.        , 17.        ,  2.92390071,  2.        ],
#        [10.        , 56.        ,  2.95988894,  3.        ],
#        [19.        , 31.        ,  2.97804771,  2.        ],
#        [52.        , 61.        ,  3.05200032,  5.        ],
#        [66.        , 69.        ,  3.21289158,  9.        ],
#        [62.        , 71.        ,  3.36050292,  4.        ],
#        [43.        , 47.        ,  3.50416072,  2.        ],
#        [22.        , 55.        ,  3.60591207,  3.        ],
#        [70.        , 74.        ,  3.74616965,  6.        ],
#        [68.        , 73.        ,  3.74838741,  5.        ],
#        [ 3.        , 72.        ,  4.17028423,  5.        ],
#        [77.        , 82.        ,  4.63506434, 14.        ],
#        [60.        , 83.        ,  4.70876711,  7.        ],
#        [76.        , 81.        ,  5.11538866, 11.        ],
#        [78.        , 84.        ,  5.23754801, 18.        ],
#        [75.        , 80.        ,  5.37036848,  5.        ],
#        [24.        , 85.        ,  5.51950497,  8.        ],
#        [67.        , 87.        ,  6.52138825, 20.        ],
#        [79.        , 90.        ,  8.56608306, 22.        ],
#        [42.        , 86.        ,  9.52585374, 12.        ],
#        [89.        , 91.        ,  9.74031214, 30.        ],
#        [88.        , 92.        , 11.19066675, 17.        ],
#        [ 6.        , 94.        , 14.81547286, 18.        ],
#        [18.        , 29.        , 15.32848722,  2.        ],
#        [93.        , 95.        , 17.15675805, 48.        ],
#        [96.        , 97.        , 26.89591872, 50.        ]])

# %% [markdown]
# On distingue 3 clusters graphiquement et les distances euclidiennes entre les clusters sont plus proches à partir de la 4e valeur d'après le Z (3e colonne).
#
# Cependant, il semblerait que les outliers forment un cluster à eux tout seul. Ce qui n'est pas bon dans une classification.
# On continue tout de même jusqu'au bout, on réglera cela lors de la prochaine itération.

# %%
# Dendogramme global

Z = linkage(X_scaled, 'ward')


# création du dendogramme
plt.figure(figsize=(10,20))
dendrogram(Z, p=X_scaled.shape[0], truncate_mode='lastp', distance_sort='ascending',
           orientation='right', labels=pays)
plt.title("Dendrogramme, Classification ascendante hiérarchique des pays")
plt.xlabel('Distance')
plt.show();

# %%
Z
# Out:
# array([[ 76.        , 129.        ,   0.85099539,   2.        ],
#        [ 52.        ,  96.        ,   0.87057338,   2.        ],
#        [ 65.        ,  88.        ,   0.9116356 ,   2.        ],
#        [ 21.        ,  46.        ,   1.00642015,   2.        ],
#        [  2.        , 120.        ,   1.05718429,   2.        ],
#        [ 51.        ,  82.        ,   1.13331058,   2.        ],
#        [ 39.        , 108.        ,   1.17674814,   2.        ],
#        [102.        , 106.        ,   1.20248389,   2.        ],
#        [ 32.        , 103.        ,   1.21523457,   2.        ],
#        [ 73.        ,  79.        ,   1.26452178,   2.        ],
#        [ 85.        , 111.        ,   1.27785248,   2.        ],
#        [  1.        ,  50.        ,   1.2778817 ,   2.        ],
#        [ 68.        ,  71.        ,   1.29244622,   2.        ],
#        [ 84.        ,  89.        ,   1.29400063,   2.        ],
#        [109.        , 116.        ,   1.32003486,   2.        ],
#        [ 33.        ,  98.        ,   1.33436914,   2.        ],
#        [141.        , 143.        ,   1.37352371,   4.        ],
#        [ 70.        , 135.        ,   1.40755834,   3.        ],
#        [ 91.        , 132.        ,   1.4110251 ,   3.        ],
#        [  9.        ,  86.        ,   1.42451307,   2.        ],
#        [ 34.        , 118.        ,   1.43061207,   2.        ],
#        [ 19.        , 144.        ,   1.45480047,   3.        ],
#        [133.        , 146.        ,   1.46651652,   4.        ],
#        [  3.        ,  99.        ,   1.47226368,   2.        ],
#        [114.        , 126.        ,   1.49914958,   2.        ],
#        [ 38.        ,  60.        ,   1.51690541,   2.        ],
#        [ 83.        , 134.        ,   1.52317152,   3.        ],
#        [  5.        , 105.        ,   1.57904371,   2.        ],
#        [  4.        ,  30.        ,   1.60012847,   2.        ],
#        [ 22.        , 152.        ,   1.60456759,   3.        ],
#        [ 48.        , 137.        ,   1.612071  ,   3.        ],
#        [ 10.        ,  57.        ,   1.61875093,   2.        ],
#        [ 29.        ,  97.        ,   1.63572102,   2.        ],
#        [ 11.        ,  40.        ,   1.72123182,   2.        ],
#        [113.        , 142.        ,   1.74749253,   3.        ],
#        [ 20.        ,  47.        ,   1.76103115,   2.        ],
#        [100.        , 158.        ,   1.83514732,   4.        ],
#        [ 49.        , 110.        ,   1.83648841,   2.        ],
#        [ 28.        ,  90.        ,   1.84693067,   2.        ],
#        [ 61.        , 119.        ,   1.87948382,   2.        ],
#        [101.        , 157.        ,   1.89597495,   3.        ],
#        [  7.        ,  24.        ,   1.96067546,   2.        ],
#        [107.        , 149.        ,   1.9656807 ,   4.        ],
#        [140.        , 164.        ,   1.9679592 ,   4.        ],
#        [139.        , 147.        ,   1.96998308,   4.        ],
#        [ 43.        , 155.        ,   2.02058032,   3.        ],
#        [138.        , 153.        ,   2.02141755,   5.        ],
#        [ 23.        ,  42.        ,   2.03339829,   2.        ],
#        [ 93.        , 127.        ,   2.16495678,   2.        ],
#        [ 94.        , 117.        ,   2.17135298,   2.        ],
#        [ 64.        , 165.        ,   2.25126945,   3.        ],
#        [ 12.        , 171.        ,   2.27684241,   3.        ],
#        [ 16.        , 176.        ,   2.27752503,   5.        ],
#        [150.        , 175.        ,   2.2793999 ,   7.        ],
#        [ 15.        , 162.        ,   2.3258162 ,   4.        ],
#        [ 37.        , 185.        ,   2.34146067,   8.        ],
#        [  0.        ,   6.        ,   2.34987027,   2.        ],
#        [ 75.        , 123.        ,   2.37966862,   2.        ],
#        [ 63.        ,  66.        ,   2.3877391 ,   2.        ],
#        [136.        , 161.        ,   2.39137394,   5.        ],
#        [ 74.        , 173.        ,   2.41747452,   3.        ],
#        [ 67.        ,  81.        ,   2.43528347,   2.        ],
#        [ 69.        , 121.        ,   2.48850748,   2.        ],
#        [ 36.        , 112.        ,   2.5120138 ,   2.        ],
#        [ 14.        , 156.        ,   2.51242103,   3.        ],
#        [ 45.        , 160.        ,   2.60972185,   3.        ],
#        [172.        , 179.        ,   2.6347144 ,   5.        ],
#        [ 31.        ,  56.        ,   2.67006842,   2.        ],
#        [ 54.        , 180.        ,   2.6855865 ,   3.        ],
#        [163.        , 166.        ,   2.85245884,   5.        ],
#        [148.        , 193.        ,   2.85608426,   6.        ],
#        [ 17.        , 182.        ,   2.89338636,   4.        ],
#        [122.        , 167.        ,   2.9491138 ,   3.        ],
#        [ 13.        ,  92.        ,   2.96123048,   2.        ],
#        [ 55.        , 191.        ,   2.99119414,   6.        ],
#        [186.        , 187.        ,   3.03499846,  12.        ],
#        [ 77.        , 170.        ,   3.16167481,   3.        ],
#        [ 35.        , 201.        ,   3.23773222,   6.        ],
#        [115.        , 168.        ,   3.24652023,   5.        ],
#        [ 78.        , 188.        ,   3.26008151,   3.        ],
#        [ 87.        , 190.        ,   3.27003444,   3.        ],
#        [ 59.        , 192.        ,   3.3004835 ,   4.        ],
#        [169.        , 196.        ,   3.34502781,   5.        ],
#        [104.        , 159.        ,   3.38561883,   3.        ],
#        [154.        , 178.        ,   3.42841646,   9.        ],
#        [184.        , 204.        ,   3.44567913,   8.        ],
#        [ 62.        , 177.        ,   3.50182747,   4.        ],
#        [174.        , 197.        ,   3.61167926,   7.        ],
#        [ 80.        , 124.        ,   3.68852599,   2.        ],
#        [ 95.        , 195.        ,   3.69696696,   3.        ],
#        [  8.        , 202.        ,   3.81777569,   7.        ],
#        [ 44.        , 181.        ,   3.82700702,   3.        ],
#        [194.        , 200.        ,   3.84744081,   5.        ],
#        [189.        , 216.        ,   3.88874962,  11.        ],
#        [151.        , 198.        ,   4.02334399,   7.        ],
#        [125.        , 199.        ,   4.02959388,   3.        ],
#        [ 58.        ,  72.        ,   4.02980827,   2.        ],
#        [128.        , 212.        ,   4.05697555,   4.        ],
#        [207.        , 208.        ,   4.07284778,  15.        ],
#        [203.        , 217.        ,   4.20870992,  12.        ],
#        [ 41.        , 183.        ,   4.22763339,   4.        ],
#        [210.        , 214.        ,   4.60237043,  10.        ],
#        [223.        , 231.        ,   4.93594653,  15.        ],
#        [206.        , 233.        ,   4.9503146 ,  16.        ],
#        [ 26.        , 228.        ,   4.95645989,   3.        ],
#        [145.        , 224.        ,   4.98958618,   7.        ],
#        [221.        , 232.        ,   5.12853463,   7.        ],
#        [213.        , 226.        ,   5.28247804,  11.        ],
#        [131.        , 219.        ,   5.554568  ,   8.        ],
#        [220.        , 230.        ,   5.9036155 ,  17.        ],
#        [215.        , 238.        ,   6.39592659,  10.        ],
#        [211.        , 218.        ,   6.50258204,   7.        ],
#        [227.        , 237.        ,   6.83266574,  10.        ],
#        [225.        , 234.        ,   6.86774174,  26.        ],
#        [209.        , 239.        ,   7.58179208,  17.        ],
#        [222.        , 245.        ,   7.62007529,  33.        ],
#        [ 25.        , 205.        ,   7.78071423,   3.        ],
#        [235.        , 244.        ,   7.84478065,  26.        ],
#        [229.        , 240.        ,   8.87770743,  12.        ],
#        [241.        , 247.        ,   9.65021909,  50.        ],
#        [ 18.        , 130.        ,  10.30881627,   2.        ],
#        [236.        , 246.        ,  11.13132335,  20.        ],
#        [249.        , 250.        ,  11.98679602,  38.        ],
#        [243.        , 253.        ,  13.06006253,  27.        ],
#        [242.        , 251.        ,  15.22393198,  60.        ],
#        [ 27.        ,  53.        ,  15.32848722,   2.        ],
#        [248.        , 255.        ,  15.49909051,  30.        ],
#        [254.        , 256.        ,  17.73791208,  98.        ],
#        [252.        , 257.        ,  18.59932164,   4.        ],
#        [258.        , 259.        ,  24.24723756, 128.        ],
#        [260.        , 261.        ,  32.4707846 , 132.        ]])

# %% [markdown]
# On distingue bien 3 à 4 clusters avec un des clusters composé des 4 outliers.

# %%
# création de la classification
cah = AgglomerativeClustering(n_clusters=3, linkage='ward')

cah = cah.fit(X_scaled)

# %%
# création des clusters
clusters_cah = cah.labels_

df['clusters_cah'] = clusters_cah

# %% [markdown]
# La classification hiérarchique fait ressortir 3 à 4 clusters. On divisera l'échantillon en 3 clusters pour cette itération.

# %% [markdown]
# ## Kmeans

# %% [markdown]
# ### Méthode du coude avec standardisation

# %%
# méthode du coude pour déterminer le nombre de clusters le plus pertinents
# on standardise les données au préalable

liste_clusters = []

for n in range(1,30):
    kmeans = KMeans(n_clusters=n, random_state=1)
    kmeans.fit(X_scaled)
    liste_clusters.append(kmeans.inertia_)

plt.plot(range(1,30), liste_clusters)
plt.xlabel('Nombre de clusters');

# %% [markdown]
# Pas vraiment de coude visible, on distingue de légères cassures à 2, 3 et 4 clusters.

# %% [markdown]
# ### Mesure de qualité des clusters : Silhouette score et Davies Bouldin score
#
# Le **silhouette score** mesure si les individus sont bien regroupés à l'intérieur de leur clusters tout en étant suffisamment séparés des autres clusters. Il varie entre -1 et 1.
#
# - Un score de silhouette proche de 1 indique que l'individu est bien placé dans son propre cluster et qu'il est loin des individus des autres clusters.
# - Un score de silhouette proche de 0 indique que l'individu est proche de la frontière entre deux clusters.
# - Un score de silhouette proche de -1 indique que l'individu est probablement mal placé et qu'il serait mieux dans un autre cluster.
#
#
# Le **Davies-Bouldin score** mesure l'homégénéité du cluster (variance intraclasse) et la séparation entre clusters (variance interclasse). On cherche à avoir une homogénéité faible et une séparation élevé.
# Le **Davies-Bouldin score** doit être minimum pour un bon clustering.

# %%
silhouette = []
davies = []

for n_clusters in range(2,20):
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(X_scaled)
    clusters_kmeans = kmeans.labels_
    silhouette.append(silhouette_score(X_scaled, clusters_kmeans))
    davies.append(davies_bouldin_score(X_scaled, clusters_kmeans))
    
plt.plot(range(2,20), silhouette, marker='o')
plt.title('silhouette_score en fonction du nombre de clusters')
plt.xticks(np.arange(2, 20, 2))
plt.show()

plt.plot(range(2,20), davies, marker='o')
plt.title('davies_bouldin_score en fonction du nombre de clusters')
plt.xticks(np.arange(2, 20, 2))
plt.show()

# %% [markdown]
# Les 2 scores indiquent 2 clusters comme le meilleurs choix.
#
# Cependant un des clusters est composé seulement des outliers.
#
# Créer seulement 2 clusters va peut partitionner les données et aider à la décision pour l'étude de marché, on choisi 3 clusters pour la première itération.

# %% [markdown]
# #### Réalisation KMeans

# %%
# création de l'estimateur

kmeans = KMeans(n_clusters=3, random_state=1)

kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, random_state=1)

# %%
# coordonnées des centroides

centroides = kmeans.cluster_centers_

# %%
# clusters de l'echantillon

clusters_kmeans = kmeans.labels_
df['clusters_kmeans']=clusters_kmeans

# %% [markdown]
# ## ACP (ou PCA), Analyse en composantes principales

# %% [markdown]
# L'analyse en composantes principales est une technique de réduction de dimensions.
#
# L'objectif est de trouver 3 variables (les composantes principales) qui résument au mieux l'ensemble de nos variables de départ.
# Chaque composantes principales est une combinaison linéaire des variables de départ et idéalement, elles résument chacunes une partie des variables de départ indépendamment.
#
# L'ACP va permettre de visualiser les données dans un espace à 2 ou 3 dimensions, à grouper nos variables et à identifier les similarités et les disparités entre individus.

# %% [markdown]
# ### Evaluation de la qualité de la PCA

# %% [markdown]
# On va mesurer l'utilité et la qualité de l'analyse en composantes principales grâce au KMO.
#
# Le KMO indique si les variables sont assez corrélées pour faire une ACP. Plus le score est élevé, plus l'ACP est pertinente.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X
# Out:
#      exportation_volaille  importation_volaille    production  \
# 0               63,000.00            514,000.00  1,667,000.00
# 1                    0.00             38,000.00     13,000.00
# 2                    0.00              2,000.00    275,000.00
# 3              646,000.00            842,000.00  1,514,000.00
# 4                    0.00            277,000.00     42,000.00
# 5                    0.00              7,000.00          0.00
# 6               10,000.00            722,000.00    616,000.00
# 7              207,000.00              8,000.00  2,161,000.00
# 8                    0.00             35,000.00     11,000.00
# 9               42,000.00             16,000.00  1,269,000.00
# 10              78,000.00            110,000.00    148,000.00
# 11                   0.00             27,000.00    104,000.00
# 12                   0.00              2,000.00     15,000.00
# 13             656,000.00            338,000.00    463,000.00
# 14                   0.00                  0.00     20,000.00
# 15               1,000.00              1,000.00    533,000.00
# 16               8,000.00             10,000.00     61,000.00
# 17                   0.00              3,000.00      5,000.00
# 18           4,223,000.00              3,000.00 14,201,000.00
# 19              45,000.00            108,000.00    107,000.00
# 20             152,000.00             21,000.00    463,000.00
# 21                   0.00            123,000.00     18,000.00
# 22                   0.00                  0.00     81,000.00
# 23             163,000.00            182,000.00  1,417,000.00
# 24             115,000.00            155,000.00    712,000.00
# 25             663,000.00            907,000.00     24,000.00
# 26                   0.00             23,000.00      3,000.00
# 27             576,000.00            452,000.00 18,236,000.00
# 28               1,000.00             14,000.00     25,000.00
# 29               2,000.00             78,000.00  1,564,000.00
# 30                   0.00            104,000.00      7,000.00
# 31                   0.00            104,000.00      7,000.00
# 32               3,000.00             17,000.00    133,000.00
# 33              17,000.00             24,000.00     61,000.00
# 34                   0.00              7,000.00     58,000.00
# 35             139,000.00            133,000.00    173,000.00
# 36                   0.00              4,000.00          0.00
# 37               2,000.00             16,000.00    136,000.00
# 38             212,000.00            205,000.00  1,515,000.00
# 39              11,000.00             21,000.00     20,000.00
# 40                   0.00              2,000.00      6,000.00
# 41                   0.00              3,000.00     23,000.00
# 42              12,000.00             16,000.00    129,000.00
# 43             501,000.00            506,000.00  1,750,000.00
# 44             115,000.00            226,000.00  4,444,000.00
# 45                   0.00             76,000.00      4,000.00
# 46                   0.00            151,000.00     60,000.00
# 47              29,000.00             79,000.00    246,000.00
# 48               7,000.00            129,000.00    235,000.00
# 49                   0.00                  0.00     31,000.00
# 50               5,000.00             51,000.00     22,000.00
# 51               1,000.00             12,000.00    193,000.00
# 52             210,000.00             58,000.00    493,000.00
# 53               4,000.00                  0.00  3,545,000.00
# 54                   0.00              1,000.00  2,301,000.00
# 55              45,000.00              6,000.00  2,174,000.00
# 56                   0.00            470,000.00     96,000.00
# 57              93,000.00             99,000.00    110,000.00
# 58                   0.00              2,000.00     10,000.00
# 59               3,000.00                  0.00    629,000.00
# 60             183,000.00             97,000.00  1,315,000.00
# 61               1,000.00             31,000.00    128,000.00
# 62              10,000.00          1,069,000.00  2,215,000.00
# 63              10,000.00             64,000.00    210,000.00
# 64               6,000.00            174,000.00    171,000.00
# 65                   0.00                  0.00     35,000.00
# 66               4,000.00            137,000.00     56,000.00
# 67                   0.00             15,000.00      2,000.00
# 68              20,000.00             43,000.00     33,000.00
# 69               4,000.00             13,000.00     64,000.00
# 70                   0.00             48,000.00     15,000.00
# 71              68,000.00             44,000.00    118,000.00
# 72               1,000.00             11,000.00          0.00
# 73               1,000.00             40,000.00      2,000.00
# 74              44,000.00             68,000.00  1,724,000.00
# 75                   0.00              9,000.00      4,000.00
# 76               1,000.00              3,000.00    762,000.00
# 77                   0.00              2,000.00     48,000.00
# 78               9,000.00            972,000.00  3,249,000.00
# 79                   0.00              8,000.00      4,000.00
# 80                   0.00              3,000.00  1,662,000.00
# 81              12,000.00             29,000.00     11,000.00
# 82                   0.00              6,000.00    143,000.00
# 83                   0.00              3,000.00     19,000.00
# 84                   0.00                  0.00    201,000.00
# 85                   0.00              2,000.00    101,000.00
# 86              23,000.00              1,000.00    223,000.00
# 87              16,000.00            126,000.00      7,000.00
# 88                   0.00                  0.00     65,000.00
# 89               4,000.00              2,000.00  1,281,000.00
# 90                   0.00             20,000.00    198,000.00
# 91               4,000.00              1,000.00     45,000.00
# 92           1,418,000.00            608,000.00  1,100,000.00
# 93               2,000.00            249,000.00  1,272,000.00
# 94           1,025,000.00             55,000.00  2,351,000.00
# 95                   0.00             15,000.00      1,000.00
# 96              44,000.00             82,000.00    361,000.00
# 97               1,000.00             60,000.00  1,465,000.00
# 98              69,000.00            146,000.00    392,000.00
# 99             359,000.00            779,000.00  1,814,000.00
# 100                  0.00                  0.00     19,000.00
# 101              6,000.00            137,000.00    838,000.00
# 102                  0.00             16,000.00     54,000.00
# 103              6,000.00             42,000.00    339,000.00
# 104                  0.00              4,000.00          0.00
# 105                  0.00             17,000.00          0.00
# 106              7,000.00             12,000.00     85,000.00
# 107                  0.00             14,000.00     17,000.00
# 108             35,000.00             63,000.00     71,000.00
# 109             29,000.00             20,000.00     72,000.00
# 110              2,000.00                  0.00    192,000.00
# 111              4,000.00             51,000.00     91,000.00
# 112              5,000.00             18,000.00     10,000.00
# 113             23,000.00             84,000.00    157,000.00
# 114                  0.00                  0.00     77,000.00
# 115                  0.00              1,000.00      6,000.00
# 116             27,000.00            116,000.00    163,000.00
# 117            796,000.00              2,000.00  1,676,000.00
# 118                  0.00             16,000.00     40,000.00
# 119                  0.00             23,000.00     61,000.00
# 120              4,000.00                  0.00    213,000.00
# 121            429,000.00              3,000.00  2,192,000.00
# 122            273,000.00            121,000.00  1,211,000.00
# 123              3,000.00              3,000.00     33,000.00
# 124              1,000.00            291,000.00    918,000.00
# 125                  0.00             78,000.00    168,000.00
# 126              1,000.00             12,000.00     49,000.00
# 127              1,000.00            110,000.00  1,118,000.00
# 128             94,000.00            433,000.00     48,000.00
# 129                  0.00                  0.00    340,000.00
# 130          3,692,000.00            123,000.00 21,914,000.00
# 131                  0.00              6,000.00          0.00
#
#      volaille_consommée  taux_dependance  taux_autosuffisance  \
# 0          2,035,000.00             0.24                 0.76
# 1             47,000.00             0.81                 0.28
# 2            264,000.00             0.01                 0.99
# 3          1,609,000.00             0.48                 0.50
# 4            315,000.00             0.87                 0.13
# 5              5,000.00             1.00                 0.00
# 6          1,435,000.00             0.50                 0.42
# 7          1,856,000.00             0.00                 1.00
# 8             47,000.00             0.74                 0.23
# 9          1,171,000.00             0.01                 1.05
# 10           160,000.00             0.64                 0.40
# 11           129,000.00             0.21                 0.81
# 12            13,000.00             0.12                 0.88
# 13           144,000.00             2.22                -1.27
# 14            10,000.00             0.00                 1.05
# 15           403,000.00             0.00                 1.24
# 16            56,000.00             0.18                 0.96
# 17             7,000.00             0.43                 0.71
# 18         9,982,000.00             0.00                 1.00
# 19           157,000.00             0.69                 0.39
# 20           264,000.00             0.08                 1.17
# 21           161,000.00             0.76                 0.11
# 22            78,000.00             0.00                 0.99
# 23         1,433,000.00             0.13                 0.88
# 24           672,000.00             0.23                 0.89
# 25           391,000.00             3.24                -2.28
# 26            21,000.00             1.21                 0.16
# 27        17,518,000.00             0.02                 0.97
# 28            30,000.00             0.37                 0.63
# 29         1,565,000.00             0.05                 0.95
# 30           110,000.00             0.95                 0.06
# 31           110,000.00             0.95                 0.06
# 32           131,000.00             0.13                 0.97
# 33            45,000.00             0.53                 0.98
# 34            62,000.00             0.11                 0.89
# 35           166,000.00             0.80                 0.20
# 36             3,000.00             1.00                 0.00
# 37           131,000.00             0.12                 1.02
# 38         1,418,000.00             0.14                 0.87
# 39            28,000.00             0.72                 0.31
# 40             7,000.00             0.29                 0.86
# 41            25,000.00             0.12                 0.88
# 42           103,000.00             0.14                 1.05
# 43         1,485,000.00             0.32                 0.79
# 44         4,509,000.00             0.05                 0.95
# 45            61,000.00             0.97                 0.05
# 46           211,000.00             0.72                 0.28
# 47           162,000.00             0.44                 1.22
# 48           348,000.00             0.36                 0.64
# 49            30,000.00             0.00                 0.97
# 50            61,000.00             0.84                 0.28
# 51           205,000.00             0.06                 0.94
# 52           246,000.00             0.22                 1.06
# 53         2,965,000.00             0.00                 0.97
# 54         1,904,000.00             0.00                 0.99
# 55         2,220,000.00             0.00                 0.96
# 56           561,000.00             0.83                 0.17
# 57           123,000.00             0.77                 0.13
# 58            10,000.00             0.20                 1.00
# 59           556,000.00             0.00                 0.98
# 60         1,146,000.00             0.08                 0.97
# 61           149,000.00             0.20                 0.84
# 62         2,359,000.00             0.44                 0.91
# 63           275,000.00             0.23                 0.73
# 64           330,000.00             0.53                 0.50
# 65            34,000.00             0.00                 1.00
# 66           188,000.00             0.72                 0.28
# 67            17,000.00             0.88                 0.12
# 68            41,000.00             1.05                 0.32
# 69            73,000.00             0.18                 0.82
# 70            50,000.00             0.96                 0.30
# 71            80,000.00             0.54                 0.61
# 72            11,000.00             1.00                -0.09
# 73            41,000.00             0.98                 0.02
# 74         1,220,000.00             0.04                 1.04
# 75            12,000.00             0.64                 0.29
# 76           746,000.00             0.00                 1.02
# 77            48,000.00             0.04                 0.98
# 78         4,058,000.00             0.23                 0.77
# 79            10,000.00             0.80                 0.40
# 80         1,621,000.00             0.00                 1.00
# 81            28,000.00             1.04                -0.04
# 82           138,000.00             0.04                 1.04
# 83            20,000.00             0.14                 0.90
# 84           192,000.00             0.00                 1.00
# 85           101,000.00             0.02                 0.99
# 86           164,000.00             0.01                 1.19
# 87           101,000.00             1.11                -0.08
# 88            62,000.00             0.00                 0.98
# 89         1,218,000.00             0.00                 1.00
# 90           139,000.00             0.10                 1.03
# 91            41,000.00             0.02                 1.00
# 92           346,000.00             1.63                -0.85
# 93         1,459,000.00             0.16                 0.83
# 94         1,150,000.00             0.05                 1.15
# 95            13,000.00             1.00                 0.07
# 96           315,000.00             0.25                 0.98
# 97           424,000.00             0.04                 0.96
# 98           381,000.00             0.38                 0.85
# 99         2,131,000.00             0.35                 0.65
# 100           18,000.00             0.00                 1.00
# 101          854,000.00             0.16                 0.97
# 102           66,000.00             0.24                 0.82
# 103          371,000.00             0.11                 0.89
# 104            3,000.00             1.00                 0.00
# 105           13,000.00             1.13                 0.00
# 106           90,000.00             0.13                 0.87
# 107           30,000.00             0.47                 0.57
# 108           76,000.00             0.85                 0.49
# 109           51,000.00             0.38                 0.83
# 110          164,000.00             0.00                 0.99
# 111          133,000.00             0.38                 0.65
# 112           18,000.00             0.72                 0.20
# 113          164,000.00             0.45                 0.72
# 114           73,000.00             0.00                 1.00
# 115            7,000.00             0.14                 0.86
# 116          234,000.00             0.47                 0.55
# 117          896,000.00             0.00                 1.00
# 118           54,000.00             0.30                 0.74
# 119           75,000.00             0.30                 0.80
# 120          195,000.00             0.00                 1.07
# 121        1,674,000.00             0.00                 1.05
# 122        1,006,000.00             0.12                 0.93
# 123           31,000.00             0.09                 0.91
# 124        1,166,000.00             0.24                 0.76
# 125          237,000.00             0.32                 0.68
# 126           58,000.00             0.20                 0.80
# 127        1,250,000.00             0.09                 0.89
# 128          412,000.00             1.05                -0.11
# 129          324,000.00             0.00                 1.00
# 130       18,100,000.00             0.01                 1.00
# 131            3,000.00             2.00                 0.00
#
#      proportion_volaille_nourriture  proportion_animaux_nourriture  \
# 0                              0.06                           0.12
# 1                              0.01                           0.05
# 2                              0.01                           0.03
# 3                              0.02                           0.10
# 4                              0.02                           0.07
# 5                              0.08                           0.20
# 6                              0.08                           0.12
# 7                              0.05                           0.15
# 8                              0.02                           0.06
# 9                              0.05                           0.16
# 10                             0.02                           0.11
# 11                             0.02                           0.05
# 12                             0.08                           0.19
# 13                             0.01                           0.08
# 14                             0.05                           0.09
# 15                             0.06                           0.13
# 16                             0.02                           0.04
# 17                             0.01                           0.06
# 18                             0.06                           0.14
# 19                             0.03                           0.10
# 20                             0.03                           0.10
# 21                             0.02                           0.05
# 22                             0.00                           0.04
# 23                             0.04                           0.11
# 24                             0.05                           0.14
# 25                             0.07                           0.30
# 26                             0.05                           0.22
# 27                             0.01                           0.10
# 28                             0.04                           0.14
# 29                             0.04                           0.08
# 30                             0.04                           0.10
# 31                             0.04                           0.10
# 32                             0.04                           0.11
# 33                             0.01                           0.09
# 34                             0.00                           0.05
# 35                             0.03                           0.10
# 36                             0.04                           0.09
# 37                             0.04                           0.07
# 38                             0.03                           0.14
# 39                             0.02                           0.07
# 40                             0.01                           0.06
# 41                             0.04                           0.11
# 42                             0.02                           0.10
# 43                             0.02                           0.12
# 44                             0.03                           0.11
# 45                             0.04                           0.13
# 46                             0.01                           0.05
# 47                             0.02                           0.09
# 48                             0.04                           0.09
# 49                             0.04                           0.09
# 50                             0.03                           0.07
# 51                             0.05                           0.08
# 52                             0.03                           0.11
# 53                             0.00                           0.02
# 54                             0.01                           0.09
# 55                             0.04                           0.07
# 56                             0.04                           0.06
# 57                             0.03                           0.10
# 58                             0.03                           0.16
# 59                             0.08                           0.14
# 60                             0.02                           0.11
# 61                             0.08                           0.13
# 62                             0.03                           0.16
# 63                             0.06                           0.09
# 64                             0.02                           0.08
# 65                             0.00                           0.05
# 66                             0.07                           0.11
# 67                             0.02                           0.06
# 68                             0.02                           0.10
# 69                             0.02                           0.05
# 70                             0.03                           0.06
# 71                             0.03                           0.11
# 72                             0.02                           0.11
# 73                             0.02                           0.05
# 74                             0.07                           0.18
# 75                             0.03                           0.13
# 76                             0.03                           0.08
# 77                             0.07                           0.13
# 78                             0.04                           0.11
# 79                             0.01                           0.08
# 80                             0.05                           0.18
# 81                             0.02                           0.07
# 82                             0.04                           0.08
# 83                             0.00                           0.03
# 84                             0.00                           0.02
# 85                             0.02                           0.10
# 86                             0.05                           0.16
# 87                             0.03                           0.09
# 88                             0.00                           0.04
# 89                             0.01                           0.04
# 90                             0.05                           0.12
# 91                             0.01                           0.10
# 92                             0.02                           0.09
# 93                             0.02                           0.11
# 94                             0.03                           0.10
# 95                             0.07                           0.21
# 96                             0.03                           0.12
# 97                             0.02                           0.07
# 98                             0.02                           0.07
# 99                             0.04                           0.10
# 100                            0.00                           0.02
# 101                            0.02                           0.14
# 102                            0.03                           0.08
# 103                            0.04                           0.08
# 104                            0.13                           0.26
# 105                            0.08                           0.18
# 106                            0.01                           0.08
# 107                            0.01                           0.05
# 108                            0.02                           0.10
# 109                            0.03                           0.10
# 110                            0.02                           0.08
# 111                            0.02                           0.09
# 112                            0.06                           0.10
# 113                            0.02                           0.11
# 114                            0.01                           0.07
# 115                            0.00                           0.12
# 116                            0.03                           0.11
# 117                            0.02                           0.10
# 118                            0.02                           0.05
# 119                            0.11                           0.18
# 120                            0.02                           0.04
# 121                            0.02                           0.05
# 122                            0.03                           0.07
# 123                            0.01                           0.09
# 124                            0.02                           0.15
# 125                            0.03                           0.07
# 126                            0.01                           0.08
# 127                            0.02                           0.07
# 128                            0.07                           0.13
# 129                            0.03                           0.09
# 130                            0.06                           0.14
# 131                            0.01                           0.06
#
#           population  accroissement_population_moyen_par_annee  \
# 0      57,009,756.00                                674,990.00
# 1       2,884,169.00                                -12,973.84
# 2      41,389,189.00                                588,745.95
# 3      82,658,409.00                                 90,712.42
# 4      29,816,766.00                                758,648.11
# 5          95,426.00                                  1,066.84
# 6      33,101,179.00                                686,258.58
# 7      43,937,140.00                                394,229.63
# 8       2,944,791.00                                 -6,202.42
# 9      24,584,620.00                                310,880.05
# 10      8,819,901.00                                 43,269.05
# 11      9,845,320.00                                 96,147.16
# 12        286,232.00                                    796.11
# 13     11,419,748.00                                 63,165.53
# 14        375,769.00                                  7,145.05
# 15     11,192,855.00                                154,467.26
# 16      3,351,525.00                                -22,486.89
# 17      2,205,080.00                                 32,143.89
# 18    207,833,823.00                              1,825,209.63
# 19      7,102,444.00                                -49,807.84
# 20      9,450,231.00                                -22,053.42
# 21     11,175,198.00                                243,110.16
# 22     24,566,073.00                                510,648.53
# 23     36,732,095.00                                341,377.84
# 24     18,470,439.00                                178,253.00
# 25      7,306,322.00                                 40,284.37
# 26        622,585.00                                 10,729.16
# 27  1,421,021,791.00                              7,215,632.68
# 28      1,179,678.00                                 12,946.05
# 29     48,909,839.00                                527,951.58
# 30      5,110,695.00                                111,418.32
# 31      5,110,695.00                                111,418.32
# 32      4,949,954.00                                 54,582.58
# 33      4,182,857.00                                -14,298.42
# 34     24,437,470.00                                453,398.00
# 35      5,732,274.00                                 21,628.00
# 36         71,458.00                                    103.95
# 37      6,388,126.00                                 28,042.63
# 38     46,647,428.00                                308,847.58
# 39      1,319,390.00                                 -4,010.11
# 40      1,124,805.00                                  6,886.63
# 41        877,459.00                                  3,814.58
# 42      5,511,371.00                                 17,611.68
# 43     64,842,509.00                                314,495.53
# 44    145,530,082.00                                -35,308.68
# 45      2,064,823.00                                 46,890.26
# 46     29,121,465.00                                552,012.95
# 47     10,569,450.00                                -29,466.21
# 48     16,914,970.00                                294,584.53
# 49        775,222.00                                  1,699.53
# 50      4,008,716.00                                -18,907.63
# 51      9,429,013.00                                158,579.63
# 52      9,729,823.00                                -27,000.42
# 53  1,338,676,785.00                             15,582,459.53
# 54    264,650,963.00                              2,955,616.84
# 55     80,673,883.00                                851,409.63
# 56     37,552,781.00                                786,106.05
# 57      4,753,279.00                                 54,504.58
# 58        334,393.00                                  2,962.00
# 59      8,243,848.00                                128,187.68
# 60     60,673,701.00                                207,111.21
# 61      2,920,848.00                                 14,744.53
# 62    127,502,725.00                                -16,946.42
# 63      9,785,843.00                                254,885.53
# 64     18,080,019.00                                178,784.16
# 65     50,221,142.00                              1,022,526.74
# 66      4,056,099.00                                110,115.21
# 67      2,091,534.00                                  3,974.95
# 68      1,951,097.00                                -23,984.47
# 69      6,819,373.00                                158,770.00
# 70      4,702,226.00                                103,711.42
# 71      2,845,414.00                                -36,872.37
# 72        591,910.00                                  8,849.58
# 73      2,081,996.00                                  2,533.58
# 74     31,104,646.00                                438,619.79
# 75        437,933.00                                  2,400.16
# 76     35,581,255.00                                380,811.26
# 77      1,264,499.00                                  4,317.89
# 78    124,777,324.00                              1,436,365.42
# 79        627,563.00                                    523.63
# 80     53,382,523.00                                367,822.05
# 81      2,402,633.00                                 34,406.84
# 82      6,384,846.00                                 73,484.16
# 83     21,602,382.00                                584,803.42
# 84    190,873,244.00                              3,873,201.74
# 85      5,296,326.00                                 44,136.58
# 86      4,702,034.00                                 46,533.26
# 87      4,665,928.00                                134,815.79
# 88     41,166,588.00                              1,004,150.74
# 89    207,906,209.00                              3,678,142.53
# 90      4,106,769.00                                 60,344.26
# 91      6,867,061.00                                 85,940.26
# 92     17,021,347.00                                 59,651.16
# 93    105,172,925.00                              1,508,402.05
# 94     37,953,180.00                                -33,426.37
# 95        276,102.00                                  1,947.00
# 96     10,288,527.00                                 -2,153.63
# 97     31,444,298.00                                291,016.63
# 98     19,653,969.00                               -138,489.74
# 99     66,727,461.00                                432,546.05
# 100    11,980,961.00                                229,909.95
# 101    51,096,415.00                                199,603.42
# 102     4,059,684.00                                 -7,932.32
# 103    10,513,104.00                                113,464.21
# 104        52,045.00                                    440.37
# 105       195,352.00                                  1,140.79
# 106     8,829,628.00                                -18,061.05
# 107     7,488,423.00                                161,346.26
# 108     5,447,900.00                                  2,831.74
# 109     2,076,394.00                                  4,743.16
# 110    21,128,032.00                                129,008.53
# 111     8,455,804.00                                 72,728.95
# 112       570,496.00                                  5,528.47
# 113     9,904,896.00                                 57,368.32
# 114    15,419,355.00                                318,767.84
# 115    15,016,753.00                                374,846.05
# 116    10,641,034.00                                 19,805.47
# 117    69,209,810.00                                340,832.16
# 118     7,698,474.00                                156,036.37
# 119     1,384,059.00                                  6,457.37
# 120    11,433,443.00                                 97,729.00
# 121    81,116,450.00                              1,005,257.58
# 122    44,487,709.00                               -241,679.42
# 123     3,436,641.00                                  6,818.37
# 124    94,600,648.00                                822,923.68
# 125    27,834,819.00                                583,663.74
# 126    16,853,599.00                                365,040.21
# 127    96,442,591.00                              1,557,475.63
# 128     9,487,203.00                                341,941.95
# 129    16,785,361.00                                231,749.21
# 130   325,084,756.00                              2,388,702.95
# 131       636,039.00                                 12,641.95
#
#      taux_accroissement_population_moyen  lpi                   pib  \
# 0                                   0.01 3.57    381,448,814,653.46
# 1                                  -0.00 2.56     13,019,689,336.69
# 2                                   0.01 2.52    170,097,014,589.13
# 3                                   0.00 4.13  3,690,849,152,517.65
# 4                                   0.03 2.24     68,972,769,395.63
# 5                                   0.01 2.90      1,467,977,777.78
# 6                                   0.02 3.19    688,586,094,412.68
# 7                                   0.01 2.96    643,628,665,302.15
# 8                                  -0.00 2.51     11,527,458,565.73
# 9                                   0.01 3.77  1,326,516,328,531.56
# 10                                  0.00 3.90    417,261,151,844.98
# 11                                  0.01 2.52     40,865,558,912.39
# 12                                  0.00 2.53      4,981,588,900.00
# 13                                  0.01 4.02    502,764,720,556.35
# 14                                  0.02 2.77      2,286,000,000.00
# 15                                  0.01 2.44     37,508,642,165.34
# 16                                 -0.01 2.80     18,080,118,186.01
# 17                                  0.01 2.76     16,105,182,316.33
# 18                                  0.01 3.09  2,063,507,864,886.88
# 19                                 -0.01 3.04     59,199,447,421.49
# 20                                 -0.00 2.58     54,726,595,249.18
# 21                                  0.02 2.71     12,701,655,845.96
# 22                                  0.02 2.37     36,098,550,141.59
# 23                                  0.01 3.87  1,649,265,644,244.09
# 24                                  0.01 3.18    276,364,933,679.63
# 25                                  0.01 3.97    341,273,289,534.47
# 26                                  0.02 3.58     50,440,941,938.70
# 27                                  0.01 3.59 12,310,409,370,892.76
# 28                                  0.01 3.12     22,946,726,163.58
# 29                                  0.01 2.79    311,883,730,442.05
# 30                                  0.02 2.35     38,019,265,625.88
# 31                                  0.02 2.35     38,019,265,625.88
# 32                                  0.01 2.78     60,516,043,590.18
# 33                                 -0.00 3.09     56,323,836,169.72
# 34                                  0.02 2.74     51,588,158,717.53
# 35                                  0.00 3.93    332,121,063,806.39
# 36                                  0.00 3.09        521,551,851.85
# 37                                  0.00 2.70     24,979,190,000.00
# 38                                  0.01 3.75  1,313,245,330,197.65
# 39                                 -0.00 3.27     26,924,385,103.07
# 40                                  0.01 2.66      4,402,969,225.92
# 41                                  0.00 2.36      5,353,404,418.66
# 42                                  0.00 3.94    255,647,979,916.47
# 43                                  0.00 3.86  2,595,151,045,197.65
# 44                                 -0.00 2.64  1,574,199,387,070.90
# 45                                  0.02 2.28     14,929,488,770.73
# 46                                  0.02 2.56     60,406,382,898.52
# 47                                 -0.00 3.19    199,844,406,013.53
# 48                                  0.02 2.62     71,654,134,378.53
# 49                                  0.00 2.41      4,748,174,334.14
# 50                                 -0.00 2.56     16,242,916,915.72
# 51                                  0.02 2.65     23,136,232,229.61
# 52                                 -0.00 3.28    143,112,196,040.33
# 53                                  0.01 3.21  2,651,472,946,375.05
# 54                                  0.01 2.99  1,015,618,742,565.81
# 55                                  0.01 2.56    486,630,146,443.62
# 56                                  0.02 2.22    187,217,660,050.68
# 57                                  0.01 3.70    336,377,500,160.55
# 58                                  0.01 3.36     24,728,285,177.46
# 59                                  0.02 3.45    358,245,427,458.54
# 60                                  0.00 3.70  1,961,796,197,354.36
# 61                                  0.01 2.54     14,808,989,993.32
# 62                                 -0.00 3.95  4,930,837,369,151.42
# 63                                  0.03 2.76     41,608,435,921.79
# 64                                  0.01 2.75    166,805,800,595.70
# 65                                  0.02 2.79     82,035,800,868.19
# 66                                  0.03 3.06    120,707,435,542.37
# 67                                  0.00 2.23      2,306,741,845.42
# 68                                 -0.01 3.18     30,483,806,017.83
# 69                                  0.02 2.82     53,027,680,685.84
# 70                                  0.02 2.38      3,390,703,400.00
# 71                                 -0.01 3.22     47,758,736,931.78
# 72                                  0.01 3.87     65,712,180,342.98
# 73                                  0.00 2.69     11,307,058,382.34
# 74                                  0.01 3.46    319,112,175,611.57
# 75                                  0.01 3.04     13,489,380,930.86
# 76                                  0.01 2.75    118,540,548,906.31
# 77                                  0.00 2.66     13,713,509,312.27
# 78                                  0.01 3.05  1,158,913,035,796.37
# 79                                  0.00 2.61      4,856,632,399.46
# 80                                  0.01 2.34     61,449,392,056.15
# 81                                  0.01 2.59     12,895,153,157.35
# 82                                  0.01 2.56     13,785,909,906.19
# 83                                  0.03 2.45     11,185,102,399.58
# 84                                  0.02 2.60    375,745,732,274.68
# 85                                  0.01 3.78    398,393,955,268.99
# 86                                  0.01 3.60    206,623,758,800.16
# 87                                  0.03 3.08     80,856,697,009.10
# 88                                  0.02 2.81     30,744,473,911.53
# 89                                  0.02 2.71    339,205,615,769.19
# 90                                  0.01 3.14     62,202,700,000.00
# 91                                  0.01 2.68     38,997,129,473.56
# 92                                  0.00 4.07    833,869,641,687.06
# 93                                  0.01 3.04    328,480,867,142.69
# 94                                 -0.00 3.49    524,645,833,884.58
# 95                                  0.01 2.84      5,833,351,477.90
# 96                                 -0.00 3.47    221,357,874,718.93
# 97                                  0.01 2.86    211,007,207,483.51
# 98                                 -0.01 3.07    210,146,748,920.42
# 99                                  0.01 3.94  2,683,399,006,715.79
# 100                                 0.02 2.64      9,252,834,120.39
# 101                                 0.00 3.69  1,623,901,496,835.79
# 102                                -0.00 2.52      9,669,741,744.22
# 103                                 0.01 2.71     79,997,975,621.87
# 104                                 0.01 2.72      1,058,937,037.04
# 105                                 0.01 2.59        884,847,176.21
# 106                                -0.00 2.81     44,179,055,279.89
# 107                                 0.02 2.04      3,719,369,107.35
# 108                                 0.00 3.13     95,649,966,260.98
# 109                                 0.00 3.22     48,589,100,043.10
# 110                                 0.01 2.63     94,376,246,466.95
# 111                                 0.01 3.93    695,200,833,086.50
# 112                                 0.01 2.62      3,591,660,723.59
# 113                                 0.01 4.02    541,018,749,769.10
# 114                                 0.02 2.51     20,996,564,751.60
# 115                                 0.02 2.33     10,000,395,242.15
# 116                                 0.00 3.47    218,628,940,951.68
# 117                                 0.00 3.34    456,356,961,443.50
# 118                                 0.02 2.51      6,395,472,574.41
# 119                                 0.00 2.44     23,797,686,965.79
# 120                                 0.01 2.73     42,163,966,272.63
# 121                                 0.01 3.37    858,996,263,095.86
# 122                                -0.01 2.78    112,090,530,368.54
# 123                                 0.00 2.85     64,233,966,861.25
# 124                                 0.01 3.11    281,353,625,688.00
# 125                                 0.02 2.42     26,842,231,204.80
# 126                                 0.02 2.43     25,873,601,260.84
# 127                                 0.02 2.94    235,733,695,652.17
# 128                                 0.04 3.81    390,516,804,016.50
# 129                                 0.01 2.78    104,295,862,000.00
# 130                                 0.01 3.90 19,477,336,549,000.00
# 131                                 0.02 2.52      1,469,787,255.62
#
#      taux_droit_douane  quantite_conteneurs_par_annee  \
# 0                 4.44                   4,563,618.00
# 1                 1.43                     118,270.00
# 2                 9.28                   1,725,238.00
# 3                 1.81                  15,169,595.00
# 4                 8.52                     570,200.00
# 5                12.48                      17,311.00
# 6                 4.03                   8,082,329.00
# 7                 6.81                   1,809,153.00
# 8                 2.74                     124,165.40
# 9                 1.49                   7,983,661.00
# 10                1.81                     285,900.00
# 11                5.98                   1,532,133.40
# 12               12.67                     107,098.00
# 13                1.81                  10,783,850.00
# 14               10.94                      44,381.00
# 15                4.77                   2,329,561.60
# 16                3.77                     229,410.00
# 17                1.03                   1,036,245.80
# 18                8.22                   9,380,502.00
# 19                1.81                     228,545.00
# 20                2.21                   2,122,421.00
# 21               11.90                     333,000.00
# 22               13.08                     386,367.00
# 23                1.48                   6,377,236.00
# 24                2.01                   4,407,502.00
# 25                0.00                  20,760,000.00
# 26                0.00                   2,653,525.00
# 27                3.96                 224,117,874.00
# 28                1.81                     345,016.00
# 29                4.93                   3,877,937.00
# 30               10.11                      52,066.00
# 31               10.11                      52,066.00
# 32                1.80                   1,489,326.00
# 33                1.81                     288,235.00
# 34                7.78                     907,646.00
# 35                1.81                     820,654.00
# 36                9.30                       7,425.00
# 37                2.55                     209,903.00
# 38                1.81                  15,929,902.00
# 39                1.81                     229,905.00
# 40                2.69                   1,398,484.00
# 41               15.45                     276,943.90
# 42                1.81                   1,630,089.00
# 43                1.81                   4,964,947.00
# 44                4.92                   4,107,713.00
# 45               15.09                     156,000.00
# 46               10.33                   1,009,755.00
# 47                1.81                   4,602,861.00
# 48                1.89                   1,389,751.00
# 49                6.83                      57,663.00
# 50                0.55                     217,472.00
# 51                4.94                     797,293.00
# 52                1.81                   1,886,256.20
# 53                6.32                  15,450,523.00
# ...
# 92                1.81                  13,992,474.00
# 93                2.27                   8,097,741.00
# 94                1.81                   2,384,782.00
# 95                4.61                      69,192.00
# 96                1.81                   3,156,657.00
# 97                1.30                   2,539,720.00
# 98                1.81                     696,438.00
# 99                2.06                  10,239,966.00
# 100               8.28                   2,012,397.40
# 101               6.58                  27,420,698.00
# 102               3.08                         735.01
# 103               5.13                   1,770,295.00
# 104              14.46                      13,767.00
# 105              10.19                      34,950.00
# 106               2.21                     421,367.80
# 107              11.11                      89,100.00
# 108               1.81                     340,316.99
# 109               1.81                     911,528.00
# 110               8.30                   6,200,000.00
# 111               2.01                     119,231.00
# 112               9.11                     112,318.00
# 113               1.81                   1,557,281.00
# 114               9.21                     570,500.00
# 115              14.85                     685,961.60
# 116               1.81                     974,330.20
# 117               4.59                   9,938,881.00
# 118              10.64                   1,193,841.00
# 119               8.63                     414,657.00
# 120               9.70                     480,619.00
# 121               2.85                  10,001,342.00
# 122               2.41                     723,575.00
# 123               5.00                     939,427.00
# 124               3.17                  12,382,524.00
# 125               4.46                     334,693.00
# 126               4.00                     860,646.60
# 127               8.06                   5,696,155.00
# 128               3.64                  19,089,706.00
# 129               6.16                   1,990,210.00
# 130               2.75                  50,202,917.00
# 131              21.61                     180,838.40
#
#      cout_production_volaille  taux_population_urbaine  stabilite_politique  \
# 0                    2,016.60                     0.66                -0.28
# 1                    2,072.14                     0.60                 0.38
# 2                    2,180.70                     0.72                -0.92
# 3                    1,459.50                     0.77                 0.59
# 4                    2,176.24                     0.65                -0.33
# 5                    2,711.42                     0.26                 0.75
# 6                    1,735.36                     0.83                -0.58
# 7                    1,324.10                     0.92                 0.17
# 8                    3,741.20                     0.63                -0.62
# 9                    2,308.30                     0.85                 0.89
# 10                   2,350.90                     0.58                 1.05
# 11                   1,783.70                     0.55                -0.75
# 12                   2,402.36                     0.31                 0.97
# 13                   2,427.02                     0.98                 0.43
# 14                   2,429.22                     0.45                 0.04
# 15                   2,195.34                     0.68                -0.28
# 16                     967.50                     0.50                -0.35
# 17                   2,005.80                     0.71                 1.02
# 18                   1,590.78                     0.87                -0.42
# 19                   2,243.80                     0.74                 0.33
# 20                   1,801.60                     0.78                -0.05
# 21                   2,042.20                     0.47                 0.03
# 22                   2,146.44                     0.55                -1.10
# 23                   1,828.78                     0.81                 1.10
# 24                   1,771.14                     0.86                 0.42
# 25                   2,214.60                     1.01                 0.83
# 26                   2,940.30                     1.00                 1.43
# 27                   1,681.40                     0.57                -0.23
# 28                   2,869.40                     0.67                 0.54
# 29                   2,164.50                     0.81                -0.77
# 30                   2,274.90                     0.68                -0.53
# 31                   2,578.08                     0.44                -2.35
# 32                   2,060.26                     0.78                 0.61
# 33                   1,580.78                     0.57                 0.69
# 34                   2,146.44                     0.50                -1.09
# 35                   1,200.10                     0.88                 0.87
# 36                   2,236.06                     0.73                 1.20
# 37                   2,860.00                     0.71                -0.26
# 38                   1,309.10                     0.80                 0.28
# 39                   1,822.88                     0.68                 0.65
# 40                   1,679.02                     0.29                -0.27
# 41                   3,628.70                     0.58                 0.64
# 42                   1,460.70                     0.86                 1.08
# 43                   1,705.70                     0.80                 0.28
# 44                   1,603.60                     0.74                -0.64
# 45                   2,373.92                     0.87                -0.10
# 46                   2,176.24                     0.55                 0.09
# 47                   2,056.00                     0.83                -0.07
# 48                   2,276.96                     0.51                -0.65
# 49                   2,032.58                     0.27                -0.04
# 50                   1,739.10                     0.57                -0.37
# 51                   1,987.04                     0.55                -0.56
# 52                   1,871.80                     0.71                 0.81
# 53                   2,357.50                     0.34                -0.76
# 54                   2,240.94                     0.55                -0.50
# 55                   2,337.38                     0.75                -0.93
# 56                   2,368.52                     0.72                -2.31
# 57                   2,515.24                     0.63                 1.00
# 58                   4,442.80                     0.94                 1.35
# 59                   2,391.36                     0.93                -0.89
# 60                   1,776.48                     0.69                 0.31
# 61                   2,572.08                     0.55                 0.31
# 62                   1,624.98                     0.92                 1.11
# 63                   2,572.66                     0.90                -0.50
# 64                   1,197.70                     0.58                 0.04
# 65                   2,139.62                     0.26                -1.13
# 66                   2,136.48                     1.02                -0.05
# 67                   2,220.32                     0.30                -0.19
# 68                   1,876.40                     0.68                 0.46
# 69                   2,674.00                     0.79                -1.63
# 70                   2,176.24                     0.51                -0.36
# 71                   1,763.90                     0.69                 0.78
# 72                   5,366.00                     0.89                 1.33
# 73                   2,072.14                     0.58                -0.25
# 74                   2,011.40                     0.77                 0.12
# 75                   1,341.70                     0.93                 1.25
# 76                   1,906.52                     0.62                -0.37
# 77                   1,911.80                     0.41                 0.97
# 78                   1,634.00                     0.83                -0.72
# 79                   2,072.14                     0.67                -0.06
# 80                   2,826.78                     0.30                -1.08
# 81                   2,536.64                     0.52                 0.63
# 82                   2,124.52                     0.57                -0.05
# 83                   2,478.90                     0.16                -1.27
# 84                   2,387.06                     0.50                -2.00
# 85                   2,317.50                     0.82                 1.17
# 86                   2,479.90                     0.87                 1.59
# 87                   1,948.94                     0.83                 0.75
# 88                   2,139.62                     0.24                -0.57
# 89                   2,387.06                     0.35                -2.41
# 90                   2,440.14                     0.67                 0.39
# 91                   2,178.30                     0.61                 0.00
# 92                   1,611.58                     0.91                 0.92
# 93                   2,072.26                     0.47                -1.18
# 94                   2,180.16                     0.60                 0.52
# 95                   2,136.48                     0.63                 0.28
# 96                   1,900.30                     0.65                 1.12
# 97                   1,843.12                     0.80                -0.26
# 98                   1,806.30                     0.54                 0.06
# 99                   1,624.98                     0.82                 0.33
# 100                  2,139.62                     0.17                 0.09
# 101                  1,880.18                     0.81                 0.32
# 102                  1,831.32                     0.42                -0.32
# 103                  1,913.88                     0.82                 0.16
# 104                  2,402.36                     0.33                 0.65
# 105                  3,079.70                     0.19                 1.18
# 106                  1,777.50                     0.56                 0.09
# 107                  2,139.62                     0.42                -0.04
# 108                  1,794.08                     0.54                 0.91
# 109                  2,056.06                     0.54                 0.87
# 110                  2,639.90                     0.18                -0.07
# 111                  2,354.40                     0.74                 1.26
# 112                  3,135.80                     0.65                 0.13
# 113                  2,354.40                     0.87                 0.98
# 114                  2,139.62                     0.48                -0.05
# 115                  2,139.62                     0.23                -1.29
# 116                  1,985.42                     0.74                 1.00
# 117                  1,785.60                     0.49                -0.75
# 118                  2,583.30                     0.42                -0.88
# 119                  2,402.36                     0.53                 0.28
# 120                  2,183.64                     0.69                -1.02
# 121                  2,201.78                     0.74                -1.79
# 122                  2,231.74                     0.69                -1.87
# 123                  1,318.20                     0.96                 1.05
# 124                  3,852.80                     0.36                 0.29
# 125                  3,877.10                     0.37                -2.94
# 126                  1,943.02                     0.44                 0.15
# 127                  1,510.50                     0.43                -1.42
# 128                  2,106.20                     0.85                 0.62
# 129                  2,178.30                     0.63                -0.07
# 130                  1,551.86                     0.82                 0.34
# 131                  2,699.64                     0.22                 0.20
#
#      pib_par_habitant
# 0            6,690.94
# 1            4,514.19
# 2            4,109.70
# 3           44,651.83
# 4            2,313.22
# 5           15,383.42
# 6           20,802.46
# 7           14,648.85
# 8            3,914.53
# 9           53,957.16
# 10          47,309.05
# 11           4,150.76
# 12          17,404.03
# 13          44,025.90
# 14           6,083.52
# 15           3,351.12
# 16           5,394.59
# 17           7,303.67
# 18           9,928.64
# 19           8,335.08
# 20           5,791.03
# 21           1,136.59
# 22           1,469.45
# 23          44,899.85
# 24          14,962.55
# 25          46,709.31
# 26          81,018.56
# 27           8,663.07
# 28          19,451.69
# 29           6,376.71
# 30           7,439.16
# 31           7,439.16
# 32          12,225.58
# 33          13,465.40
# 34           2,111.03
# 35          57,938.80
# 36           7,298.72
# 37           3,910.25
# 38          28,152.58
# 39          20,406.69
# 40           3,914.43
# 41           6,101.03
# 42          46,385.55
# 43          40,022.37
# 44          10,817.00
# 45           7,230.40
# 46           2,074.29
# 47          18,907.74
# 48           4,236.14
# 49           6,124.92
# 50           4,051.90
# 51           2,453.73
# 52          14,708.61
# 53           1,980.67
# 54           3,837.58
# 55           6,032.07
# 56           4,985.45
# 57          70,767.46
# 58          73,949.77
# 59          43,456.09
# 60          32,333.55
# 61           5,070.10
# 62          38,672.41
# 63           4,251.90
# 64           9,225.97
# 65           1,633.49
# 66          29,759.49
# 67           1,102.89
# 68          15,623.93
# 69           7,776.03
# 70             721.08
# 71          16,784.46
# 72         111,017.18
# 73           5,430.87
# 74          10,259.31
# 75          30,802.39
# 76           3,331.54
# 77          10,845.01
# 78           9,287.85
# 79           7,738.88
# 80           1,151.11
# 81           5,367.09
# 82           2,159.16
# 83             517.77
# 84           1,968.56
# 85          75,220.81
# 86          43,943.48
# 87          17,329.18
# 88             746.83
# 89           1,631.53
# 90          15,146.38
# 91           5,678.87
# 92          48,989.64
# 93           3,123.25
# 94          13,823.50
# 95          21,127.52
# 96          21,515.02
# 97           6,710.51
# 98          10,692.33
# 99          40,214.31
# 100            772.29
# 101         31,781.12
# 102          2,381.90
# 103          7,609.36
# 104         20,346.57
# 105          4,529.50
# 106          5,003.50
# 107            496.68
# 108         17,557.22
# 109         23,400.71
# 110          4,466.87
# 111         82,215.82
# 112          6,295.68
# 113         54,621.35
# 114          1,361.70
# 115            665.95
# 116         20,545.84
# 117          6,593.82
# 118            830.75
# 119         17,194.13
# 120          3,687.78
# 121         10,589.67
# 122          2,519.58
# 123         18,690.92
# 124          2,974.12
# 125            964.34
# 126          1,535.20
# 127          2,444.29
# 128         41,162.48
# 129          6,213.50
# 130         59,914.64
# 131          2,310.84

# %%
calculate_kmo(X)
# Out:
# (array([0.45400722, 0.33726478, 0.58058237, 0.6115388 , 0.57328744,
#         0.54429102, 0.50408698, 0.61936246, 0.54900053, 0.45373553,
#         0.37172532, 0.69298961, 0.83077091, 0.77409646, 0.57808782,
#         0.57732448, 0.76254306, 0.81001364, 0.59839311]),
#  0.5852397455818192)

# %% [markdown]
# Dans cette situation, la PCA est indiquée "misérable".
#
# On va améliorer le KMO en enlevant des variables.

# %% [markdown]
# #### Test de sphéricité de Bartlett
# Teste l'hypothèse selon laquelle votre matrice de corrélation est une matrice d'identité, ce qui indiquerait que les variables ne sont pas liées et donc ne conviennent pas pour la détection de structure. Des valeurs faibles (inférieures à 0,05) du niveau de signification indiquent qu'une analyse factorielle peut être utile avec vos données.

# %%
from factor_analyzer import calculate_bartlett_sphericity

# %%
calculate_bartlett_sphericity(X)
# Out:
# (2902.094222803202, 0.0)

# %% [markdown]
# La p-value est inférieur à 0.05, les test est significatif, l'ACP peut être utile aux données.

# %% [markdown]
# ### Tentative d'amélioration du KMO

# %% [markdown]
# Plusieurs possibilités pour améliorer le KMO:
# - Analyser le KMO par variable et rejeter les variables qui ont un KMO faible (inférieur ou égale à 0.5)
# - Enlever les variables les moins corrélées avec les autres variables

# %% [markdown]
# Les propositions pour améliorer le KMO global proviennent de 2 sources :
# - https://spss.espaceweb.usherbrooke.ca/procedure-spss-5/
# - Le livre Consis_Statistique consultable ci-dessous à partir de la page 651 chapitre sur l'ACP.

# %%
from IPython.display import IFrame
IFrame("Consis_Statistique.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="Consis_Statistique.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### KMO par variables

# %%
kmo_variable = pd.DataFrame(data=calculate_kmo(X)[0], index=X.columns.values, columns=['KMO'])
kmo_variable.sort_values('KMO', ascending = False)
# Out:
#                                           KMO
# pib                                      0.83
# stabilite_politique                      0.81
# taux_droit_douane                        0.77
# taux_population_urbaine                  0.76
# lpi                                      0.69
# proportion_animaux_nourriture            0.62
# volaille_consommée                       0.61
# pib_par_habitant                         0.60
# production                               0.58
# quantite_conteneurs_par_annee            0.58
# cout_production_volaille                 0.58
# taux_dependance                          0.57
# population                               0.55
# taux_autosuffisance                      0.54
# proportion_volaille_nourriture           0.50
# exportation_volaille                     0.45
# accroissement_population_moyen_par_annee 0.45
# taux_accroissement_population_moyen      0.37
# importation_volaille                     0.34

# %% [markdown]
# On conserve les variables dont le KMO est supérieur ou égale à 0,5.

# %% [markdown]
# ##### KMO > 0.5

# %%
# score KMO en fonction de la valeur limite KMO variables
for x in np.arange(0.5, 0.6, 0.01):
    kmo_col = kmo_variable[kmo_variable['KMO'] > x].index.values
    print(f'KMO global avec KMO limite = {round(x,2)} :', calculate_kmo(X[kmo_col])[1])
# Out:
# KMO global avec KMO limite = 0.5 : 0.6909782524576117
# KMO global avec KMO limite = 0.51 : 0.7102155025841848
# KMO global avec KMO limite = 0.52 : 0.7102155025841848
# KMO global avec KMO limite = 0.53 : 0.7102155025841848
# KMO global avec KMO limite = 0.54 : 0.7102155025841848
# KMO global avec KMO limite = 0.55 : 0.6961888535063276
# KMO global avec KMO limite = 0.56 : 0.6961888535063276
# KMO global avec KMO limite = 0.57 : 0.6961888535063276
# KMO global avec KMO limite = 0.58 : 0.750810309763196
# KMO global avec KMO limite = 0.59 : 0.6966679157746037

# %%
# on garde les variables dont le kmo est > 0.51, on garde beaucoup de variable et le score est acceptable
kmo_col = kmo_variable[kmo_variable['KMO'] > 0.51].index.values
kmo_col
# Out:
# array(['production', 'volaille_consommée', 'taux_dependance',
#        'taux_autosuffisance', 'proportion_animaux_nourriture',
#        'population', 'lpi', 'pib', 'taux_droit_douane',
#        'quantite_conteneurs_par_annee', 'cout_production_volaille',
#        'taux_population_urbaine', 'stabilite_politique',
#        'pib_par_habitant'], dtype=object)

# %%
# variables enlevées par la condition ci-dessus
kmo_variable[~(kmo_variable['KMO'] > 0.51)].index.values
# Out:
# array(['exportation_volaille', 'importation_volaille',
#        'proportion_volaille_nourriture',
#        'accroissement_population_moyen_par_annee',
#        'taux_accroissement_population_moyen'], dtype=object)

# %%
calculate_kmo(X[kmo_col])
# Out:
# (array([0.69263471, 0.6660962 , 0.56937365, 0.55848194, 0.76380571,
#         0.84729192, 0.72590787, 0.88575499, 0.83885213, 0.73475386,
#         0.37558115, 0.81940699, 0.7389775 , 0.66059163]),
#  0.7102155025841848)

# %% [markdown]
# Le KMO est de 0.71, ce qui est 'moyen' mais acceptable, on va voir si on peut encore l'améliorer.
# D'autres sources affirment qu'un KMO est acceptable à partir de 0,6.

# %%
X[kmo_col].shape
# Out:
# (132, 14)

# %% [markdown]
# ##### Variables les moins corrélées aux autres variables

# %%
plt.figure(figsize=(15,9))
sns.heatmap(X.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# je détermine les variables corrélées en sommant les valeurs absolues des corrélations des variables 
corr_tot_var = np.abs(X.corr()).sum(axis=1).sort_values(ascending = False)
corr_tot_var
# Out:
# volaille_consommée                         7.08
# production                                 6.99
# pib                                        6.88
# lpi                                        6.54
# population                                 5.95
# quantite_conteneurs_par_annee              5.74
# pib_par_habitant                           5.70
# taux_population_urbaine                    5.26
# accroissement_population_moyen_par_annee   5.25
# proportion_animaux_nourriture              5.25
# exportation_volaille                       5.20
# stabilite_politique                        5.00
# importation_volaille                       4.85
# taux_dependance                            4.60
# taux_autosuffisance                        4.49
# taux_droit_douane                          4.32
# cout_production_volaille                   3.64
# proportion_volaille_nourriture             3.46
# taux_accroissement_population_moyen        3.29
# dtype: float64

# %%
# on boucle pour déterminer identifier les différents KMO
for x in np.arange(3.5, 6.5, 0.1):
    col_corr = corr_tot_var[corr_tot_var >= x].index.values
    print(f'KMO global avec corrélation limite = {round(x,2)} :', calculate_kmo(X[col_corr])[1])
# Out:
# KMO global avec corrélation limite = 3.5 : 0.6013069256654837
# KMO global avec corrélation limite = 3.6 : 0.6013069256654837
# KMO global avec corrélation limite = 3.7 : 0.6021809536405167
# KMO global avec corrélation limite = 3.8 : 0.6021809536405167
# KMO global avec corrélation limite = 3.9 : 0.6021809536405167
# KMO global avec corrélation limite = 4.0 : 0.6021809536405167
# KMO global avec corrélation limite = 4.1 : 0.6021809536405167
# KMO global avec corrélation limite = 4.2 : 0.6021809536405167
# KMO global avec corrélation limite = 4.3 : 0.6021809536405167
# KMO global avec corrélation limite = 4.4 : 0.5933510395969018
# KMO global avec corrélation limite = 4.5 : 0.5858389625307626
# KMO global avec corrélation limite = 4.6 : 0.5766130815106186
# KMO global avec corrélation limite = 4.7 : 0.5766130815106186
# KMO global avec corrélation limite = 4.8 : 0.5766130815106186
# KMO global avec corrélation limite = 4.9 : 0.6792168552176224
# KMO global avec corrélation limite = 5.0 : 0.6799554334685166
# KMO global avec corrélation limite = 5.1 : 0.6799554334685166
# KMO global avec corrélation limite = 5.2 : 0.6835024602450126
# KMO global avec corrélation limite = 5.3 : 0.7303544466333133
# KMO global avec corrélation limite = 5.4 : 0.7303544466333133
# KMO global avec corrélation limite = 5.5 : 0.7303544466333133
# KMO global avec corrélation limite = 5.6 : 0.7303544466333133
# KMO global avec corrélation limite = 5.7 : 0.7529921212960256
# KMO global avec corrélation limite = 5.8 : 0.7311173367800907
# KMO global avec corrélation limite = 5.9 : 0.7311173367800907
# KMO global avec corrélation limite = 6.0 : 0.7064087477040147
# KMO global avec corrélation limite = 6.1 : 0.7064087477040147
# KMO global avec corrélation limite = 6.2 : 0.7064087477040147
# KMO global avec corrélation limite = 6.3 : 0.7064087477040147
# KMO global avec corrélation limite = 6.4 : 0.7064087477040147

# %%
col_corr = corr_tot_var[corr_tot_var >= 4.9].index.values
col_corr
# Out:
# array(['volaille_consommée', 'production', 'pib', 'lpi', 'population',
#        'quantite_conteneurs_par_annee', 'pib_par_habitant',
#        'taux_population_urbaine',
#        'accroissement_population_moyen_par_annee',
#        'proportion_animaux_nourriture', 'exportation_volaille',
#        'stabilite_politique'], dtype=object)

# %%
len(col_corr)
# Out:
# 12

# %%
calculate_kmo(X[col_corr])
# Out:
# (array([0.71024392, 0.68184849, 0.90416568, 0.72580696, 0.59276138,
#         0.64163682, 0.76379866, 0.84862427, 0.49200515, 0.72637754,
#         0.59443257, 0.64511789]),
#  0.6792168552176224)

# %% [markdown]
# La première solution donne de meilleurs résultats en conservant plus de variables.

# %% [markdown]
# #### Deuxième KMeans
#
# On refait le KMeans avec les variables qu'on va utiliser pour l'ACP, pour garder la cohérence de l'ensemble.

# %%
kmeans = KMeans(n_clusters=3, random_state=1)

kmeans.fit(df_X_scaled[kmo_col].values)

centroides = kmeans.cluster_centers_

clusters_kmeans = kmeans.labels_

df['clusters_kmeans']=clusters_kmeans

# %% [markdown]
# ### PCA

# %% [markdown]
# Je garde les colonnes 'kmo_col' pour la suite.

# %%
df_X_scaled = df_X_scaled[kmo_col]
X_scaled = df_X_scaled.values

# %%
# création de l'estimateur
pca = PCA(n_components=3, random_state=1)

pca.fit(X_scaled)
# Out:
# PCA(n_components=3, random_state=1)

# %%
X_scaled.shape
# Out:
# (132, 14)

# %% [markdown]
# #### Graphique éboulie des valeurs propres, variance expliquée par chaque composante

# %%
# explication de la variance dans chacune des composantes, éboulis des valeurs propres

cumsum_variance = pca.explained_variance_ratio_.cumsum()

plt.figure(figsize = (10,6))

sns.barplot(x=[n for n in range(pca.components_.shape[0])],
            y=pca.explained_variance_ratio_)

plt.plot([n for n in range(pca.components_.shape[0])], cumsum_variance, c='r', marker='o')


listF = []
for x in range(pca.components_.shape[0]):
    a = f"F{x+1} ({round(100*pca.explained_variance_ratio_[x],2)}%)"
    listF.append(a)
    
plt.text(max([n for n in range(pca.components_.shape[0])]), cumsum_variance.max(), '{:.2%}'.format(round(cumsum_variance.max(),4)))  
plt.title("Variance expliquée par chacune des composantes, éboulis des valeurs propres")
plt.ylabel("Pourcentage de la variance expliquée")
plt.xticks([n for n in range(pca.components_.shape[0])], listF);

# %% [markdown]
# 68% de la variance est expliquée par les 3 composantes principales, l'ACP est acceptable.

# %% [markdown]
# #### Représentation des composantes dans les variables

# %% [markdown]
# On cherche à voir ce que représente chaque composante en regardant pour chaque variable par quelle composante est le plus représentée.
# Ensuite on groupe les variables pour dégager une idée globale du groupe de variable pour nommer la composante principale.

# %%
df_composante = pd.DataFrame(data=pca.components_, index=['F1', 'F2', 'F3'], columns=kmo_col).T
df_composante
# Out:
#                                  F1    F2    F3
# production                     0.43 -0.15  0.09
# volaille_consommée             0.44 -0.15  0.11
# taux_dependance               -0.07  0.32  0.54
# taux_autosuffisance            0.06 -0.31 -0.56
# proportion_animaux_nourriture  0.11  0.29  0.12
# population                     0.32 -0.21  0.16
# lpi                            0.27  0.35 -0.19
# pib                            0.43 -0.08  0.08
# taux_droit_douane             -0.15 -0.26  0.36
# quantite_conteneurs_par_annee  0.38 -0.11  0.19
# cout_production_volaille      -0.12  0.05  0.25
# taux_population_urbaine        0.16  0.33 -0.22
# stabilite_politique            0.08  0.38 -0.09
# pib_par_habitant               0.17  0.41 -0.11

# %% [markdown]
# #### Identification d'une composante principale associée à chaque variable

# %%
# on copie df_composante et on sort les variables
df_composante2 = df_composante.reset_index()
df_composante2.rename(columns={'index':'variable'}, inplace=True)

# %%
# on pivote les 3 composantes sur une colonne
melt = pd.melt(df_composante2, id_vars='variable', value_vars=['F1','F2','F3'], var_name = 'composantes',
        value_name='correlation')

# %%
# valeur absolu correlation
melt['correlation_abs'] = melt['correlation'].abs()

# window function pour avoir le rang de chaque composante
melt['rank'] = melt.groupby(['variable'])['correlation_abs'].rank(ascending=False)

# %%
composante_variable = melt[melt['rank']==1][['variable', 'composantes', 'correlation']].reset_index(drop=True)
composante_variable
# Out:
#                          variable composantes  correlation
# 0                      production          F1         0.43
# 1              volaille_consommée          F1         0.44
# 2                      population          F1         0.32
# 3                             pib          F1         0.43
# 4   quantite_conteneurs_par_annee          F1         0.38
# 5   proportion_animaux_nourriture          F2         0.29
# 6                             lpi          F2         0.35
# 7         taux_population_urbaine          F2         0.33
# 8             stabilite_politique          F2         0.38
# 9                pib_par_habitant          F2         0.41
# 10                taux_dependance          F3         0.54
# 11            taux_autosuffisance          F3        -0.56
# 12              taux_droit_douane          F3         0.36
# 13       cout_production_volaille          F3         0.25

# %% [markdown]
# #### Analyse du sens des composantes principales

# %% [markdown]
# F1 :
# - Associé à la taille du pays, à la richesse globale, au flux économique global et à la quantité globale de volaille consommée.
# - On l'associe globalement à la **Puissance commerciale et logistique, Consommation Volaille**.
#
#
# F2 :
# - Associé à la pauvreté, au non développement urbain et logistique du pays et à la non stabilité politique.
# - On l'associe globalement à la **Qualité de vie, Richesse Individuelle**.
#
#
# F3 :
# - Associé à la présence viande dans la nourriture, à la non auto-suffisance et cout de production assez élevé de la volaille
# - On l'associe globalement à **Condition de marché**.

# %%
# En résumé
F1_resume = "Puissance commerciale et logistique, Consommation Volaille"
F2_resume = "Qualité de vie, Richesse Individuelle"
F3_resume = "Condition de marché"

resume_composante = [F1_resume, F2_resume, F3_resume]

# %% [markdown]
# ## Analyse Résultats

# %% [markdown]
# ### Cercle de corrélation et Représentation des individus sur le plan factoriel

# %%
# représenation des individus sur le plan factoriel
X_projected = pca.transform(X_scaled)

df_projection = pd.DataFrame(data=X_projected, columns=['F1', 'F2', 'F3'], index=pays)
df_projection
# Out:
#                                                       F1    F2    F3
# Afrique du Sud                                      0.64 -0.01 -0.45
# Albanie                                            -0.97  0.15  0.37
# Algérie                                            -0.96 -1.90 -0.52
# Allemagne                                           2.34  1.81 -0.78
# Angola                                             -1.30 -0.55  1.53
# Antigua-et-Barbuda                                 -1.17  0.90  2.70
# Arabie saoudite                                     0.48  0.61 -0.08
# Argentine                                           0.86  0.05 -1.14
# Arménie                                            -1.43 -0.16  1.29
# Australie                                           1.58  2.09 -1.71
# Autriche                                            0.36  2.32 -0.36
# Azerbaïdjan                                        -1.01 -1.48 -0.38
# Barbade                                            -1.04 -0.41  0.64
# Belgique                                            0.44  4.55  2.97
# Belize                                             -1.13 -1.36 -0.18
# Bolivie (État plurinational de)                    -0.55 -0.94 -0.91
# Bosnie-Herzégovine                                 -0.67 -1.25 -1.26
# Botswana                                           -0.53  0.37 -0.83
# Brésil                                              4.73 -1.88  0.19
# Bulgarie                                           -0.43  0.89  0.03
# Bélarus                                            -0.31 -0.50 -1.43
# Bénin                                              -1.39 -0.75  1.59
# Cameroun                                           -1.46 -2.53  0.05
# Canada                                              1.61  1.74 -1.68
# Chili                                               0.43  0.84 -1.20
# Chine - RAS de Hong-Kong                            0.99  7.53  5.58
# Chine - RAS de Macao                                0.86  5.07  0.41
# Chine, continentale                                15.28 -5.56  3.94
# Chypre                                             -0.35  1.14 -0.25
# Colombie                                            0.08 -0.98 -0.75
# Congo                                              -1.32 -0.14  1.85
# Congo                                              -1.73 -1.28  2.40
# Costa Rica                                         -0.26  0.29 -1.27
# Croatie                                            -0.29  0.37 -0.99
# Côte d'Ivoire                                      -1.10 -1.79 -0.25
# Danemark                                            0.84  3.01 -0.82
# Dominique                                          -0.80  1.19  1.35
# El Salvador                                        -0.80 -0.67 -0.82
# Espagne                                             1.64  1.05 -1.45
# Estonie                                            -0.27  1.24 -0.21
# Eswatini                                           -1.01 -1.30 -0.51
# Fidji                                              -1.58 -1.07  1.05
# Finlande                                            0.87  1.93 -2.32
# France                                              1.76  1.39 -1.20
# Fédération de Russie                                1.59 -1.46 -0.46
# Gabon                                              -1.32  0.20  2.23
# Ghana                                              -1.27 -0.77  1.24
# Grèce                                               0.06  0.42 -1.36
# Guatemala                                          -0.81 -0.72 -0.06
# Guyana                                             -1.24 -1.66 -0.29
# Géorgie                                            -0.91 -0.05  0.35
# Honduras                                           -0.83 -1.25 -0.68
# Hongrie                                             0.14  0.63 -1.45
# Inde                                                3.35 -3.93  1.08
# Indonésie                                           0.96 -1.41 -0.50
# Iran (République islamique d')                     -0.22 -2.14  0.28
# Iraq                                               -1.32 -1.30  1.51
# Irlande                                             0.36  2.94  0.04
# Islande                                             0.31  3.14 -0.88
# Israël                                              0.59  1.01 -1.52
# Italie                                              1.39  0.71 -1.42
# Jamaïque                                           -1.01 -0.65  0.30
# Japon                                               3.22  1.84 -0.92
# Jordanie                                           -0.64 -0.27 -0.30
# Kazakhstan                                         -0.46 -0.17 -0.29
# Kenya                                              -1.28 -2.50 -0.04
# Koweït                                             -0.07  1.68  0.03
# Lesotho                                            -1.62 -0.82  1.58
# Lettonie                                           -0.36  1.38  0.32
# Liban                                              -0.81 -0.94 -0.61
# Libéria                                            -1.56 -0.88  1.69
# Lituanie                                           -0.12  1.09 -0.65
# Luxembourg                                          0.29  5.05  1.16
# Macédoine du Nord                                  -1.06  0.16  0.99
# Malaisie                                            1.13  0.45 -0.92
# Malte                                               0.23  2.20 -0.58
# Maroc                                              -0.37 -1.24 -0.83
# Maurice                                            -0.48 -0.07 -1.04
# Mexique                                             1.51 -0.63 -0.44
# Monténégro                                         -0.91  0.14  0.47
# Myanmar                                            -0.49 -1.51  0.22
# Namibie                                            -1.07  0.76  1.25
# Nicaragua                                          -0.78 -0.95 -1.04
# Niger                                              -1.75 -2.80  0.50
# Nigéria                                            -1.00 -2.96  0.08
# Norvège                                             0.81  2.36 -1.96
# Nouvelle-Zélande                                    0.73  2.15 -1.95
# Oman                                               -0.25  1.86  0.72
# Ouganda                                            -1.20 -2.21 -0.24
# Pakistan                                           -0.61 -3.28  0.33
# Panama                                             -0.22  0.13 -0.74
# Paraguay                                           -0.74 -0.72 -0.87
# Pays-Bas                                            1.09  4.06  1.60
# Philippines                                         0.16 -1.16 -0.29
# Pologne                                             0.68  0.08 -1.40
# Polynésie française                                -0.48  1.79  1.36
# Portugal                                            0.31  1.06 -1.34
# Pérou                                               0.03 -0.49 -1.41
# Roumanie                                           -0.31 -0.22 -0.81
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...  2.03  1.41 -1.02
# Rwanda                                             -1.39 -2.22 -0.26
# République de Corée                                 1.45  0.80 -0.82
# République de Moldova                              -0.98 -1.08 -0.43
# République dominicaine                             -0.39 -0.34 -0.94
# Saint-Kitts-et-Nevis                               -1.06  1.15  2.88
# Samoa                                              -1.51  0.62  2.93
# Serbie                                             -0.58 -0.53 -0.99
# Sierra Leone                                       -1.71 -1.70  1.02
# Slovaquie                                          -0.34  1.10 -0.01
# Slovénie                                           -0.21  0.77 -0.86
# Sri Lanka                                          -1.19 -1.89  0.16
# Suisse                                              0.86  2.94 -1.31
# Suriname                                           -1.29  0.14  1.57
# Suède                                               0.82  2.66 -1.27
# Sénégal                                            -1.15 -1.66 -0.32
# Tchad                                              -1.70 -2.55  1.09
# Tchéquie                                            0.14  1.47 -0.72
# Thaïlande                                           0.34 -1.07 -0.82
# Togo                                               -1.55 -1.92  0.70
# Trinité-et-Tobago                                  -0.87 -0.09  0.43
# Tunisie                                            -0.98 -1.79 -0.62
# Turquie                                             0.67 -1.36 -1.11
# Ukraine                                            -0.39 -1.51 -0.71
# Uruguay                                            -0.05  0.57 -1.61
# Viet Nam                                           -0.14 -0.19  0.75
# Yémen                                              -1.75 -2.30  1.14
# Zambie                                             -1.01 -1.08 -0.34
# Égypte                                             -0.27 -2.14 -0.24
# Émirats arabes unis                                 0.74  2.87  0.80
# Équateur                                           -0.56 -0.83 -0.74
# États-Unis d'Amérique                              13.06 -1.65  0.94
# Îles Salomon                                       -2.34 -0.73  4.53

# %% [markdown]
# Tous les individus ont été transformés sur le plan factoriel. Ils ont été réduit selon leurs composantes principales.

# %%
def correlation_graph(pca, 
                      x_y, 
                      features,
                      resume_composante) : 
    """Affiche le graphe des correlations

    Positional arguments : 
    -----------------------------------
    pca : sklearn.decomposition.PCA : notre objet PCA qui a été fit
    x_y : list ou tuple : le couple x,y des plans à afficher, exemple [0,1] pour F1, F2
    features : list ou tuple : la liste des features (ie des dimensions) à représenter
    """

    # Extrait x et y 
    x,y=x_y

    # Taille de l'image (en inches)
    fig, ax = plt.subplots(figsize=(15, 13))

    # Pour chaque composante : 
    for i in range(0, pca.components_.shape[1]):

        # Les flèches
        ax.arrow(0,0, 
                pca.components_[x, i],  
                pca.components_[y, i],  
                head_width=0.07,
                head_length=0.07, 
                width=0.02, )

        # Les labels
        plt.text(pca.components_[x, i] + 0.05,
                pca.components_[y, i] + 0.05,
                features[i])
        
    # Affichage des lignes horizontales et verticales
    plt.plot([-1, 1], [0, 0], color='grey', ls='--')
    plt.plot([0, 0], [-1, 1], color='grey', ls='--')

    # Nom des axes, avec le pourcentage d'inertie expliqué
    axe_x = 'F{} ({}%)'.format(x+1, round(100*pca.explained_variance_ratio_[x],1))
    axe_y = 'F{} ({}%)'.format(y+1, round(100*pca.explained_variance_ratio_[y],1))
    plt.xlabel(f"{axe_x} : {resume_composante[x]}")
    plt.ylabel(f"{axe_y} : {resume_composante[y]}")

    # # Affichage du titre
    plt.title("Cercle des corrélations (F{} et F{})".format(x+1, y+1))

    # Le cercle 
    an = np.linspace(0, 2 * np.pi, 100)
    plt.plot(np.cos(an), np.sin(an))  # Add a unit circle for scale

    # Axes et display
    plt.axis('equal')
    plt.show(block=False)

# %%
def display_factorial_planes(   X_projected, 
                                x_y,
                                resume_composante,
                                pca=None,
                                labels = None,
                                clusters=None,
                                centroides=None,
                                alpha=1,
                                figsize=[10,8], 
                                marker="." ):
    """
    Affiche la projection des individus

    Positional arguments : 
    -------------------------------------
    X_projected : np.array, pd.DataFrame, list of list : la matrice des points projetés
    x_y : list ou tuple : le couple x,y des plans à afficher, exemple [0,1] pour F1, F2

    Optional arguments : 
    -------------------------------------
    pca : sklearn.decomposition.PCA : un objet PCA qui a été fit, cela nous permettra d'afficher la variance de chaque composante, default = None
    labels : list ou tuple : les labels des individus à projeter, default = None
    clusters : list ou tuple : la liste des clusters auquel appartient chaque individu, default = None
    alpha : float in [0,1] : paramètre de transparence, 0=100% transparent, 1=0% transparent, default = 1
    figsize : list ou tuple : couple width, height qui définit la taille de la figure en inches, default = [10,8] 
    marker : str : le type de marker utilisé pour représenter les individus, points croix etc etc, default = "."
    """

    # Transforme X_projected en np.array
    X_ = np.array(X_projected)

    # On définit la forme de la figure si elle n'a pas été donnée
    if not figsize: 
        figsize = (7,6)

    # On gère les labels
    if  labels is None : 
        labels = []
    try : 
        len(labels)
    except Exception as e : 
        raise e

    # On vérifie la variable axis 
    if not len(x_y) ==2 : 
        raise AttributeError("2 axes sont demandées")   
    if max(x_y )>= X_.shape[1] : 
        raise AttributeError("la variable axis n'est pas bonne")   

    # on définit x et y 
    x, y = x_y

    # Initialisation de la figure       
    fig, ax = plt.subplots(1, 1, figsize=figsize)

    # On vérifie s'il y a des clusters ou non
    c = None if clusters is None else clusters
 
    # Les points    
    # plt.scatter(   X_[:, x], X_[:, y], alpha=alpha, 
    #                     c=c, cmap="Set1", marker=marker)
    sns.scatterplot(data=None, x=X_[:, x], y=X_[:, y], hue=c)

    # Si la variable pca a été fournie, on peut calculer le % de variance de chaque axe 
    if pca : 
        v1 = str(round(100*pca.explained_variance_ratio_[x]))  + " %"
        v2 = str(round(100*pca.explained_variance_ratio_[y]))  + " %"
    else : 
        v1=v2= ''

    # Nom des axes, avec le pourcentage d'inertie expliqué
    ax.set_xlabel(f'F{x+1} {v1} : {resume_composante[x]}')
    ax.set_ylabel(f'F{y+1} {v2} : {resume_composante[y]}')

    # Valeur x max et y max
    x_max = np.abs(X_[:, x]).max() *1.1
    y_max = np.abs(X_[:, y]).max() *1.1

    # On borne x et y 
    ax.set_xlim(left=-x_max, right=x_max)
    ax.set_ylim(bottom= -y_max, top=y_max)

    # Affichage des lignes horizontales et verticales
    plt.plot([-x_max, x_max], [0, 0], color='grey', alpha=0.8)
    plt.plot([0,0], [-y_max, y_max], color='grey', alpha=0.8)

    # Affichage des labels des points
    if len(labels) : 
        for i,(_x,_y) in enumerate(X_[:,[x,y]]):
            plt.text(_x, _y+0.05, labels[i], fontsize='14', ha='center',va='center')
    
    # On vérifie s'il y a des centroides ou non
    if centroides is None : 
        centroides = []
    if len(centroides) :   
    # visualisation des centroides sous forme de croix rouge
        plt.scatter(centroides[:,x], centroides[:,y], c='r', marker='x', s=100)

    # Titre et display
    plt.title(f"Projection des individus (sur F{x+1} et F{y+1})")
    plt.show()

# %%
# Plan factoriel composé de F1 et F2
# affichage des variables sur ce plan factoriel
# affichage du cercle des corrélations

x_y = (0,1)
features = kmo_col
correlation_graph(pca, x_y, features, resume_composante)

# %% [markdown]
# La moitié supérieur concerne les variables plutôt associées à la Qualité de vie et la Richesse Individuelle (F2).
# La partie droite concerne les variables plutôt associées à la Puissance commerciale et logistique et à la Consommation de Volaille (F1).
#
# Sur ce plan factoriel, on cherchera plutôt des pays positionnés entre les 2 groupes de variables, avec une assez forte puissance économique et une bonne qualité de vie. C'est à dire avec un F1 positif plutôt fort et un F2 positif fort (le plus important).
# En effet, on priviligiera la Qualité de vie et la Richesse Individuelle sur ce plan factorielle car F1 peut être influencer par les outliers.

# %%
x_y = (0,1)

display_factorial_planes(   X_projected, 
                                x_y,
                                resume_composante,
                                pca=pca,
                                labels = None,
                                clusters=clusters_kmeans,
                                centroides=None,
                                alpha=1,
                                figsize=[10,8],
                                marker="." )

# %% [markdown]
# On distingue les 4 outliers en bas à droite (Etats Unis, Chine, Inde, Brésil), très grosse puissance global mais par forcément individuellement.
#
#
# Le clusters bas gauche correspond aux pays "pauvres" ou "peu dévellopés", ils consomment potentiellement peu de volaille et sont moyennement ou peu dévellopés au niveau commercial et logistique (F1 assez faible).
# Leur Qualité de vie et leur Richesse individuelle va de moyenne à faible.
#
#
# Le clusters haut droit correspond aux pays plutôt "riches" ou "dévellopés", ils consomment de la volaille et sont dévellopés au niveau commercial et logistique (F1 assez fort).
# Leur Qualité de vie et leur Richesse individuelle va de moyenne à élevé.
# C'est les pays de ce clusters qu'on priviligiera sur ce plan factoriel.
#
# Pour synthétiser, ici on recherche F1>0 et F2>0

# %%
# Cercle des corrélation sur F1 et F3

x_y = (0,2)
correlation_graph(pca, x_y, features, resume_composante)

# %% [markdown]
# La moitié supérieur concerne les variables plutôt associées au Condition de Marché (F3).
# La partie droite concerne les variables plutôt associées à la Puissance commerciale et logistique et à la Consommation de Volaille (F1) et aussi à la Qualité de vie et à la Richesse Individuelle avec le groupe de variables associé à F2 présent aussi.
#
# Sur ce plan factoriel, on cherchera plutôt des pays positionnés entre les 2 groupes de variables, avec une assez forte puissance économique et des bonnes conditions de marchés. C'est à dire avec un F1 positif et un F3 positif fort.
# En effet, on priviligiera les conditions de marché sur ce plan factorielle car F1 peut être influencer par les outliers.

# %%
x_y = (0,2)

display_factorial_planes(   X_projected, 
                                x_y,
                                resume_composante,
                                pca=pca, 
                                labels = None,
                                clusters=clusters_kmeans, 
                                centroides=None, 
                                alpha=1,
                                figsize=[10,8], 
                                marker="." )

# %% [markdown]
# On distingue les 4 outliers en haut à droite (Etats Unis, Chine, Inde, Brésil), grosse puissance globale et bonne conditions de marché à priori.
#
# Clusters gauche :
# Puissance commerciale et logistique et consommation de volaille plutôt faible.
# Condition de marché allant de mauvaise à bonne.
#
# Clusters droit :
# Puissance commerciale et logistique et consommation de volaille plutôt élevé.
# Condition de marché allant de mauvaise à bonne.
#
# Pour synthétiser, ici on recherche F1>0 et F3>0

# %%
# Cercle des corrélation sur F2 et F3

x_y = (1,2)
correlation_graph(pca, x_y, features, resume_composante)

# %% [markdown]
# Partie supérieur : Condition de marché avantageuse
#
# Partie droite : Bonne qualité de vie et richesse individuelle
#
# On veut cibler en priorité la partie droite supérieur soit F2>0 et F3>0.

# %%
# En résumé
F1_resume = "Puissance commerciale et logistique, Consommation Volaille"
F2_resume = "Qualité de vie, Richesse Individuelle"
F3_resume = "Condition de marché"

# %%
x_y = (1,2)

display_factorial_planes(   X_projected, 
                                x_y,
                                resume_composante,
                                pca=pca, 
                                labels = None,
                                clusters=clusters_kmeans, 
                                centroides=None, 
                                alpha=1,
                                figsize=[10,8], 
                                marker="." )

# %% [markdown]
# Clusters outliers :
# Qualité de vie moyenne/Richesse individuelle faible
# Condition de marché plutôt bonne
#
# Clusters gauche :
# Qualité de vie moyenne/Richesse individuelle faible à moyen
# Condition de marché plutôt bonne à faible
#
# Cluster droit :
# Qualité de vie moyenne/Richesse individuelle moyen à élevé
# Conditions de marché bonne à faible
#
# C'est ce dernier clusters qu'on priviligiera en sélectionnant les pays dans le quart supérieur droit.
#
# En résumé, on cherche les pays avec F2>0, F3>0

# %% [markdown]
# ### Qualité de représentation des individus

# %% [markdown]
# Certains individus sont plus ou moins bien représentés sur le plan factoriel.
# On va voir ici comment mesure cette qualité de représentation.
#
# Pour calculer la qualité de représentation des individus sur les axes, on calcule les carrés des distances à l’origine des individus, qui correspondent également à leur contribution dans l’inertie totale.
#
# Voici la formule :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Di²

# %%
di2 = np.sum(X_scaled**2,axis=1)

df_di2 = pd.DataFrame({'di2':di2}, index=pays)
df_di2.sort_values('di2', ascending=False).head(20)
# Out:
#                             di2
# Chine, continentale      302.41
# États-Unis d'Amérique    210.78
# Chine - RAS de Hong-Kong  99.32
# Inde                      66.29
# Luxembourg                61.03
# Brésil                    44.09
# Belgique                  38.40
# Îles Salomon              35.53
# Chine - RAS de Macao      31.22
# Islande                   31.02
# Pays-Bas                  26.91
# Saint-Kitts-et-Nevis      24.21
# Yémen                     23.41
# Samoa                     18.25
# Japon                     17.04
# Antigua-et-Barbuda        16.61
# Suisse                    16.56
# Fidji                     15.81
# Tchad                     14.99
# Pakistan                  14.92

# %% [markdown]
# Cela semble correspondre aux outliers également.

# %% [markdown]
# #### Cos²

# %% [markdown]
# Ensuite nous devons calculer le cos² de chaque individu pour chaque composante. Il représente la qualité de représentation par rapport à cette composante.
#
# Ensuite on ajoutera les cos² des 2 composantes principales pour chaque plan factoriel.
# ![image.png](attachment:image.png)

# %%
# multiplication de tous les termes par eux même
cos2 = df_projection**2

# application de la formule ci-dessus
for j in range(cos2.columns.shape[0]):    
    cos2.iloc[:,j] = cos2.iloc[:,j]/di2
    
cos2.columns = ['cos2_1', 'cos2_2', 'cos2_3']

cos2['total'] = cos2.sum(axis=1)
cos2.sort_values('total', ascending=False)
# Out:
#                                                     cos2_1  cos2_2  cos2_3  \
# Honduras                                              0.24    0.54    0.16
# Canada                                                0.28    0.33    0.31
# Chine, continentale                                   0.77    0.10    0.05
# Maroc                                                 0.05    0.60    0.27
# Chine - RAS de Hong-Kong                              0.01    0.57    0.31
# Togo                                                  0.32    0.50    0.07
# Émirats arabes unis                                   0.05    0.76    0.06
# Côte d'Ivoire                                         0.24    0.63    0.01
# Finlande                                              0.07    0.33    0.47
# Italie                                                0.37    0.10    0.39
# France                                                0.41    0.26    0.19
# Suède                                                 0.06    0.65    0.15
# Japon                                                 0.61    0.20    0.05
# Chine - RAS de Macao                                  0.02    0.82    0.01
# Libéria                                               0.34    0.11    0.40
# Sénégal                                               0.27    0.55    0.02
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...    0.48    0.23    0.12
# Niger                                                 0.23    0.59    0.02
# États-Unis d'Amérique                                 0.81    0.01    0.00
# Australie                                             0.21    0.37    0.24
# Équateur                                              0.17    0.36    0.29
# Paraguay                                              0.24    0.24    0.34
# Kenya                                                 0.17    0.64    0.00
# Sierra Leone                                          0.34    0.34    0.12
# Cameroun                                              0.20    0.59    0.00
# Azerbaïdjan                                           0.24    0.51    0.03
# Belgique                                              0.01    0.54    0.23
# Tchéquie                                              0.01    0.62    0.15
# Congo                                                 0.26    0.00    0.51
# Ouganda                                               0.17    0.59    0.01
# Allemagne                                             0.44    0.26    0.05
# Espagne                                               0.34    0.14    0.27
# Pakistan                                              0.02    0.72    0.01
# Hongrie                                               0.01    0.12    0.63
# Pays-Bas                                              0.04    0.61    0.09
# Nigéria                                               0.08    0.67    0.00
# Îles Salomon                                          0.15    0.02    0.58
# Nouvelle-Zélande                                      0.04    0.38    0.31
# Nicaragua                                             0.17    0.26    0.30
# Danemark                                              0.05    0.62    0.05
# Congo                                                 0.21    0.11    0.39
# Angola                                                0.28    0.05    0.38
# Tchad                                                 0.19    0.43    0.08
# Portugal                                              0.02    0.26    0.42
# Tunisie                                               0.15    0.49    0.06
# Norvège                                               0.04    0.38    0.26
# Autriche                                              0.02    0.65    0.02
# Irlande                                               0.01    0.67    0.00
# Suriname                                              0.27    0.00    0.41
# Lesotho                                               0.31    0.08    0.29
# Guyana                                                0.24    0.43    0.01
# Indonésie                                             0.20    0.42    0.05
# Suisse                                                0.05    0.52    0.10
# Ghana                                                 0.29    0.11    0.27
# Bénin                                                 0.26    0.07    0.34
# Algérie                                               0.13    0.50    0.04
# Égypte                                                0.01    0.64    0.01
# Rwanda                                                0.18    0.46    0.01
# Pologne                                               0.12    0.00    0.51
# Fédération de Russie                                  0.33    0.28    0.03
# Chili                                                 0.05    0.19    0.39
# Serbie                                                0.13    0.11    0.38
# Samoa                                                 0.13    0.02    0.47
# Pérou                                                 0.00    0.07    0.55
# Zambie                                                0.27    0.31    0.03
# République de Moldova                                 0.25    0.31    0.05
# Lituanie                                              0.01    0.44    0.16
# Grèce                                                 0.00    0.05    0.55
# Malte                                                 0.01    0.56    0.04
# Belize                                                0.24    0.35    0.01
# Sri Lanka                                             0.17    0.42    0.00
# Brésil                                                0.51    0.08    0.00
# Costa Rica                                            0.02    0.03    0.54
# Oman                                                  0.01    0.50    0.08
# Bélarus                                               0.02    0.06    0.49
# Polynésie française                                   0.03    0.35    0.20
# Antigua-et-Barbuda                                    0.08    0.05    0.44
# Dominique                                             0.09    0.20    0.26
# Lettonie                                              0.03    0.49    0.03
# République de Corée                                   0.32    0.10    0.11
# Thaïlande                                             0.03    0.31    0.18
# Koweït                                                0.00    0.52    0.00
# Slovénie                                              0.02    0.22    0.28
# Gabon                                                 0.13    0.00    0.38
# Mexique                                               0.40    0.07    0.03
# Colombie                                              0.00    0.31    0.18
# Eswatini                                              0.17    0.28    0.04
# Iran (République islamique d')                        0.00    0.47    0.01
# Bosnie-Herzégovine                                    0.06    0.20    0.20
# République dominicaine                                0.06    0.04    0.35
# Estonie                                               0.02    0.42    0.01
# Iraq                                                  0.14    0.13    0.18
# Israël                                                0.04    0.13    0.28
# Monténégro                                            0.35    0.01    0.09
# Namibie                                               0.15    0.08    0.21
# Saint-Kitts-et-Nevis                                  0.05    0.05    0.34
# Luxembourg                                            0.00    0.42    0.02
# Bulgarie                                              0.08    0.35    0.00
# Bolivie (État plurinational de)                       0.07    0.19    0.18
# Guatemala                                             0.24    0.19    0.00
# Ukraine                                               0.02    0.33    0.07
# Turquie                                               0.05    0.22    0.15
# Inde                                                  0.17    0.23    0.02
# Yémen                                                 0.13    0.23    0.06
# Uruguay                                               0.00    0.04    0.36
# Chypre                                                0.03    0.35    0.02
# El Salvador                                           0.14    0.10    0.15
# Jamaïque                                              0.26    0.11    0.02
# Roumanie                                              0.05    0.02    0.31
# Macédoine du Nord                                     0.20    0.00    0.17
# Philippines                                           0.01    0.33    0.02
# Slovaquie                                             0.03    0.33    0.00
# Croatie                                               0.02    0.04    0.29
# Islande                                               0.00    0.32    0.02
# Malaisie                                              0.18    0.03    0.12
# Arménie                                               0.18    0.00    0.14
# Fidji                                                 0.16    0.07    0.07
# Panama                                                0.02    0.01    0.26
# Argentine                                             0.10    0.00    0.18
# Liban                                                 0.09    0.13    0.05
# Botswana                                              0.07    0.03    0.16
# Afrique du Sud                                        0.17    0.00    0.08
# Arabie saoudite                                       0.08    0.14    0.00
# Maurice                                               0.04    0.00    0.18
# Albanie                                               0.18    0.00    0.03
# Myanmar                                               0.02    0.18    0.00
# Géorgie                                               0.15    0.00    0.02
# Trinité-et-Tobago                                     0.13    0.00    0.03
# Jordanie                                              0.12    0.02    0.03
# Barbade                                               0.09    0.01    0.03
# Kazakhstan                                            0.05    0.01    0.02
# Viet Nam                                              0.00    0.00    0.05
#
#                                                     total
# Honduras                                             0.93
# Canada                                               0.93
# Chine, continentale                                  0.93
# Maroc                                                0.92
# Chine - RAS de Hong-Kong                             0.89
# Togo                                                 0.89
# Émirats arabes unis                                  0.88
# Côte d'Ivoire                                        0.88
# Finlande                                             0.87
# Italie                                               0.86
# France                                               0.86
# Suède                                                0.86
# Japon                                                0.86
# Chine - RAS de Macao                                 0.85
# Libéria                                              0.84
# Sénégal                                              0.84
# Royaume-Uni de Grande-Bretagne et d'Irlande du ...   0.84
# Niger                                                0.84
# États-Unis d'Amérique                                0.83
# Australie                                            0.82
# Équateur                                             0.82
# Paraguay                                             0.82
# Kenya                                                0.81
# Sierra Leone                                         0.79
# Cameroun                                             0.79
# Azerbaïdjan                                          0.78
# Belgique                                             0.77
# Tchéquie                                             0.77
# Congo                                                0.77
# Ouganda                                              0.76
# Allemagne                                            0.76
# Espagne                                              0.75
# Pakistan                                             0.75
# Hongrie                                              0.75
# Pays-Bas                                             0.75
# Nigéria                                              0.75
# Îles Salomon                                         0.75
# Nouvelle-Zélande                                     0.74
# Nicaragua                                            0.73
# Danemark                                             0.72
# Congo                                                0.71
# Angola                                               0.71
# Tchad                                                0.70
# Portugal                                             0.70
# Tunisie                                              0.69
# Norvège                                              0.69
# Autriche                                             0.69
# Irlande                                              0.68
# Suriname                                             0.68
# Lesotho                                              0.68
# Guyana                                               0.68
# Indonésie                                            0.67
# Suisse                                               0.67
# Ghana                                                0.67
# Bénin                                                0.67
# Algérie                                              0.67
# Égypte                                               0.66
# Rwanda                                               0.65
# Pologne                                              0.64
# Fédération de Russie                                 0.63
# Chili                                                0.62
# Serbie                                               0.62
# Samoa                                                0.62
# Pérou                                                0.62
# Zambie                                               0.61
# République de Moldova                                0.61
# Lituanie                                             0.61
# Grèce                                                0.61
# Malte                                                0.60
# Belize                                               0.60
# Sri Lanka                                            0.60
# Brésil                                               0.59
# Costa Rica                                           0.59
# Oman                                                 0.58
# Bélarus                                              0.57
# Polynésie française                                  0.57
# Antigua-et-Barbuda                                   0.57
# Dominique                                            0.55
# Lettonie                                             0.55
# République de Corée                                  0.53
# Thaïlande                                            0.53
# Koweït                                               0.52
# Slovénie                                             0.52
# Gabon                                                0.51
# Mexique                                              0.50
# Colombie                                             0.49
# Eswatini                                             0.49
# Iran (République islamique d')                       0.48
# Bosnie-Herzégovine                                   0.46
# République dominicaine                               0.46
# Estonie                                              0.46
# Iraq                                                 0.46
# Israël                                               0.45
# Monténégro                                           0.44
# Namibie                                              0.44
# Saint-Kitts-et-Nevis                                 0.44
# Luxembourg                                           0.44
# Bulgarie                                             0.44
# Bolivie (État plurinational de)                      0.44
# Guatemala                                            0.43
# Ukraine                                              0.43
# Turquie                                              0.42
# Inde                                                 0.42
# Yémen                                                0.41
# Uruguay                                              0.40
# Chypre                                               0.40
# El Salvador                                          0.40
# Jamaïque                                             0.39
# Roumanie                                             0.38
# Macédoine du Nord                                    0.37
# Philippines                                          0.36
# Slovaquie                                            0.36
# Croatie                                              0.36
# Islande                                              0.35
# Malaisie                                             0.33
# Arménie                                              0.32
# Fidji                                                0.30
# Panama                                               0.29
# Argentine                                            0.28
# Liban                                                0.27
# Botswana                                             0.26
# Afrique du Sud                                       0.25
# Arabie saoudite                                      0.22
# Maurice                                              0.22
# Albanie                                              0.21
# Myanmar                                              0.21
# Géorgie                                              0.18
# Trinité-et-Tobago                                    0.17
# Jordanie                                             0.16
# Barbade                                              0.13
# Kazakhstan                                           0.08
# Viet Nam                                             0.05

# %% [markdown]
# On utilisera ce tableau pour vérifier que les pays sélectionner pour le nouveau marché est bien représenté sur le plan factoriel.

# %% [markdown]
# ### Représentation des centroides de chaque clusters

# %%
df_centroide_kmeans = pd.DataFrame(pca.transform(centroides), columns=['F1', 'F2', 'F3'])
df_centroide_kmeans
# Out:
#      F1    F2    F3
# 0 -0.71 -1.03  0.23
# 1 14.17 -3.60  2.44
# 2  0.58  1.79 -0.47

# %%
def projection_centroides(df_centroide_kmeans, resume_composante, x_y, pca=pca) :

    fig, ax = plt.subplots(1, 1, figsize=[7,5])

    x,y = x_y

    markers = ['o', 's', '^', 'v', '+', 'x', '*', 'D']

    X = df_centroide_kmeans.values

    # Valeur x max et y max
    x_max = np.abs(X[:, x]).max() *1.5
    y_max = np.abs(X[:, y]).max() *1.5

    # On borne x et y 
    ax.set_xlim(left=-x_max, right=x_max)
    ax.set_ylim(bottom= -y_max, top=y_max)

    # titre
    plt.title(f"Centroides sur le plan factoriel {df_centroide_kmeans.columns[x]}/{df_centroide_kmeans.columns[y]}")


    # Si la variable pca a été fournie, on peut calculer le % de variance de chaque axe 
    if pca : 
        v1 = str(round(100*pca.explained_variance_ratio_[x]))  + " %"
        v2 = str(round(100*pca.explained_variance_ratio_[y]))  + " %"
    else : 
        v1=v2= ''

    # Nom des axes, avec le pourcentage d'inertie expliqué
    ax.set_xlabel(f'F{x+1} {v1} : {resume_composante[x]}')
    ax.set_ylabel(f'F{y+1} {v2} : {resume_composante[y]}')

    # point centroides
    for i in range(len(X)):
        plt.scatter(X[i,x], X[i,y], marker=markers[i], label=f'Clusters {range(len(X))[i]}')
    
    # affichage legend
    plt.legend()

    # Affichage des lignes horizontales et verticales
    plt.plot([-x_max, x_max], [0, 0], color='grey', alpha=0.8)
    plt.plot([0,0], [-y_max, y_max], color='grey', alpha=0.8)

# %%
x_y = (0,1)
projection_centroides(df_centroide_kmeans, resume_composante, x_y, pca=pca)

x_y = (0,2)
projection_centroides(df_centroide_kmeans, resume_composante, x_y, pca=pca)

x_y = (1,2)
projection_centroides(df_centroide_kmeans, resume_composante, x_y, pca=pca)

# %% [markdown]
# Cluster 0 :
# Puissance commerciale et logistique, Consommation Volaille -
# Qualité de vie, Richesse Individuelle -
# Condition de marché +
#
#
# Cluster 1 :
# Puissance commerciale et logistique, Consommation Volaille ++
# Qualité de vie, Richesse Individuelle -
# Condition de marché ++
#
#
# Cluster 2 :
# Puissance commerciale et logistique, Consommation Volaille +
# Qualité de vie, Richesse Individuelle -
# Condition de marché -

# %% [markdown]
# Ces constats prennent les clusters dans leur ensemble, hors, on a vu qu'il y a une partie du clusters 2 qui est très intéressante.
#
# De plus, on sait que l'ACP est sensible aux outliers, cela peut déséquilibrer l'ensemble.
#
# On va donc procéder à une nouvelle itération en retirant les outliers et en modifiant certains paramètres.

# %% [markdown]
# ### Représentation 3D

# %%
title = "Représentation des pays en fonction des 3 composantes principales"

fig = px.scatter_3d(x=X_projected[:,0], y=X_projected[:,1], z=X_projected[:, 2], hover_name=pays,
              color=clusters_kmeans, title=title, labels={'x':'F1', 'y':'F2', 'z':'F3'})
fig.show()
# Out:
# <div>                            <div id="36825fd4-7c4d-4fd5-a722-4f370b5dd10f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36825fd4-7c4d-4fd5-a722-4f370b5dd10f")) {                    Plotly.newPlot(                        "36825fd4-7c4d-4fd5-a722-4f370b5dd10f",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>F1=%{x}<br>F2=%{y}<br>F3=%{z}<br>color=%{marker.color}<extra></extra>","hovertext":["Afrique du Sud","Albanie","Alg\u00e9rie","Allemagne","Angola","Antigua-et-Barbuda","Arabie saoudite","Argentine","Arm\u00e9nie","Australie","Autriche","Azerba\u00efdjan","Barbade","Belgique","Belize","Bolivie (\u00c9tat plurinational de)","Bosnie-Herz\u00e9govine","Botswana","Br\u00e9sil","Bulgarie","B\u00e9larus","B\u00e9nin","Cameroun","Canada","Chili","Chine - RAS de Hong-Kong","Chine - RAS de Macao","Chine, continentale","Chypre","Colombie","Congo","Congo","Costa Rica","Croatie","C\u00f4te d'Ivoire","Danemark","Dominique","El Salvador","Espagne","Estonie","Eswatini","Fidji","Finlande","France","F\u00e9d\u00e9ration de Russie","Gabon","Ghana","Gr\u00e8ce","Guatemala","Guyana","G\u00e9orgie","Honduras","Hongrie","Inde","Indon\u00e9sie","Iran (R\u00e9publique islamique d')","Iraq","Irlande","Islande","Isra\u00ebl","Italie","Jama\u00efque","Japon","Jordanie","Kazakhstan","Kenya","Kowe\u00eft","Lesotho","Lettonie","Liban","Lib\u00e9ria","Lituanie","Luxembourg","Mac\u00e9doine du Nord","Malaisie","Malte","Maroc","Maurice","Mexique","Mont\u00e9n\u00e9gro","Myanmar","Namibie","Nicaragua","Niger","Nig\u00e9ria","Norv\u00e8ge","Nouvelle-Z\u00e9lande","Oman","Ouganda","Pakistan","Panama","Paraguay","Pays-Bas","Philippines","Pologne","Polyn\u00e9sie fran\u00e7aise","Portugal","P\u00e9rou","Roumanie","Royaume-Uni de Grande-Bretagne et d'Irlande du Nord","Rwanda","R\u00e9publique de Cor\u00e9e","R\u00e9publique de Moldova","R\u00e9publique dominicaine","Saint-Kitts-et-Nevis","Samoa","Serbie","Sierra Leone","Slovaquie","Slov\u00e9nie","Sri Lanka","Suisse","Suriname","Su\u00e8de","S\u00e9n\u00e9gal","Tchad","Tch\u00e9quie","Tha\u00eflande","Togo","Trinit\u00e9-et-Tobago","Tunisie","Turquie","Ukraine","Uruguay","Viet Nam","Y\u00e9men","Zambie","\u00c9gypte","\u00c9mirats arabes unis","\u00c9quateur","\u00c9tats-Unis d'Am\u00e9rique","\u00celes Salomon"],"legendgroup":"","marker":{"color":[2,0,0,2,0,0,2,2,0,2,2,0,0,2,0,0,0,0,0,2,0,0,0,2,2,2,2,1,2,0,0,0,2,2,0,2,2,0,2,2,0,0,2,2,0,0,0,2,0,0,0,0,2,0,0,0,0,2,2,2,2,0,2,0,0,0,2,0,2,0,0,2,2,0,2,2,0,0,0,0,0,0,0,0,0,2,2,2,0,0,0,0,2,0,2,2,2,0,0,2,0,2,0,0,0,0,0,0,2,2,0,2,0,2,0,0,2,0,0,0,0,0,0,2,0,0,0,0,2,0,1,0],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.6431708326563625,-0.9660431608600676,-0.95747360018276,2.3415631357175637,-1.2991512123059898,-1.1714674752214749,0.47672876968977973,0.8569812180248719,-1.4267461106723607,1.5822788207888432,0.36245583190127556,-1.0104721021903242,-1.0433518924345822,0.443587621920449,-1.1314442112299474,-0.548473320675297,-0.6723602896649055,-0.5308578730444565,4.733269715720649,-0.4337221666710091,-0.30873669426183625,-1.385283839438432,-1.4627417117334305,1.6080627244816115,0.42994945753199476,0.9913161540533262,0.8564538026983235,15.283526948204608,-0.345188116153205,0.07833836706021041,-1.3162067129161459,-1.733753482827519,-0.2583881629946019,-0.2870013136173029,-1.099908815417827,0.839696290510518,-0.8037361816551915,-0.8035996857947767,1.6352937104647995,-0.27185496473853954,-1.01292639429813,-1.5812782516564794,0.8709527457912107,1.7619702836204358,1.5853083199871598,-1.3220298135855,-1.2727700523279466,0.06249990889191405,-0.8128258077885211,-1.2388416138617964,-0.906647069750205,-0.8312815283325314,0.140278523446217,3.351905526534052,0.962038 ...

# %% [markdown]
# ### Visualisation des clusters sur la carte

# %%
# importation latitude et longitude
coordonnees = pd.read_csv(folder+'latitude_longitude.csv', sep=';')
coordonnees.columns = ['pays', 'latitude', 'longitude', 'clusters']

# %%
coordonnees = coordonnees[['pays', 'latitude', 'longitude']]

# %%
# df avec les coordonnées gps
df_carte = df.merge(coordonnees, how='left', on='pays')
df_carte.head()
# Out:
#              pays  exportation_volaille  importation_volaille   production  \
# 0  Afrique du Sud             63,000.00            514,000.00 1,667,000.00
# 1         Albanie                  0.00             38,000.00    13,000.00
# 2         Algérie                  0.00              2,000.00   275,000.00
# 3       Allemagne            646,000.00            842,000.00 1,514,000.00
# 4          Angola                  0.00            277,000.00    42,000.00
#
#    volaille_consommée  taux_dependance  taux_autosuffisance  \
# 0        2,035,000.00             0.24                 0.76
# 1           47,000.00             0.81                 0.28
# 2          264,000.00             0.01                 0.99
# 3        1,609,000.00             0.48                 0.50
# 4          315,000.00             0.87                 0.13
#
#    proportion_volaille_nourriture  proportion_animaux_nourriture  \
# 0                            0.06                           0.12
# 1                            0.01                           0.05
# 2                            0.01                           0.03
# 3                            0.02                           0.10
# 4                            0.02                           0.07
#
#      population  ...  taux_droit_douane  quantite_conteneurs_par_annee  \
# 0 57,009,756.00  ...               4.44                   4,563,618.00
# 1  2,884,169.00  ...               1.43                     118,270.00
# 2 41,389,189.00  ...               9.28                   1,725,238.00
# 3 82,658,409.00  ...               1.81                  15,169,595.00
# 4 29,816,766.00  ...               8.52                     570,200.00
#
#    cout_production_volaille  taux_population_urbaine  stabilite_politique  \
# 0                  2,016.60                     0.66                -0.28
# 1                  2,072.14                     0.60                 0.38
# 2                  2,180.70                     0.72                -0.92
# 3                  1,459.50                     0.77                 0.59
# 4                  2,176.24                     0.65                -0.33
#
#    pib_par_habitant  clusters_cah  clusters_kmeans  latitude  longitude
# 0          6,690.94             2                2     -31,7     23,441
# 1          4,514.19             1                0    40,654     20,076
# 2          4,109.70             1                0   28,6045       2,64
# 3         44,651.83             2                2   51,3819     9,9877
# 4          2,313.22             1                0   -12,836     17,808
#
# [5 rows x 24 columns]

# %%
code_iso_3 = {
    'Afrique du Sud': 'ZAF',
    'Albanie': 'ALB',
    'Algérie': 'DZA',
    'Allemagne': 'DEU',
    'Angola': 'AGO',
    'Antigua-et-Barbuda': 'ATG',
    'Arabie saoudite': 'SAU',
    'Argentine': 'ARG',
    'Arménie': 'ARM',
    'Australie': 'AUS',
    'Autriche': 'AUT',
    'Azerbaïdjan': 'AZE',
    'Barbade': 'BRB',
    'Belgique': 'BEL',
    'Belize': 'BLZ',
    'Bolivie (État plurinational de)': 'BOL',
    'Bosnie-Herzégovine': 'BIH',
    'Botswana': 'BWA',
    'Brésil': 'BRA',
    'Bulgarie': 'BGR',
    'Bélarus': 'BLR',
    'Bénin': 'BEN',
    'Cameroun': 'CMR',
    'Canada': 'CAN',
    'Chili': 'CHL',
    'Chine - RAS de Hong-Kong': 'HKG',
    'Chine - RAS de Macao': 'MAC',
    'Chine, continentale': 'CHN',
    'Chypre': 'CYP',
    'Colombie': 'COL',
    'Congo': 'COG',
    'Costa Rica': 'CRI',
    'Croatie': 'HRV',
    "Côte d'Ivoire": 'CIV',
    'Danemark': 'DNK',
    'Dominique': 'DMA',
    'El Salvador': 'SLV',
    'Espagne': 'ESP',
    'Estonie': 'EST',
    'Eswatini': 'SWZ',
    'Fidji': 'FJI',
    'Finlande': 'FIN',
    'France': 'FRA',
    'Fédération de Russie': 'RUS',
    'Gabon': 'GAB',
    'Ghana': 'GHA',
    'Grèce': 'GRC',
    'Guatemala': 'GTM',
    'Guyana': 'GUY',
    'Géorgie': 'GEO',
    'Honduras': 'HND',
    'Hongrie': 'HUN',
    'Inde': 'IND',
    'Indonésie': 'IDN',
    "Iran (République islamique d')": 'IRN',
    'Iraq': 'IRQ',
    'Irlande': 'IRL',
    'Islande': 'ISL',
    'Israël': 'ISR',
    'Italie': 'ITA',
    'Jamaïque': 'JAM',
    'Japon': 'JPN',
    'Jordanie': 'JOR',
    'Kazakhstan': 'KAZ',
    'Kenya': 'KEN',
    'Koweït': 'KWT',
    'Lesotho': 'LSO',
    'Lettonie': 'LVA',
    'Liban': 'LBN',
    'Libéria': 'LBR',
    'Lituanie': 'LTU',
    'Luxembourg': 'LUX',
    'Macédoine du Nord': 'MKD',
    'Malaisie': 'MYS',
    'Malte': 'MLT',
    'Maroc': 'MAR',
    'Maurice': 'MUS',
    'Mexique': 'MEX',
    'Monténégro': 'MNE',
    'Myanmar': 'MMR',
    'Namibie': 'NAM',
    'Nicaragua': 'NIC',
    'Niger': 'NER',
    'Nigéria': 'NGA',
    'Norvège': 'NOR',
    'Nouvelle-Zélande': 'NZL',
    'Oman': 'OMN',
    'Ouganda': 'UGA',
    'Pakistan': 'PAK',
    'Panama': 'PAN',
    'Paraguay': 'PRY',
    'Pays-Bas': 'NLD',
    'Philippines': 'PHL',
    'Pologne': 'POL',
    'Polynésie française': 'PYF',
    'Portugal': 'PRT',
    'Pérou': 'PER',
    'Roumanie': 'ROU',
    "Royaume-Uni de Grande-Bretagne et d'Irlande du Nord": 'GBR',
    'Rwanda': 'RWA',
    'République de Corée': 'KOR',
    'République de Moldova': 'MDA',
    'République dominicaine': 'DOM',
    'Saint-Kitts-et-Nevis': 'KNA',
    'Samoa': 'WSM',
    'Serbie': 'SRB',
    'Sierra Leone': 'SLE',
    'Slovaquie': 'SVK',
    'Slovénie': 'SVN',
    'Sri Lanka': 'LKA',
    'Suisse': 'CHE',
    'Suriname': 'SUR',
    'Suède': 'SWE',
    'Sénégal': 'SEN',
    'Tchad': 'TCD',
    'Tchéquie': 'CZE',
    'Thaïlande': 'THA',
    'Togo': 'TGO',
    'Trinité-et-Tobago': 'TTO',
    'Tunisie': 'TUN',
    'Turquie': 'TUR',
    'Ukraine': 'UKR',
    'Uruguay': 'URY',
    'Viet Nam': 'VNM',
    'Yémen': 'YEM',
    'Zambie': 'ZMB',
    'Égypte': 'EGY',
    'Émirats arabes unis': 'ARE',
    'Équateur': 'ECU',
    "États-Unis d'Amérique": 'USA',
    'Îles Salomon': 'SLB'
}

# %%
# df code iso
code_iso = pd.DataFrame(data=code_iso_3, index=['code_iso']).T.reset_index().rename(columns={'index' : 'pays'})

# %%
# jointure df carte
df_carte = df_carte.merge(code_iso, how='left', on='pays')

# %%
len(df_carte['clusters_kmeans'].unique())
# Out:
# 3

# %%
# création de la carte
fig = px.choropleth(df_carte, color='clusters_kmeans', locations='code_iso',
                    hover_name='pays', title='Carte des clusters', scope='world')
fig.show()
# Out:
# <div>                            <div id="89f47a68-0fb5-4f1f-9b3e-684c1c68af0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89f47a68-0fb5-4f1f-9b3e-684c1c68af0e")) {                    Plotly.newPlot(                        "89f47a68-0fb5-4f1f-9b3e-684c1c68af0e",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>code_iso=%{location}<br>clusters_kmeans=%{z}<extra></extra>","hovertext":["Afrique du Sud","Albanie","Alg\u00e9rie","Allemagne","Angola","Antigua-et-Barbuda","Arabie saoudite","Argentine","Arm\u00e9nie","Australie","Autriche","Azerba\u00efdjan","Barbade","Belgique","Belize","Bolivie (\u00c9tat plurinational de)","Bosnie-Herz\u00e9govine","Botswana","Br\u00e9sil","Bulgarie","B\u00e9larus","B\u00e9nin","Cameroun","Canada","Chili","Chine - RAS de Hong-Kong","Chine - RAS de Macao","Chine, continentale","Chypre","Colombie","Congo","Congo","Costa Rica","Croatie","C\u00f4te d'Ivoire","Danemark","Dominique","El Salvador","Espagne","Estonie","Eswatini","Fidji","Finlande","France","F\u00e9d\u00e9ration de Russie","Gabon","Ghana","Gr\u00e8ce","Guatemala","Guyana","G\u00e9orgie","Honduras","Hongrie","Inde","Indon\u00e9sie","Iran (R\u00e9publique islamique d')","Iraq","Irlande","Islande","Isra\u00ebl","Italie","Jama\u00efque","Japon","Jordanie","Kazakhstan","Kenya","Kowe\u00eft","Lesotho","Lettonie","Liban","Lib\u00e9ria","Lituanie","Luxembourg","Mac\u00e9doine du Nord","Malaisie","Malte","Maroc","Maurice","Mexique","Mont\u00e9n\u00e9gro","Myanmar","Namibie","Nicaragua","Niger","Nig\u00e9ria","Norv\u00e8ge","Nouvelle-Z\u00e9lande","Oman","Ouganda","Pakistan","Panama","Paraguay","Pays-Bas","Philippines","Pologne","Polyn\u00e9sie fran\u00e7aise","Portugal","P\u00e9rou","Roumanie","Royaume-Uni de Grande-Bretagne et d'Irlande du Nord","Rwanda","R\u00e9publique de Cor\u00e9e","R\u00e9publique de Moldova","R\u00e9publique dominicaine","Saint-Kitts-et-Nevis","Samoa","Serbie","Sierra Leone","Slovaquie","Slov\u00e9nie","Sri Lanka","Suisse","Suriname","Su\u00e8de","S\u00e9n\u00e9gal","Tchad","Tch\u00e9quie","Tha\u00eflande","Togo","Trinit\u00e9-et-Tobago","Tunisie","Turquie","Ukraine","Uruguay","Viet Nam","Y\u00e9men","Zambie","\u00c9gypte","\u00c9mirats arabes unis","\u00c9quateur","\u00c9tats-Unis d'Am\u00e9rique","\u00celes Salomon"],"locations":["ZAF","ALB","DZA","DEU","AGO","ATG","SAU","ARG","ARM","AUS","AUT","AZE","BRB","BEL","BLZ","BOL","BIH","BWA","BRA","BGR","BLR","BEN","CMR","CAN","CHL","HKG","MAC","CHN","CYP","COL","COG","COG","CRI","HRV","CIV","DNK","DMA","SLV","ESP","EST","SWZ","FJI","FIN","FRA","RUS","GAB","GHA","GRC","GTM","GUY","GEO","HND","HUN","IND","IDN","IRN","IRQ","IRL","ISL","ISR","ITA","JAM","JPN","JOR","KAZ","KEN","KWT","LSO","LVA","LBN","LBR","LTU","LUX","MKD","MYS","MLT","MAR","MUS","MEX","MNE","MMR","NAM","NIC","NER","NGA","NOR","NZL","OMN","UGA","PAK","PAN","PRY","NLD","PHL","POL","PYF","PRT","PER","ROU","GBR","RWA","KOR","MDA","DOM","KNA","WSM","SRB","SLE","SVK","SVN","LKA","CHE","SUR","SWE","SEN","TCD","CZE","THA","TGO","TTO","TUN","TUR","UKR","URY","VNM","YEM","ZMB","EGY","ARE","ECU","USA","SLB"],"name":"","z":[2,0,0,2,0,0,2,2,0,2,2,0,0,2,0,0,0,0,0,2,0,0,0,2,2,2,2,1,2,0,0,0,2,2,0,2,2,0,2,2,0,0,2,2,0,0,0,2,0,0,0,0,2,0,0,0,0,2,2,2,2,0,2,0,0,0,2,0,2,0,0,2,2,0,2,2,0,0,0,0,0,0,0,0,0,2,2,2,0,0,0,0,2,0,2,2,2,0,0,2,0,2,0,0,0,0,0,0,2,2,0,2,0,2,0,0,2,0,0,0,0,0,0,2,0,0,0,0,2,0,1,0],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666 ...

# %% [markdown]
# ### Analyse des pays par clusters

# %%
# df analyse finale
col_finale = np.insert(kmo_col, 0, ['pays', 'clusters_kmeans'])
df_final = df[col_finale]
df_final = df_final.set_index('pays')
df_final.head()
# Out:
#                 clusters_kmeans   production  volaille_consommée  \
# pays
# Afrique du Sud                2 1,667,000.00        2,035,000.00
# Albanie                       0    13,000.00           47,000.00
# Algérie                       0   275,000.00          264,000.00
# Allemagne                     2 1,514,000.00        1,609,000.00
# Angola                        0    42,000.00          315,000.00
#
#                 taux_dependance  taux_autosuffisance  \
# pays
# Afrique du Sud             0.24                 0.76
# Albanie                    0.81                 0.28
# Algérie                    0.01                 0.99
# Allemagne                  0.48                 0.50
# Angola                     0.87                 0.13
#
#                 proportion_animaux_nourriture    population  lpi  \
# pays
# Afrique du Sud                           0.12 57,009,756.00 3.57
# Albanie                                  0.05  2,884,169.00 2.56
# Algérie                                  0.03 41,389,189.00 2.52
# Allemagne                                0.10 82,658,409.00 4.13
# Angola                                   0.07 29,816,766.00 2.24
#
#                                 pib  taux_droit_douane  \
# pays
# Afrique du Sud   381,448,814,653.46               4.44
# Albanie           13,019,689,336.69               1.43
# Algérie          170,097,014,589.13               9.28
# Allemagne      3,690,849,152,517.65               1.81
# Angola            68,972,769,395.63               8.52
#
#                 quantite_conteneurs_par_annee  cout_production_volaille  \
# pays
# Afrique du Sud                   4,563,618.00                  2,016.60
# Albanie                            118,270.00                  2,072.14
# Algérie                          1,725,238.00                  2,180.70
# Allemagne                       15,169,595.00                  1,459.50
# Angola                             570,200.00                  2,176.24
#
#                 taux_population_urbaine  stabilite_politique  pib_par_habitant
# pays
# Afrique du Sud                     0.66                -0.28          6,690.94
# Albanie                            0.60                 0.38          4,514.19
# Algérie                            0.72                -0.92          4,109.70
# Allemagne                          0.77                 0.59         44,651.83
# Angola                             0.65                -0.33          2,313.22

# %%
# Distribution des variable pour chaque clusters
print("Distribution des variables pour chaque clusters")

for col in df_final.drop(columns='clusters_kmeans'):
    sns.boxplot(data=df_final, y=col, x='clusters_kmeans')
    plt.show()
# Out:
# Distribution des variables pour chaque clusters

# %% [markdown]
# Ces graphiques que c'est le clusters 2 qui est le plus intéressant pour implanter un nouveau marché.
# On va voir plus en détails les pays qui composent ce clusters.

# %% [markdown]
# ### Pays Clusters 2

# %%
df_final[df_final['clusters_kmeans'] == 2].head()
# Out:
#                  clusters_kmeans   production  volaille_consommée  \
# pays
# Afrique du Sud                 2 1,667,000.00        2,035,000.00
# Allemagne                      2 1,514,000.00        1,609,000.00
# Arabie saoudite                2   616,000.00        1,435,000.00
# Argentine                      2 2,161,000.00        1,856,000.00
# Australie                      2 1,269,000.00        1,171,000.00
#
#                  taux_dependance  taux_autosuffisance  \
# pays
# Afrique du Sud              0.24                 0.76
# Allemagne                   0.48                 0.50
# Arabie saoudite             0.50                 0.42
# Argentine                   0.00                 1.00
# Australie                   0.01                 1.05
#
#                  proportion_animaux_nourriture    population  lpi  \
# pays
# Afrique du Sud                            0.12 57,009,756.00 3.57
# Allemagne                                 0.10 82,658,409.00 4.13
# Arabie saoudite                           0.12 33,101,179.00 3.19
# Argentine                                 0.15 43,937,140.00 2.96
# Australie                                 0.16 24,584,620.00 3.77
#
#                                  pib  taux_droit_douane  \
# pays
# Afrique du Sud    381,448,814,653.46               4.44
# Allemagne       3,690,849,152,517.65               1.81
# Arabie saoudite   688,586,094,412.68               4.03
# Argentine         643,628,665,302.15               6.81
# Australie       1,326,516,328,531.56               1.49
#
#                  quantite_conteneurs_par_annee  cout_production_volaille  \
# pays
# Afrique du Sud                    4,563,618.00                  2,016.60
# Allemagne                        15,169,595.00                  1,459.50
# Arabie saoudite                   8,082,329.00                  1,735.36
# Argentine                         1,809,153.00                  1,324.10
# Australie                         7,983,661.00                  2,308.30
#
#                  taux_population_urbaine  stabilite_politique  \
# pays
# Afrique du Sud                      0.66                -0.28
# Allemagne                           0.77                 0.59
# Arabie saoudite                     0.83                -0.58
# Argentine                           0.92                 0.17
# Australie                           0.85                 0.89
#
#                  pib_par_habitant
# pays
# Afrique du Sud           6,690.94
# Allemagne               44,651.83
# Arabie saoudite         20,802.46
# Argentine               14,648.85
# Australie               53,957.16

# %% [markdown]
# ### Proposition de pays

# %%
df_projection['clusters_kmeans'] = clusters_kmeans

# %%
# sélection des pays selon les conditions indiquées plus haut
mask = (df_projection['F1']>0)&(df_projection['F2']>0)&(df_projection['F3']>0)

# %%
df_projection[mask]
# Out:
#                            F1   F2   F3  clusters_kmeans
# Belgique                 0.44 4.55 2.97                2
# Chine - RAS de Hong-Kong 0.99 7.53 5.58                2
# Chine - RAS de Macao     0.86 5.07 0.41                2
# Irlande                  0.36 2.94 0.04                2
# Luxembourg               0.29 5.05 1.16                2
# Pays-Bas                 1.09 4.06 1.60                2
# Émirats arabes unis      0.74 2.87 0.80                2

# %% [markdown]
# 100% des pays qui réunissent les conditions appartiennent au cluster 2.
# Les pays européens présélectionnées ont l'avantage de la proximité géographique.
# Macao et Hong Kong sont potentiellement fournis exclusivement pas la Chine.
# Les Émirats arabes unis peuvent être intéressant également.
#
# Nous allons voir plus en détails les variables pour ces pays.

# %%
# on rajoute toutes les colonnes pour comparer la présélection
df_final2 = df.set_index('pays').drop(columns=['clusters_cah', 'clusters_kmeans'])

# %%
preselection = df_final2.loc[list(df_projection[mask].index)]
preselection
# Out:
#                           exportation_volaille  importation_volaille  \
# pays
# Belgique                            656,000.00            338,000.00
# Chine - RAS de Hong-Kong            663,000.00            907,000.00
# Chine - RAS de Macao                      0.00             23,000.00
# Irlande                              93,000.00             99,000.00
# Luxembourg                            1,000.00             11,000.00
# Pays-Bas                          1,418,000.00            608,000.00
# Émirats arabes unis                  94,000.00            433,000.00
#
#                            production  volaille_consommée  taux_dependance  \
# pays
# Belgique                   463,000.00          144,000.00             2.22
# Chine - RAS de Hong-Kong    24,000.00          391,000.00             3.24
# Chine - RAS de Macao         3,000.00           21,000.00             1.21
# Irlande                    110,000.00          123,000.00             0.77
# Luxembourg                       0.00           11,000.00             1.00
# Pays-Bas                 1,100,000.00          346,000.00             1.63
# Émirats arabes unis         48,000.00          412,000.00             1.05
#
#                           taux_autosuffisance  proportion_volaille_nourriture  \
# pays
# Belgique                                -1.27                            0.01
# Chine - RAS de Hong-Kong                -2.28                            0.07
# Chine - RAS de Macao                     0.16                            0.05
# Irlande                                  0.13                            0.03
# Luxembourg                              -0.09                            0.02
# Pays-Bas                                -0.85                            0.02
# Émirats arabes unis                     -0.11                            0.07
#
#                           proportion_animaux_nourriture    population  \
# pays
# Belgique                                           0.08 11,419,748.00
# Chine - RAS de Hong-Kong                           0.30  7,306,322.00
# Chine - RAS de Macao                               0.22    622,585.00
# Irlande                                            0.10  4,753,279.00
# Luxembourg                                         0.11    591,910.00
# Pays-Bas                                           0.09 17,021,347.00
# Émirats arabes unis                                0.13  9,487,203.00
#
#                           accroissement_population_moyen_par_annee  \
# pays
# Belgique                                                 63,165.53
# Chine - RAS de Hong-Kong                                 40,284.37
# Chine - RAS de Macao                                     10,729.16
# Irlande                                                  54,504.58
# Luxembourg                                                8,849.58
# Pays-Bas                                                 59,651.16
# Émirats arabes unis                                     341,941.95
#
#                           taux_accroissement_population_moyen  lpi  \
# pays
# Belgique                                                 0.01 4.02
# Chine - RAS de Hong-Kong                                 0.01 3.97
# Chine - RAS de Macao                                     0.02 3.58
# Irlande                                                  0.01 3.70
# Luxembourg                                               0.01 3.87
# Pays-Bas                                                 0.00 4.07
# Émirats arabes unis                                      0.04 3.81
#
#                                         pib  taux_droit_douane  \
# pays
# Belgique                 502,764,720,556.35               1.81
# Chine - RAS de Hong-Kong 341,273,289,534.47               0.00
# Chine - RAS de Macao      50,440,941,938.70               0.00
# Irlande                  336,377,500,160.55               1.81
# Luxembourg                65,712,180,342.98               1.81
# Pays-Bas                 833,869,641,687.06               1.81
# Émirats arabes unis      390,516,804,016.50               3.64
#
#                           quantite_conteneurs_par_annee  \
# pays
# Belgique                                  10,783,850.00
# Chine - RAS de Hong-Kong                  20,760,000.00
# Chine - RAS de Macao                       2,653,525.00
# Irlande                                      958,488.00
# Luxembourg                                   749,888.20
# Pays-Bas                                  13,992,474.00
# Émirats arabes unis                       19,089,706.00
#
#                           cout_production_volaille  taux_population_urbaine  \
# pays
# Belgique                                  2,427.02                     0.98
# Chine - RAS de Hong-Kong                  2,214.60                     1.01
# Chine - RAS de Macao                      2,940.30                     1.00
# Irlande                                   2,515.24                     0.63
# Luxembourg                                5,366.00                     0.89
# Pays-Bas                                  1,611.58                     0.91
# Émirats arabes unis                       2,106.20                     0.85
#
#                           stabilite_politique  pib_par_habitant
# pays
# Belgique                                 0.43         44,025.90
# Chine - RAS de Hong-Kong                 0.83         46,709.31
# Chine - RAS de Macao                     1.43         81,018.56
# Irlande                                  1.00         70,767.46
# Luxembourg                               1.33        111,017.18
# Pays-Bas                                 0.92         48,989.64
# Émirats arabes unis                      0.62         41,162.48

# %%
# Distribution des variable pour les pays sélectionnés
print("Distribution des variables")

for col in preselection:
    sns.barplot(data=preselection, x=col, y=preselection.index, orient='h')
    plt.ylabel(None)
    plt.show()
# Out:
# Distribution des variables

# %% [markdown]
# ### Conclusion première itération

# %% [markdown]
# Ces 7 pays sont intéressant et possèdent les caractéristiques adéquoites pour implanter un nouveau marché.
# On peut penser que Macao et Honk Kong sont déjà alimentés par la Chine.
#
# Les 4 pays européens sont particulièrement intéressant pour leur proximité géographique et leur appartenance à l'espace Schengen.
# On choisira la Belgique ou les Pays Bas si on souhaite un marché important et plutôt l'Irlande ou le Luxembourg si on souhaite commencer par un plus petit marché. Sachant que ce dernier ne produit pas de poulets.
#
# Les Émirats arabes unis pourront être intéressant de part la taille de son marché et l'accroissement de sa population.
# Mais les taux de doit de douane sont plus élevés et la stabilité politique est un petit peu plus faible.

# %% [markdown]
# ### Export Tableau

# %%
col_test_clusters = np.insert(kmo_col, 0, 'pays')

df_test_clusters = df[col_test_clusters]

df_test_clusters['clusters'] = clusters_kmeans
df_test_clusters['clusters'] = df_test_clusters['clusters'].astype('str')


df_test_clusters.to_csv(folder+'export_tableau.csv', index=False)

# %% [markdown]
# Je passe maintenant à la deuxième itération sur un autre fichier.
