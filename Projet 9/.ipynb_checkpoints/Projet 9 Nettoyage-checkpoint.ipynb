# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
folder = 'D:/Data_Analyst_Projet/Projet 9/Donnees/donnees en plus/'
folder2 = 'D:/Data_Analyst_Projet/Projet 9/Donnees/'

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Fichier Disponibilité alimentaire

# %% [markdown]
# On va chercher les données qui nous intéresse dans le fichier disponibilité alimentaire.
#
# L'objectif est d'avoir une vision mondiale de la viande de Volaille et d'extraire les indicateurs importants dans ce domaine.
#
# Je vais agréger les données par pays, pour avoir des informations pour chaque pays sur :
# - l'importation de volaille,
# - la part de l'importation par rapport à ce qui est consommé,
# - la part de la production par rapport à ce qui est consommé,
# - la proportion de la volaille dans la nourriture,
# - la proportion d'animaux dans la nourriture.
#
# Les données sont en milliers de tonnes.

# %%
df = pd.read_csv(folder2+'DisponibiliteAlimentaire_2017.csv')
df.head()
# Out:
#   Code Domaine                      Domaine  Code zone         Zone  \
# 0          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 1          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 2          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 3          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 4          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
#
#    Code Élément                   Élément  Code Produit          Produit  \
# 0          5511                Production          2511  Blé et produits
# 1          5611   Importations - Quantité          2511  Blé et produits
# 2          5072        Variation de stock          2511  Blé et produits
# 3          5911   Exportations - Quantité          2511  Blé et produits
# 4          5301  Disponibilité intérieure          2511  Blé et produits
#
#    Code année  Année               Unité   Valeur Symbole  \
# 0        2017   2017  Milliers de tonnes 4,281.00       S
# 1        2017   2017  Milliers de tonnes 2,302.00       S
# 2        2017   2017  Milliers de tonnes  -119.00       S
# 3        2017   2017  Milliers de tonnes     0.00       S
# 4        2017   2017  Milliers de tonnes 6,701.00       S
#
#   Description du Symbole
# 0  Données standardisées
# 1  Données standardisées
# 2  Données standardisées
# 3  Données standardisées
# 4  Données standardisées

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176600 entries, 0 to 176599
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Code Domaine            176600 non-null  object
#  1   Domaine                 176600 non-null  object
#  2   Code zone               176600 non-null  int64
#  3   Zone                    176600 non-null  object
#  4   Code Élément            176600 non-null  int64
#  5   Élément                 176600 non-null  object
#  6   Code Produit            176600 non-null  int64
#  7   Produit                 176600 non-null  object
#  8   Code année              176600 non-null  int64
#  9   Année                   176600 non-null  int64
#  10  Unité                   176600 non-null  object
#  11  Valeur                  176600 non-null  float64
#  12  Symbole                 176600 non-null  object
#  13  Description du Symbole  176600 non-null  object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 18.9+ MB

# %%
dispo_alim = df.copy()

# %%
# on garde que la viande de volaille et les colonnes pertinentes
dispo_poulet = dispo_alim[dispo_alim['Produit']=='Viande de Volailles'][['Zone', 'Élément', 'Valeur']].reset_index(drop=True)
dispo_poulet = pd.pivot_table(dispo_poulet, columns='Élément', index='Zone', values='Valeur').reset_index()

# %%
# renommage colonne
dispo_poulet.rename(columns={'Zone' : 'pays'}, inplace=True)

# %%
dispo_poulet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 18 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   pays                                                           172 non-null    object
#  1   Alimentation pour touristes                                    78 non-null     float64
#  2   Aliments pour animaux                                          1 non-null      float64
#  3   Autres utilisations (non alimentaire)                          34 non-null     float64
#  4   Disponibilité alimentaire (Kcal/personne/jour)                 172 non-null    float64
#  5   Disponibilité alimentaire en quantité (kg/personne/an)         172 non-null    float64
#  6   Disponibilité de matière grasse en quantité (g/personne/jour)  172 non-null    float64
#  7   Disponibilité de protéines en quantité (g/personne/jour)       172 non-null    float64
#  8   Disponibilité intérieure                                       170 non-null    float64
#  9   Exportations - Quantité                                        135 non-null    float64
#  10  Importations - Quantité                                        170 non-null    float64
#  11  Nourriture                                                     170 non-null    float64
#  12  Pertes                                                         67 non-null     float64
#  13  Production                                                     168 non-null    float64
#  14  Résidus                                                        164 non-null    float64
#  15  Semences                                                       1 non-null      float64
#  16  Traitement                                                     46 non-null     float64
#  17  Variation de stock                                             169 non-null    float64
# dtypes: float64(17), object(1)
# memory usage: 24.3+ KB

# %%
# création de la variable taux de dépendance, part importation par rapport à ce qui est consommé
dispo_poulet['taux_dependance'] = dispo_poulet['Importations - Quantité']/dispo_poulet['Disponibilité intérieure']
# création de la variable taux d'autosuffisance', part production par rapport à ce qui est consommé
dispo_poulet['taux_autosuffisance'] = dispo_poulet['Production']/dispo_poulet['Disponibilité intérieure']

# %%
# nourriture totale par pays
nourriture = dispo_alim[dispo_alim['Élément']=='Nourriture'].groupby('Zone')[['Valeur']].sum().reset_index()

nourriture.rename(columns={'Zone':'pays', 'Valeur':'nourriture_totale'}, inplace=True)

dispo_poulet = dispo_poulet.merge(nourriture, how='left', on='pays')

# %%
# création de la variable part de la volaille dans la nourriture du pays
dispo_poulet['proportion_volaille_nourriture'] = dispo_poulet['Nourriture']/dispo_poulet['nourriture_totale']

# %%
# part produit animaux

# liste des produits animaux, viandes, poissons ou fruits de mer
produits_animaux = ['Viande de Bovins',
       "Viande d'Ovins/Caprins", 'Viande de Suides',
       'Viande de Volailles', 'Viande, Autre', 'Abats Comestible',
       'Poissons Eau Douce','Poissons Pelagiques', 'Poissons Marins, Autres', 'Crustacés',
       'Cephalopodes', 'Mollusques, Autres', 'Animaux Aquatiques Autre',
       'Viande de Anim Aquatiq']

# Consommation de la nourriture animale : animaux, viandes, poissons ou fruits de mer 
A = dispo_alim[dispo_alim.Produit.isin(produits_animaux)]
consommation_produits_animaux = A[A['Élément']=='Nourriture'].groupby('Zone')[['Valeur']].sum().reset_index()

# renommage
consommation_produits_animaux.rename(columns={'Zone':'pays', 'Valeur':'nourriture_produits_animaux'}, inplace=True)

# jointure
dispo_poulet = dispo_poulet.merge(consommation_produits_animaux, how='left', on='pays')

# création du champs part animaux dans la nourriture du pays
dispo_poulet['proportion_animaux_nourriture'] = dispo_poulet['nourriture_produits_animaux']/dispo_poulet['nourriture_totale']

# %%
dispo_poulet[dispo_poulet.isna().any(axis=1)]
# Out:
#                       pays  Alimentation pour touristes  \
# 0              Afghanistan                          NaN
# 1           Afrique du Sud                         0.00
# 2                  Albanie                          NaN
# 3                  Algérie                         0.00
# 4                Allemagne                          NaN
# ..                     ...                          ...
# 167    Émirats arabes unis                          NaN
# 168               Équateur                         0.00
# 169  États-Unis d'Amérique                          NaN
# 170               Éthiopie                         0.00
# 171           Îles Salomon                         0.00
#
#      Aliments pour animaux  Autres utilisations (non alimentaire)  \
# 0                      NaN                                    NaN
# 1                      NaN                                    NaN
# 2                      NaN                                    NaN
# 3                      NaN                                    NaN
# 4                      NaN                                    NaN
# ..                     ...                                    ...
# 167                    NaN                                    NaN
# 168                    NaN                                    NaN
# 169                    NaN                                  89.00
# 170                    NaN                                    NaN
# 171                    NaN                                    NaN
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                              5.00
# 1                                            143.00
# 2                                             85.00
# 3                                             22.00
# 4                                             71.00
# ..                                              ...
# 167                                          147.00
# 168                                           83.00
# 169                                          219.00
# 170                                            0.00
# 171                                           18.00
#
#      Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                 1.53
# 1                                                35.69
# 2                                                16.36
# 3                                                 6.38
# 4                                                19.47
# ..                                                 ...
# 167                                              43.47
# 168                                              19.31
# 169                                              55.68
# 170                                               0.13
# 171                                               4.45
#
#      Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                                 0.33
# 1                                                 9.25
# 2                                                 6.45
# 3                                                 1.50
# 4                                                 4.16
# ..                                                 ...
# 167                                               9.25
# 168                                               6.35
# 169                                              14.83
# 170                                               0.03
# 171                                               1.31
#
#      Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                 0.54
# 1                                                14.11
# 2                                                 6.26
# 3                                                 1.97
# 4                                                 7.96
# ..                                                 ...
# 167                                              14.80
# 168                                               6.15
# 169                                              19.93
# 170                                               0.04
# 171                                               1.51
#
#      Disponibilité intérieure  Exportations - Quantité  ...  Résidus  \
# 0                       57.00                      NaN  ...     0.00
# 1                    2,118.00                    63.00  ...     0.00
# 2                       47.00                     0.00  ...     0.00
# 3                      277.00                     0.00  ...     0.00
# 4                    1,739.00                   646.00  ...   -38.00
# ..                        ...                      ...  ...      ...
# 167                    412.00                    94.00  ...     0.00
# 168                    341.00                     0.00  ...     0.00
# 169                 18,266.00                 3,692.00  ...     0.00
# 170                     14.00                      NaN  ...     0.00
# 171                      3.00                     0.00  ...     0.00
#
#      Semences  Traitement  Variation de stock  taux_dependance  \
# 0         NaN         NaN                0.00             0.51
# 1         NaN         NaN                0.00             0.24
# 2         NaN         NaN                4.00             0.81
# 3         NaN         NaN                0.00             0.01
# 4         NaN      167.00              -29.00             0.48
# ..        ...         ...                 ...              ...
# 167       NaN         NaN              -26.00             1.05
# 168       NaN         NaN               -1.00             0.00
# 169       NaN       77.00               80.00             0.01
# 170       NaN         NaN                0.00             0.07
# 171       NaN         NaN                3.00             2.00
#
#      taux_autosuffisance  nourriture_totale  proportion_volaille_nourriture  \
# 0                   0.49          12,968.00                            0.00
# 1                   0.79          31,726.00                            0.06
# 2                   0.28           3,631.00                            0.01
# 3                   0.99          33,056.00                            0.01
# 4                   0.87          77,988.00                            0.02
# ..                   ...                ...                             ...
# 167                 0.12           5,958.00                            0.07
# 168                 1.00           9,465.00                            0.03
# 169                 1.20         322,036.00                            0.06
# 170                 1.00          38,502.00                            0.00
# 171                 0.00             419.00                            0.01
#
#      nourriture_produits_animaux  proportion_animaux_nourriture
# 0                         374.00                           0.03
# 1                       3,902.00                           0.12
# 2                         165.00                           0.05
# 3                         948.00                           0.03
# 4                       8,100.00                           0.10
# ..                           ...                            ...
# 167                       768.00                           0.13
# 168                       896.00                           0.09
# 169                    46,267.00                           0.14
# 170                       730.00                           0.02
# 171                        27.00                           0.06
#
# [171 rows x 24 columns]

# %%
# on garde uniquement les variables qui nous intéresse
data = dispo_poulet[['pays', 'Importations - Quantité', 'Nourriture', 'taux_dependance',
             'taux_autosuffisance','proportion_volaille_nourriture','proportion_animaux_nourriture']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172 entries, 0 to 171
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pays                            172 non-null    object
#  1   Importations - Quantité         170 non-null    float64
#  2   Nourriture                      170 non-null    float64
#  3   taux_dependance                 170 non-null    float64
#  4   taux_autosuffisance             168 non-null    float64
#  5   proportion_volaille_nourriture  170 non-null    float64
#  6   proportion_animaux_nourriture   172 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 10.8+ KB

# %%
# on a trop peu d'informations pour ces pays, on ne les prends par en compte dans l'analyse
data[data.isna().any(axis=1)]
# Out:
#                                       pays  Importations - Quantité  \
# 43                                Djibouti                     3.00
# 92                                Maldives                    12.00
# 113                            Ouzbékistan                      NaN
# 130  République démocratique populaire lao                      NaN
#
#      Nourriture  taux_dependance  taux_autosuffisance  \
# 43         3.00             1.00                  NaN
# 92         7.00             1.00                  NaN
# 113         NaN              NaN                  NaN
# 130         NaN              NaN                  NaN
#
#      proportion_volaille_nourriture  proportion_animaux_nourriture
# 43                             0.01                           0.05
# 92                             0.03                           0.22
# 113                             NaN                           1.00
# 130                             NaN                           1.00

# %%
# on supprime les lignes ci-dessus
data = data.drop(data[data.isna().any(axis=1)].index).reset_index(drop=True)

# %%
plt.figure(figsize=(15,9))

sns.pairplot(data)

plt.show()

# %% [markdown]
# ## Fichier Population

# %% [markdown]
# On va extraire du fichier la population de 2017 (l'année représentée dans disponibilité alimentaire) de chaque pays et le taux d'accroissement de la population.
#
# Un pays qui a un taux d'accroissement de la population fort est un pays avec de futurs potentiels clients, on observera donc cette variable dans l'analyse.

# %%
df2 = pd.read_csv(folder2+'Population_2000_2018.csv')
df2.head()
# Out:
#   Code Domaine                       Domaine  Code zone         Zone  \
# 0           OA  Séries temporelles annuelles          2  Afghanistan
# 1           OA  Séries temporelles annuelles          2  Afghanistan
# 2           OA  Séries temporelles annuelles          2  Afghanistan
# 3           OA  Séries temporelles annuelles          2  Afghanistan
# 4           OA  Séries temporelles annuelles          2  Afghanistan
#
#    Code Élément            Élément  Code Produit                 Produit  \
# 0           511  Population totale          3010  Population-Estimations
# 1           511  Population totale          3010  Population-Estimations
# 2           511  Population totale          3010  Population-Estimations
# 3           511  Population totale          3010  Population-Estimations
# 4           511  Population totale          3010  Population-Estimations
#
#    Code année  Année           Unité    Valeur Symbole  \
# 0        2000   2000  1000 personnes 20,779.95       X
# 1        2001   2001  1000 personnes 21,606.99       X
# 2        2002   2002  1000 personnes 22,600.77       X
# 3        2003   2003  1000 personnes 23,680.87       X
# 4        2004   2004  1000 personnes 24,726.68       X
#
#           Description du Symbole Note
# 0  Sources internationales sûres  NaN
# 1  Sources internationales sûres  NaN
# 2  Sources internationales sûres  NaN
# 3  Sources internationales sûres  NaN
# 4  Sources internationales sûres  NaN

# %%
population = df2.copy()

# %%
population = population.pivot_table(index='Zone', columns='Année', values='Valeur').reset_index()

# %%
population.head()
# Out:
# Année            Zone      2000      2001      2002      2003      2004  \
# 0         Afghanistan 20,779.95 21,606.99 22,600.77 23,680.87 24,726.68
# 1      Afrique du Sud 44,967.71 45,571.27 46,150.91 46,719.20 47,291.61
# 2             Albanie  3,129.24  3,129.70  3,126.19  3,118.02  3,104.89
# 3             Algérie 31,042.24 31,451.51 31,855.11 32,264.16 32,692.16
# 4           Allemagne 81,400.88 81,453.88 81,535.12 81,614.38 81,646.47
#
# Année      2005      2006      2007      2008      2009      2010      2011  \
# 0     25,654.28 26,433.05 27,100.54 27,722.28 28,394.81 29,185.51 30,117.41
# 1     47,880.60 48,489.46 49,119.76 49,779.47 50,477.01 51,216.96 52,003.75
# 2      3,086.81  3,063.02  3,034.00  3,002.68  2,973.05  2,948.02  2,928.59
# 3     33,149.72 33,641.00 34,166.97 34,730.61 35,333.88 35,977.46 36,661.44
# 4     81,602.74 81,472.23 81,277.83 81,065.75 80,899.96 80,827.00 80,855.63
#
# Année      2012      2013      2014      2015      2016      2017      2018
# 0     31,161.38 32,269.59 33,370.79 34,413.60 35,383.03 36,296.11 37,171.92
# 1     52,832.66 53,687.12 54,544.19 55,386.37 56,207.65 57,009.76 57,792.52
# 2      2,914.10  2,903.79  2,896.30  2,890.51  2,886.44  2,884.17  2,882.74
# 3     37,383.89 38,140.13 38,923.69 39,728.03 40,551.39 41,389.19 42,228.41
# 4     80,972.63 81,174.37 81,450.38 81,787.41 82,193.77 82,658.41 83,124.42

# %%
# des valeurs nulles à traiter pour créer de nouvelles variables
population[population.isna().any(axis=1)]
# Out:
# Année                                 Zone      2000      2001      2002  \
# 26         Bonaire, Saint-Eustache et Saba       NaN       NaN       NaN
# 52                                 Curaçao       NaN       NaN       NaN
# 125                             Monténégro       NaN       NaN       NaN
# 169                       Saint-Barthélemy       NaN       NaN       NaN
# 172        Saint-Martin (partie française)       NaN       NaN       NaN
# 181                                 Serbie       NaN       NaN       NaN
# 182                   Serbie-et-Monténégro 10,101.17 10,023.94  9,959.84
# 186    Sint Maarten  (partie néerlandaise)       NaN       NaN       NaN
# 190                                 Soudan       NaN       NaN       NaN
# 191                            Soudan (ex) 33,474.41 34,418.88 35,393.00
# 192                          Soudan du Sud       NaN       NaN       NaN
#
# Année      2003      2004      2005      2006      2007      2008      2009  \
# 26          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 52          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 125         NaN       NaN       NaN    617.86    619.55    621.32    622.94
# 169         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 172         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 181         NaN       NaN       NaN  9,145.91  9,101.18  9,060.10  9,023.36
# 182    9,906.31  9,857.77  9,810.22       NaN       NaN       NaN       NaN
# 186         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 190         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 191   36,396.19 37,427.54 38,485.45 39,569.23 40,675.76 41,797.78 42,926.05
# 192         NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# Année      2010      2011      2012      2013      2014      2015      2016  \
# 26          NaN     21.99     22.84     23.50     24.07     24.57     25.02
# 52          NaN    152.31    154.82    156.79    158.42    159.85    161.05
# 125      624.27    625.27    625.92    626.35    626.64    626.96    627.26
# 169         NaN      9.34      9.44      9.54      9.62      9.69      9.75
# 172         NaN     37.45     37.01     36.45     36.02     35.86     36.06
# 181    8,991.25  8,963.77  8,940.11  8,918.90  8,898.29  8,876.78  8,853.96
# 182         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 186         NaN     35.06     36.24     37.58     38.88     39.97     40.81
# 190         NaN       NaN 36,193.78 37,072.55 37,977.65 38,902.95 39,847.44
# 191   44,053.38 45,180.38       NaN       NaN       NaN       NaN       NaN
# 192         NaN       NaN 10,113.65 10,355.03 10,554.88 10,715.66 10,832.52
#
# Année      2017      2018
# 26        25.40     25.71
# 52       162.00    162.75
# 125      627.56    627.81
# 169        9.78      9.82
# 172       36.56     37.26
# 181    8,829.63  8,802.75
# 182         NaN       NaN
# 186       41.44     41.94
# 190   40,813.40 41,801.53
# 191         NaN       NaN
# 192   10,910.76 10,975.93

# %%
colonne_date = [2000,   2001,   2002,   2003,   2004,   2005,   2006,   2007,
         2008,   2009,   2010,   2011,   2012,   2013,   2014,   2015,   2016,
         2017,   2018]

# on remplace les valeurs nulles par l'interpolation de la ligne, en l'occurence, on étant la dernière valeur
population.loc[population.isna().any(axis=1),colonne_date] = population[population.isna().any(axis=1)].drop(columns='Zone').interpolate(method='linear', axis=1, limit_direction='both')

# %%
# création de la variables accroissement par année
population['accroissement_moyen_par_annee'] = (population[2018]-population[2000])/19

# %%
# calcul des taux d'accroissement 
population['ta_1']=population['accroissement_moyen_par_annee']/population[2016]
population['ta_2']=population['accroissement_moyen_par_annee']/population[2017]
population['ta_3']=population['accroissement_moyen_par_annee']/population[2018]

population['taux_accroissement_moyen'] = (population['ta_1']+population['ta_2']+population['ta_3'])/3

# %%
population.head()
# Out:
# Année            Zone      2000      2001      2002      2003      2004  \
# 0         Afghanistan 20,779.95 21,606.99 22,600.77 23,680.87 24,726.68
# 1      Afrique du Sud 44,967.71 45,571.27 46,150.91 46,719.20 47,291.61
# 2             Albanie  3,129.24  3,129.70  3,126.19  3,118.02  3,104.89
# 3             Algérie 31,042.24 31,451.51 31,855.11 32,264.16 32,692.16
# 4           Allemagne 81,400.88 81,453.88 81,535.12 81,614.38 81,646.47
#
# Année      2005      2006      2007      2008  ...      2014      2015  \
# 0     25,654.28 26,433.05 27,100.54 27,722.28  ... 33,370.79 34,413.60
# 1     47,880.60 48,489.46 49,119.76 49,779.47  ... 54,544.19 55,386.37
# 2      3,086.81  3,063.02  3,034.00  3,002.68  ...  2,896.30  2,890.51
# 3     33,149.72 33,641.00 34,166.97 34,730.61  ... 38,923.69 39,728.03
# 4     81,602.74 81,472.23 81,277.83 81,065.75  ... 81,450.38 81,787.41
#
# Année      2016      2017      2018  accroissement_moyen_par_annee  ta_1  \
# 0     35,383.03 36,296.11 37,171.92                         862.74  0.02
# 1     56,207.65 57,009.76 57,792.52                         674.99  0.01
# 2      2,886.44  2,884.17  2,882.74                         -12.97 -0.00
# 3     40,551.39 41,389.19 42,228.41                         588.75  0.01
# 4     82,193.77 82,658.41 83,124.42                          90.71  0.00
#
# Année  ta_2  ta_3  taux_accroissement_moyen
# 0      0.02  0.02                      0.02
# 1      0.01  0.01                      0.01
# 2     -0.00 -0.00                     -0.00
# 3      0.01  0.01                      0.01
# 4      0.00  0.00                      0.00
#
# [5 rows x 25 columns]

# %%
population.rename(columns={'Zone' : 'pays'}, inplace=True)

# %%
population2 = population[['pays', 2017, 'accroissement_moyen_par_annee', 'taux_accroissement_moyen']]

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   pays                           238 non-null    object
#  1   2000                           238 non-null    float64
#  2   2001                           238 non-null    float64
#  3   2002                           238 non-null    float64
#  4   2003                           238 non-null    float64
#  5   2004                           238 non-null    float64
#  6   2005                           238 non-null    float64
#  7   2006                           238 non-null    float64
#  8   2007                           238 non-null    float64
#  9   2008                           238 non-null    float64
#  10  2009                           238 non-null    float64
#  11  2010                           238 non-null    float64
#  12  2011                           238 non-null    float64
#  13  2012                           238 non-null    float64
#  14  2013                           238 non-null    float64
#  15  2014                           238 non-null    float64
#  16  2015                           238 non-null    float64
#  17  2016                           238 non-null    float64
#  18  2017                           238 non-null    float64
#  19  2018                           238 non-null    float64
#  20  accroissement_moyen_par_annee  238 non-null    float64
#  21  ta_1                           238 non-null    float64
#  22  ta_2                           238 non-null    float64
#  23  ta_3                           238 non-null    float64
#  24  taux_accroissement_moyen       238 non-null    float64
# dtypes: float64(24), object(1)
# memory usage: 46.6+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pays                            168 non-null    object
#  1   Importations - Quantité         168 non-null    float64
#  2   Nourriture                      168 non-null    float64
#  3   taux_dependance                 168 non-null    float64
#  4   taux_autosuffisance             168 non-null    float64
#  5   proportion_volaille_nourriture  168 non-null    float64
#  6   proportion_animaux_nourriture   168 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 9.3+ KB

# %%
A = population['pays'].unique()
B = data['pays'].unique()
liste = []
for pays in B :
    if pays not in A : print(pays), liste.append(pays)

print(len(liste))
# Out:
# 0

# %%
A = population['pays'].unique()
B = data['pays'].unique()
liste = []
for pays in A :
    if pays not in B : print(pays), liste.append(pays)

print(len(liste))
# Out:
# Andorre
# Anguilla
# Antilles néerlandaises (ex)
# Aruba
# Bahreïn
# Bermudes
# Bhoutan
# Bonaire, Saint-Eustache et Saba
# Brunéi Darussalam
# Burundi
# Comores
# Curaçao
# Djibouti
# Gibraltar
# Groenland
# Guadeloupe
# Guam
# Guinée équatoriale
# Guyane française
# Libye
# Liechtenstein
# Maldives
# Martinique
# Mayotte
# Micronésie (États fédérés de)
# Monaco
# Montserrat
# Nauru
# Nioué
# Ouzbékistan
# Palaos
# Palestine
# Papouasie-Nouvelle-Guinée
# Porto Rico
# Qatar
# République arabe syrienne
# République démocratique du Congo
# République démocratique populaire lao
# Réunion
# Sahara occidental
# Saint-Barthélemy
# Saint-Marin
# Saint-Martin (partie française)
# Saint-Pierre-et-Miquelon
# Saint-Siège
# Sainte-Hélène, Ascension et Tristan da Cunha
# Samoa américaines
# Serbie-et-Monténégro
# Seychelles
# Singapour
# Sint Maarten  (partie néerlandaise)
# Somalie
# Soudan (ex)
# Soudan du Sud
# Tokélaou
# Tonga
# Tuvalu
# Érythrée
# Île de Man
# Îles Anglo-Normandes
# Îles Caïmanes
# Îles Cook
# Îles Falkland (Malvinas)
# Îles Féroé
# Îles Mariannes du Nord
# Îles Marshall
# Îles Turques-et-Caïques
# Îles Vierges américaines
# Îles Vierges britanniques
# Îles Wallis-et-Futuna
# 70

# %% [markdown]
# On a 70 pays du fichier population qui ne sont pas représentés dans data, les données provenant de disponibilité alimentaire où il y les informations sur la consommation de volaille de chaque pays. On garde donc uniquement les 168 pays où nous avons des informations sur les consommations de volaille dans la suite de l'analyse.

# %%
data = data.merge(population2, how='left', on='pays')

# %%
data
# Out:
#                       pays  Importations - Quantité  Nourriture  \
# 0              Afghanistan                    29.00       55.00
# 1           Afrique du Sud                   514.00    2,035.00
# 2                  Albanie                    38.00       47.00
# 3                  Algérie                     2.00      264.00
# 4                Allemagne                   842.00    1,609.00
# ..                     ...                      ...         ...
# 163    Émirats arabes unis                   433.00      412.00
# 164               Équateur                     0.00      324.00
# 165  États-Unis d'Amérique                   123.00   18,100.00
# 166               Éthiopie                     1.00       14.00
# 167           Îles Salomon                     6.00        3.00
#
#      taux_dependance  taux_autosuffisance  proportion_volaille_nourriture  \
# 0               0.51                 0.49                            0.00
# 1               0.24                 0.79                            0.06
# 2               0.81                 0.28                            0.01
# 3               0.01                 0.99                            0.01
# 4               0.48                 0.87                            0.02
# ..               ...                  ...                             ...
# 163             1.05                 0.12                            0.07
# 164             0.00                 1.00                            0.03
# 165             0.01                 1.20                            0.06
# 166             0.07                 1.00                            0.00
# 167             2.00                 0.00                            0.01
#
#      proportion_animaux_nourriture       2017  accroissement_moyen_par_annee  \
# 0                             0.03  36,296.11                         862.74
# 1                             0.12  57,009.76                         674.99
# 2                             0.05   2,884.17                         -12.97
# 3                             0.03  41,389.19                         588.75
# 4                             0.10  82,658.41                          90.71
# ..                             ...        ...                            ...
# 163                           0.13   9,487.20                         341.94
# 164                           0.09  16,785.36                         231.75
# 165                           0.14 325,084.76                       2,388.70
# 166                           0.02 106,399.92                       2,263.14
# 167                           0.06     636.04                          12.64
#
#      taux_accroissement_moyen
# 0                        0.02
# 1                        0.01
# 2                       -0.00
# 3                        0.01
# 4                        0.00
# ..                        ...
# 163                      0.04
# 164                      0.01
# 165                      0.01
# 166                      0.02
# 167                      0.02
#
# [168 rows x 10 columns]

# %%
data.columns = ['pays','importation_volaille', 'nourriture', 'taux_dependance','taux_autosuffisance',
 'proportion_volaille_nourriture', 'proportion_animaux_nourriture',
  'population', 'accroissement_population_moyen_par_annee', 'taux_accroissement_population_moyen']

# %%
data
# Out:
#                       pays  importation_volaille  nourriture  taux_dependance  \
# 0              Afghanistan                 29.00       55.00             0.51
# 1           Afrique du Sud                514.00    2,035.00             0.24
# 2                  Albanie                 38.00       47.00             0.81
# 3                  Algérie                  2.00      264.00             0.01
# 4                Allemagne                842.00    1,609.00             0.48
# ..                     ...                   ...         ...              ...
# 163    Émirats arabes unis                433.00      412.00             1.05
# 164               Équateur                  0.00      324.00             0.00
# 165  États-Unis d'Amérique                123.00   18,100.00             0.01
# 166               Éthiopie                  1.00       14.00             0.07
# 167           Îles Salomon                  6.00        3.00             2.00
#
#      taux_autosuffisance  proportion_volaille_nourriture  \
# 0                   0.49                            0.00
# 1                   0.79                            0.06
# 2                   0.28                            0.01
# 3                   0.99                            0.01
# 4                   0.87                            0.02
# ..                   ...                             ...
# 163                 0.12                            0.07
# 164                 1.00                            0.03
# 165                 1.20                            0.06
# 166                 1.00                            0.00
# 167                 0.00                            0.01
#
#      proportion_animaux_nourriture  population  \
# 0                             0.03   36,296.11
# 1                             0.12   57,009.76
# 2                             0.05    2,884.17
# 3                             0.03   41,389.19
# 4                             0.10   82,658.41
# ..                             ...         ...
# 163                           0.13    9,487.20
# 164                           0.09   16,785.36
# 165                           0.14  325,084.76
# 166                           0.02  106,399.92
# 167                           0.06      636.04
#
#      accroissement_population_moyen_par_annee  \
# 0                                      862.74
# 1                                      674.99
# 2                                      -12.97
# 3                                      588.75
# 4                                       90.71
# ..                                        ...
# 163                                    341.94
# 164                                    231.75
# 165                                  2,388.70
# 166                                  2,263.14
# 167                                     12.64
#
#      taux_accroissement_population_moyen
# 0                                   0.02
# 1                                   0.01
# 2                                  -0.00
# 3                                   0.01
# 4                                   0.00
# ..                                   ...
# 163                                 0.04
# 164                                 0.01
# 165                                 0.01
# 166                                 0.02
# 167                                 0.02
#
# [168 rows x 10 columns]

# %% [markdown]
# ## Ajoût d'autres fichiers

# %% [markdown]
# Pour améliorer dans étude de marché, on intègre d'autres données à notre dataset.
#
# On intègre des données politiques, économiques, sociales, technologiques et réglementaires en suivant les principes de l'analyse Pestel.
#
# Les nouveaux indicateurs sont :
# - Le LPI (indicateur de performance logistique)
# - Le PIB
# - Le taux de droit de douane
# - Le taux de population urbaine
# - Le nombre de conteneurs à l'année
# - L'indicateur de stabilité politique
# - Le coût de production du poulet

# %% [markdown]
# ### LPI

# %%
lpi = pd.read_excel(folder+'lpi.xls')
lpi.head()
# Out:
#           pays  lpi
# 0        Aruba 2.49
# 1  Afghanistan 1.95
# 2       Angola 2.05
# 3      Albanie 2.66
# 4      Andorre  NaN

# %%
lpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pays    264 non-null    object
#  1   lpi     206 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.2+ KB

# %%
lpi[lpi.isna().any(axis=1)]
# Out:
#                                            pays  lpi
# 4                                       Andorre  NaN
# 9                             Samoa américaines  NaN
# 10                           Antigua-et-Barbuda  NaN
# 13                                  Azerbaïdjan  NaN
# 24                                       Belize  NaN
# 25                                     Bermudes  NaN
# 28                                      Barbade  NaN
# 31                                     Botswana  NaN
# 36                         Îles Anglo-Normandes  NaN
# 45                                   Cabo Verde  NaN
# 49                                      Curacao  NaN
# 50                                 Îles Caïmans  NaN
# 55                                    Dominique  NaN
# 70                                     Éthiopie  NaN
# 76                                   Îles Féroé  NaN
# 77                 Micronésie, États fédérés de  NaN
# 82                                    Gibraltar  NaN
# 88                                      Grenade  NaN
# 89                                    Groenland  NaN
# 91                                         Guam  NaN
# 106                                  Île de Man  NaN
# 108                               Non classifié  NaN
# 122                                    Kiribati  NaN
# 123                        Saint-Kitts-et-Nevis  NaN
# 131                                Sainte-Lucie  NaN
# 135                               Liechtenstein  NaN
# 144                        Chine - RAS de Macao  NaN
# 145                           Saint-Martin (fr)  NaN
# 147                                      Monaco  NaN
# 153                               Îles Marshall  NaN
# 162                                   Mariannes  NaN
# 163                                  Mozambique  NaN
# 169                                     Namibie  NaN
# 170                          Nouvelle-Calédonie  NaN
# 173                                   Nicaragua  NaN
# 177                                       Nauru  NaN
# 186                                      Palaos  NaN
# 190                                  Porto Rico  NaN
# 191  République populaire démocratique de Corée  NaN
# 194                         Cisjordanie et Gaza  NaN
# 197                         Polynésie française  NaN
# 210                                 Saint-Marin  NaN
# 214                               Soudan du Sud  NaN
# 218                                    Suriname  NaN
# 222                                    Eswatini  NaN
# 223                   Sint Maarten (Dutch part)  NaN
# 224                                  Seychelles  NaN
# 226                     Îles Turques-et-Caïques  NaN
# 235                                 Timor-Leste  NaN
# 237                                       Tonga  NaN
# 243                                      Tuvalu  NaN
# 244                 République-Unie de Tanzanie  NaN
# 251             Saint-Vincent-et-les Grenadines  NaN
# 253                   Îles Vierges britanniques  NaN
# 254                           Îles Vierges (EU)  NaN
# 256                                     Vanuatu  NaN
# 258                                       Samoa  NaN
# 259                                      Kosovo  NaN

# %%
# supression des valeurs nulles
#lpi.drop(lpi[lpi.isna().any(axis=1)].index, inplace=True)

# %%
A = lpi['pays'].unique()
B = data['pays'].unique()
liste = []
for pays in B :
    if pays not in A : print(pays), liste.append(pays)

print(len(liste))
# Out:
# Chine, Taiwan Province de
# Kirghizistan
# 2

# %%
data = data.merge(lpi, how='left', on='pays')
data.head()
# Out:
#              pays  importation_volaille  nourriture  taux_dependance  \
# 0     Afghanistan                 29.00       55.00             0.51
# 1  Afrique du Sud                514.00    2,035.00             0.24
# 2         Albanie                 38.00       47.00             0.81
# 3         Algérie                  2.00      264.00             0.01
# 4       Allemagne                842.00    1,609.00             0.48
#
#    taux_autosuffisance  proportion_volaille_nourriture  \
# 0                 0.49                            0.00
# 1                 0.79                            0.06
# 2                 0.28                            0.01
# 3                 0.99                            0.01
# 4                 0.87                            0.02
#
#    proportion_animaux_nourriture  population  \
# 0                           0.03   36,296.11
# 1                           0.12   57,009.76
# 2                           0.05    2,884.17
# 3                           0.03   41,389.19
# 4                           0.10   82,658.41
#
#    accroissement_population_moyen_par_annee  \
# 0                                    862.74
# 1                                    674.99
# 2                                    -12.97
# 3                                    588.75
# 4                                     90.71
#
#    taux_accroissement_population_moyen  lpi
# 0                                 0.02 1.95
# 1                                 0.01 3.38
# 2                                -0.00 2.66
# 3                                 0.01 2.45
# 4                                 0.00 4.20

# %% [markdown]
# ### PIB

# %%
pib = pd.read_excel(folder+'PIB.xls')
pib.head()
# Out:
#           pays               pib
# 0        Aruba  3,092,178,770.95
# 1  Afghanistan 18,896,352,021.94
# 2       Angola 68,972,769,395.63
# 3      Albanie 13,019,689,336.69
# 4      Andorre  3,000,180,750.11

# %%
pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pays    264 non-null    object
#  1   pib     255 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.2+ KB

# %%
pib[pib.isna().any(axis=1)]
# Out:
#                                            pays  pib
# 36                         Îles Anglo-Normandes  NaN
# 67                                     Érythrée  NaN
# 82                                    Gibraltar  NaN
# 108                               Non classifié  NaN
# 145                           Saint-Martin (fr)  NaN
# 191  République populaire démocratique de Corée  NaN
# 214                               Soudan du Sud  NaN
# 252      Venezuela (République bolivarienne du)  NaN
# 253                   Îles Vierges britanniques  NaN

# %%
A = pib['pays'].unique()
B = data['pays'].unique()
liste = []
for pays in B :
    if pays not in A : print(pays), liste.append(pays)

print(len(liste))
# Out:
# Chine, Taiwan Province de
# Kirghizistan
# 2

# %%
data = data.merge(pib, how='left', on='pays')
data.head()
# Out:
#              pays  importation_volaille  nourriture  taux_dependance  \
# 0     Afghanistan                 29.00       55.00             0.51
# 1  Afrique du Sud                514.00    2,035.00             0.24
# 2         Albanie                 38.00       47.00             0.81
# 3         Algérie                  2.00      264.00             0.01
# 4       Allemagne                842.00    1,609.00             0.48
#
#    taux_autosuffisance  proportion_volaille_nourriture  \
# 0                 0.49                            0.00
# 1                 0.79                            0.06
# 2                 0.28                            0.01
# 3                 0.99                            0.01
# 4                 0.87                            0.02
#
#    proportion_animaux_nourriture  population  \
# 0                           0.03   36,296.11
# 1                           0.12   57,009.76
# 2                           0.05    2,884.17
# 3                           0.03   41,389.19
# 4                           0.10   82,658.41
#
#    accroissement_population_moyen_par_annee  \
# 0                                    862.74
# 1                                    674.99
# 2                                    -12.97
# 3                                    588.75
# 4                                     90.71
#
#    taux_accroissement_population_moyen  lpi                  pib
# 0                                 0.02 1.95    18,896,352,021.94
# 1                                 0.01 3.38   381,448,814,653.46
# 2                                -0.00 2.66    13,019,689,336.69
# 3                                 0.01 2.45   170,097,014,589.13
# 4                                 0.00 4.20 3,690,849,152,517.65

# %% [markdown]
# ### Taux droit de douane

# %%
taux_droit_douane = pd.read_excel(folder+'taux_droit_douane.xls')
taux_droit_douane.head()
# Out:
#           pays  taux_droit_douane
# 0        Aruba              10.16
# 1  Afghanistan               5.63
# 2       Angola               9.38
# 3      Albanie               1.06
# 4      Andorre                NaN

# %%
taux_droit_douane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pays               264 non-null    object
#  1   taux_droit_douane  167 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.2+ KB

# %%
A = taux_droit_douane['pays'].unique()
B = data['pays'].unique()
liste = []
for pays in B :
    if pays not in A : print(pays), liste.append(pays)

print(len(liste))
# Out:
# Chine, Taiwan Province de
# Kirghizistan
# 2

# %%
data = data.merge(taux_droit_douane, how='left', on='pays')
data.head()
# Out:
#              pays  importation_volaille  nourriture  taux_dependance  \
# 0     Afghanistan                 29.00       55.00             0.51
# 1  Afrique du Sud                514.00    2,035.00             0.24
# 2         Albanie                 38.00       47.00             0.81
# 3         Algérie                  2.00      264.00             0.01
# 4       Allemagne                842.00    1,609.00             0.48
#
#    taux_autosuffisance  proportion_volaille_nourriture  \
# 0                 0.49                            0.00
# 1                 0.79                            0.06
# 2                 0.28                            0.01
# 3                 0.99                            0.01
# 4                 0.87                            0.02
#
#    proportion_animaux_nourriture  population  \
# 0                           0.03   36,296.11
# 1                           0.12   57,009.76
# 2                           0.05    2,884.17
# 3                           0.03   41,389.19
# 4                           0.10   82,658.41
#
#    accroissement_population_moyen_par_annee  \
# 0                                    862.74
# 1                                    674.99
# 2                                    -12.97
# 3                                    588.75
# 4                                     90.71
#
#    taux_accroissement_population_moyen  lpi                  pib  \
# 0                                 0.02 1.95    18,896,352,021.94
# 1                                 0.01 3.38   381,448,814,653.46
# 2                                -0.00 2.66    13,019,689,336.69
# 3                                 0.01 2.45   170,097,014,589.13
# 4                                 0.00 4.20 3,690,849,152,517.65
#
#    taux_droit_douane
# 0               5.63
# 1               4.51
# 2               1.06
# 3               8.85
# 4               2.09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168 entries, 0 to 167
# Data columns (total 13 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   pays                                      168 non-null    object
#  1   importation_volaille                      168 non-null    float64
#  2   nourriture                                168 non-null    float64
#  3   taux_dependance                           168 non-null    float64
#  4   taux_autosuffisance                       168 non-null    float64
#  5   proportion_volaille_nourriture            168 non-null    float64
#  6   proportion_animaux_nourriture             168 non-null    float64
#  7   population                                168 non-null    float64
#  8   accroissement_population_moyen_par_annee  168 non-null    float64
#  9   taux_accroissement_population_moyen       168 non-null    float64
#  10  lpi                                       140 non-null    float64
#  11  pib                                       164 non-null    float64
#  12  taux_droit_douane                         134 non-null    float64
# dtypes: float64(12), object(1)
# memory usage: 18.4+ KB

# %% [markdown]
# ### Traffic conteneurs

# %%
trafic_conteneurs = pd.read_excel(folder+'trafic_conteneurs.xls')
trafic_conteneurs.head()
# Out:
#           pays  quantite_conteneurs
# 0        Aruba            31,689.00
# 1  Afghanistan         7,324,816.16
# 2       Angola           570,200.00
# 3      Albanie           118,270.00
# 4      Andorre                  NaN

# %%
A = trafic_conteneurs['pays'].unique()
B = data['pays'].unique()
liste = []
for pays in B :
    if pays not in A : print(pays), liste.append(pays)

print(len(liste))
# Out:
# Chine, Taiwan Province de
# Kirghizistan
# 2

# %%
data = data.merge(trafic_conteneurs, how='left', on='pays')
data.head()
# Out:
#              pays  importation_volaille  nourriture  taux_dependance  \
# 0     Afghanistan                 29.00       55.00             0.51
# 1  Afrique du Sud                514.00    2,035.00             0.24
# 2         Albanie                 38.00       47.00             0.81
# 3         Algérie                  2.00      264.00             0.01
# 4       Allemagne                842.00    1,609.00             0.48
#
#    taux_autosuffisance  proportion_volaille_nourriture  \
# 0                 0.49                            0.00
# 1                 0.79                            0.06
# 2                 0.28                            0.01
# 3                 0.99                            0.01
# 4                 0.87                            0.02
#
#    proportion_animaux_nourriture  population  \
# 0                           0.03   36,296.11
# 1                           0.12   57,009.76
# 2                           0.05    2,884.17
# 3                           0.03   41,389.19
# 4                           0.10   82,658.41
#
#    accroissement_population_moyen_par_annee  \
# 0                                    862.74
# 1                                    674.99
# 2                                    -12.97
# 3                                    588.75
# 4                                     90.71
#
#    taux_accroissement_population_moyen  lpi                  pib  \
# 0                                 0.02 1.95    18,896,352,021.94
# 1                                 0.01 3.38   381,448,814,653.46
# 2                                -0.00 2.66    13,019,689,336.69
# 3                                 0.01 2.45   170,097,014,589.13
# 4                                 0.00 4.20 3,690,849,152,517.65
#
#    taux_droit_douane  quantite_conteneurs
# 0               5.63         7,324,816.16
# 1               4.51         4,563,618.00
# 2               1.06           118,270.00
# 3               8.85         1,725,238.00
# 4               2.09        15,169,595.00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168 entries, 0 to 167
# Data columns (total 14 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   pays                                      168 non-null    object
#  1   importation_volaille                      168 non-null    float64
#  2   nourriture                                168 non-null    float64
#  3   taux_dependance                           168 non-null    float64
#  4   taux_autosuffisance                       168 non-null    float64
#  5   proportion_volaille_nourriture            168 non-null    float64
#  6   proportion_animaux_nourriture             168 non-null    float64
#  7   population                                168 non-null    float64
#  8   accroissement_population_moyen_par_annee  168 non-null    float64
#  9   taux_accroissement_population_moyen       168 non-null    float64
#  10  lpi                                       140 non-null    float64
#  11  pib                                       164 non-null    float64
#  12  taux_droit_douane                         134 non-null    float64
#  13  quantite_conteneurs                       131 non-null    float64
# dtypes: float64(13), object(1)
# memory usage: 19.7+ KB

# %% [markdown]
# ### Coût production poulet

# %%
cout_production_poulet_2017 = pd.read_csv(folder+'prix_production_poulet_2017_fao.csv', sep=';')
cout_production_poulet_2017.head()
# Out:
#              pays  cout (dollars)/tonne
# 0  Afrique du Sud              2,016.60
# 1         Algérie              2,180.70
# 2       Allemagne              1,459.50
# 3       Argentine              1,324.10
# 4         Arménie              3,741.20

# %%
A = cout_production_poulet_2017['pays'].unique()
B = data['pays'].unique()
liste = []
for pays in A :
    if pays not in B : print(pays), liste.append(pays)

print(len(liste))
# Out:
# Brunéi Darussalam
# Palestine
# Qatar
# 3

# %%
A = cout_production_poulet_2017['pays'].unique()
B = data['pays'].unique()
liste = []
for pays in B :
    if pays not in A : print(pays), liste.append(pays)

print(len(liste))
# Out:
# Afghanistan
# Albanie
# Angola
# Antigua-et-Barbuda
# Arabie saoudite
# Australie
# Bahamas
# Bangladesh
# Barbade
# Belgique
# Belize
# Bolivie (État plurinational de)
# Botswana
# Brésil
# Bulgarie
# Burkina Faso
# Bélarus
# Bénin
# Cambodge
# Cameroun
# Canada
# Chili
# Chine - RAS de Hong-Kong
# Chine - RAS de Macao
# Chine, Taiwan Province de
# Colombie
# Congo
# Costa Rica
# Croatie
# Cuba
# Côte d'Ivoire
# Dominique
# Estonie
# Eswatini
# Gabon
# Gambie
# Ghana
# Guatemala
# Guinée
# Guinée-Bissau
# Guyana
# Haïti
# Honduras
# Hongrie
# Inde
# Indonésie
# Iran (République islamique d')
# Iraq
# Irlande
# Israël
# Italie
# Jamaïque
# Japon
# Jordanie
# Kenya
# Kirghizistan
# Kiribati
# Koweït
# Lesotho
# Libéria
# Lituanie
# Macédoine du Nord
# Madagascar
# Malawi
# Mali
# Maroc
# Mauritanie
# Mongolie
# Monténégro
# Mozambique
# Myanmar
# Namibie
# Nicaragua
# Niger
# Nigéria
# Nouvelle-Calédonie
# Nouvelle-Zélande
# Oman
# Ouganda
# Pakistan
# Panama
# Paraguay
# Pays-Bas
# Philippines
# Pologne
# Polynésie française
# Portugal
# Pérou
# Royaume-Uni de Grande-Bretagne et d'Irlande du Nord
# Rwanda
# République centrafricaine
# République de Corée
# République de Moldova
# République dominicaine
# République populaire démocratique de Corée
# République-Unie de Tanzanie
# Saint-Kitts-et-Nevis
# Saint-Vincent-et-les Grenadines
# Samoa
# Sao Tomé-et-Principe
# Serbie
# Sierra Leone
# Slovaquie
# Slovénie
# Soudan
# Suisse
# Suède
# Sénégal
# Tadjikistan
# Tchad
# Tchéquie
# Thaïlande
# Timor-Leste
# Trinité-et-Tobago
# Tunisie
# Turkménistan
# Turquie
# Ukraine
# Vanuatu
# Venezuela (République bolivarienne du)
# Zambie
# Zimbabwe
# Émirats arabes unis
# Équateur
# États-Unis d'Amérique
# Éthiopie
# Îles Salomon
# 127

# %%
data = data.merge(cout_production_poulet_2017, how='left', on='pays')
data.head()
# Out:
#              pays  importation_volaille  nourriture  taux_dependance  \
# 0     Afghanistan                 29.00       55.00             0.51
# 1  Afrique du Sud                514.00    2,035.00             0.24
# 2         Albanie                 38.00       47.00             0.81
# 3         Algérie                  2.00      264.00             0.01
# 4       Allemagne                842.00    1,609.00             0.48
#
#    taux_autosuffisance  proportion_volaille_nourriture  \
# 0                 0.49                            0.00
# 1                 0.79                            0.06
# 2                 0.28                            0.01
# 3                 0.99                            0.01
# 4                 0.87                            0.02
#
#    proportion_animaux_nourriture  population  \
# 0                           0.03   36,296.11
# 1                           0.12   57,009.76
# 2                           0.05    2,884.17
# 3                           0.03   41,389.19
# 4                           0.10   82,658.41
#
#    accroissement_population_moyen_par_annee  \
# 0                                    862.74
# 1                                    674.99
# 2                                    -12.97
# 3                                    588.75
# 4                                     90.71
#
#    taux_accroissement_population_moyen  lpi                  pib  \
# 0                                 0.02 1.95    18,896,352,021.94
# 1                                 0.01 3.38   381,448,814,653.46
# 2                                -0.00 2.66    13,019,689,336.69
# 3                                 0.01 2.45   170,097,014,589.13
# 4                                 0.00 4.20 3,690,849,152,517.65
#
#    taux_droit_douane  quantite_conteneurs  cout (dollars)/tonne
# 0               5.63         7,324,816.16                   NaN
# 1               4.51         4,563,618.00              2,016.60
# 2               1.06           118,270.00                   NaN
# 3               8.85         1,725,238.00              2,180.70
# 4               2.09        15,169,595.00              1,459.50

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168 entries, 0 to 167
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   pays                                      168 non-null    object
#  1   importation_volaille                      168 non-null    float64
#  2   nourriture                                168 non-null    float64
#  3   taux_dependance                           168 non-null    float64
#  4   taux_autosuffisance                       168 non-null    float64
#  5   proportion_volaille_nourriture            168 non-null    float64
#  6   proportion_animaux_nourriture             168 non-null    float64
#  7   population                                168 non-null    float64
#  8   accroissement_population_moyen_par_annee  168 non-null    float64
#  9   taux_accroissement_population_moyen       168 non-null    float64
#  10  lpi                                       140 non-null    float64
#  11  pib                                       164 non-null    float64
#  12  taux_droit_douane                         134 non-null    float64
#  13  quantite_conteneurs                       131 non-null    float64
#  14  cout (dollars)/tonne                      41 non-null     float64
# dtypes: float64(14), object(1)
# memory usage: 21.0+ KB

# %% [markdown]
# ### Fichier traduction

# %%
trad = pd.read_excel(folder+'traduction_pays_fr_anglais.xlsx')
trad.head()
# Out:
#              pays_fr         pays_an
# 0        Afghanistan     Afghanistan
# 1            Albanie         Albania
# 2        Antarctique      Antarctica
# 3            Algérie         Algeria
# 4  Samoa Américaines  American Samoa

# %%
trad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   pays_fr  242 non-null    object
#  1   pays_an  242 non-null    object
# dtypes: object(2)
# memory usage: 3.9+ KB

# %%
A = trad['pays_fr'].unique()
B = data['pays'].unique()
liste = []
for pays in B :
    if pays not in A : print(pays), liste.append(pays)

print(len(liste))
# Out:
# 0

# %%
data = data.merge(trad, how='left', left_on='pays', right_on='pays_fr')
data.head()
# Out:
#              pays  importation_volaille  nourriture  taux_dependance  \
# 0     Afghanistan                 29.00       55.00             0.51
# 1  Afrique du Sud                514.00    2,035.00             0.24
# 2         Albanie                 38.00       47.00             0.81
# 3         Algérie                  2.00      264.00             0.01
# 4       Allemagne                842.00    1,609.00             0.48
#
#    taux_autosuffisance  proportion_volaille_nourriture  \
# 0                 0.49                            0.00
# 1                 0.79                            0.06
# 2                 0.28                            0.01
# 3                 0.99                            0.01
# 4                 0.87                            0.02
#
#    proportion_animaux_nourriture  population  \
# 0                           0.03   36,296.11
# 1                           0.12   57,009.76
# 2                           0.05    2,884.17
# 3                           0.03   41,389.19
# 4                           0.10   82,658.41
#
#    accroissement_population_moyen_par_annee  \
# 0                                    862.74
# 1                                    674.99
# 2                                    -12.97
# 3                                    588.75
# 4                                     90.71
#
#    taux_accroissement_population_moyen  lpi                  pib  \
# 0                                 0.02 1.95    18,896,352,021.94
# 1                                 0.01 3.38   381,448,814,653.46
# 2                                -0.00 2.66    13,019,689,336.69
# 3                                 0.01 2.45   170,097,014,589.13
# 4                                 0.00 4.20 3,690,849,152,517.65
#
#    taux_droit_douane  quantite_conteneurs  cout (dollars)/tonne  \
# 0               5.63         7,324,816.16                   NaN
# 1               4.51         4,563,618.00              2,016.60
# 2               1.06           118,270.00                   NaN
# 3               8.85         1,725,238.00              2,180.70
# 4               2.09        15,169,595.00              1,459.50
#
#           pays_fr       pays_an
# 0     Afghanistan   Afghanistan
# 1  Afrique du Sud  South Africa
# 2         Albanie       Albania
# 3         Algérie       Algeria
# 4       Allemagne       Germany

# %%
data.drop(columns='pays_fr', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   pays                                      169 non-null    object
#  1   importation_volaille                      169 non-null    float64
#  2   nourriture                                169 non-null    float64
#  3   taux_dependance                           169 non-null    float64
#  4   taux_autosuffisance                       169 non-null    float64
#  5   proportion_volaille_nourriture            169 non-null    float64
#  6   proportion_animaux_nourriture             169 non-null    float64
#  7   population                                169 non-null    float64
#  8   accroissement_population_moyen_par_annee  169 non-null    float64
#  9   taux_accroissement_population_moyen       169 non-null    float64
#  10  lpi                                       141 non-null    float64
#  11  pib                                       165 non-null    float64
#  12  taux_droit_douane                         134 non-null    float64
#  13  quantite_conteneurs                       132 non-null    float64
#  14  cout (dollars)/tonne                      41 non-null     float64
#  15  pays_an                                   169 non-null    object
# dtypes: float64(14), object(2)
# memory usage: 22.4+ KB

# %% [markdown]
# ### Taux de population urbaine

# %%
taux_urban_rate = pd.read_excel(folder+'taux_urban_rate.xlsx')
taux_urban_rate.head()
# Out:
#              pays  taux_population_urbaine
# 0     Afghanistan                     0.25
# 1         Albania                     0.60
# 2         Algeria                     0.72
# 3  American Samoa                     0.87
# 4         Andorra                     0.88

# %%
taux_urban_rate.rename(columns={'pays':'pays_an'}, inplace=True)

# %%
taux_urban_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   pays_an                  238 non-null    object
#  1   taux_population_urbaine  234 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.8+ KB

# %%
A = taux_urban_rate['pays_an'].unique()
B = data['pays_an'].unique()
liste = []
for pays in B :
    if pays not in A : print(pays), liste.append(pays)

print(len(liste))
# Out:
# 0

# %%
data = data.merge(taux_urban_rate, how='left', on='pays_an')
data.head()
# Out:
#              pays  importation_volaille  nourriture  taux_dependance  \
# 0     Afghanistan                 29.00       55.00             0.51
# 1  Afrique du Sud                514.00    2,035.00             0.24
# 2         Albanie                 38.00       47.00             0.81
# 3         Algérie                  2.00      264.00             0.01
# 4       Allemagne                842.00    1,609.00             0.48
#
#    taux_autosuffisance  proportion_volaille_nourriture  \
# 0                 0.49                            0.00
# 1                 0.79                            0.06
# 2                 0.28                            0.01
# 3                 0.99                            0.01
# 4                 0.87                            0.02
#
#    proportion_animaux_nourriture  population  \
# 0                           0.03   36,296.11
# 1                           0.12   57,009.76
# 2                           0.05    2,884.17
# 3                           0.03   41,389.19
# 4                           0.10   82,658.41
#
#    accroissement_population_moyen_par_annee  \
# 0                                    862.74
# 1                                    674.99
# 2                                    -12.97
# 3                                    588.75
# 4                                     90.71
#
#    taux_accroissement_population_moyen  lpi                  pib  \
# 0                                 0.02 1.95    18,896,352,021.94
# 1                                 0.01 3.38   381,448,814,653.46
# 2                                -0.00 2.66    13,019,689,336.69
# 3                                 0.01 2.45   170,097,014,589.13
# 4                                 0.00 4.20 3,690,849,152,517.65
#
#    taux_droit_douane  quantite_conteneurs  cout (dollars)/tonne       pays_an  \
# 0               5.63         7,324,816.16                   NaN   Afghanistan
# 1               4.51         4,563,618.00              2,016.60  South Africa
# 2               1.06           118,270.00                   NaN       Albania
# 3               8.85         1,725,238.00              2,180.70       Algeria
# 4               2.09        15,169,595.00              1,459.50       Germany
#
#    taux_population_urbaine
# 0                     0.25
# 1                     0.66
# 2                     0.60
# 3                     0.72
# 4                     0.77

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   pays                                      169 non-null    object
#  1   importation_volaille                      169 non-null    float64
#  2   nourriture                                169 non-null    float64
#  3   taux_dependance                           169 non-null    float64
#  4   taux_autosuffisance                       169 non-null    float64
#  5   proportion_volaille_nourriture            169 non-null    float64
#  6   proportion_animaux_nourriture             169 non-null    float64
#  7   population                                169 non-null    float64
#  8   accroissement_population_moyen_par_annee  169 non-null    float64
#  9   taux_accroissement_population_moyen       169 non-null    float64
#  10  lpi                                       141 non-null    float64
#  11  pib                                       165 non-null    float64
#  12  taux_droit_douane                         134 non-null    float64
#  13  quantite_conteneurs                       132 non-null    float64
#  14  cout (dollars)/tonne                      41 non-null     float64
#  15  pays_an                                   169 non-null    object
#  16  taux_population_urbaine                   169 non-null    float64
# dtypes: float64(15), object(2)
# memory usage: 23.8+ KB

# %% [markdown]
# ### Stabilité politique

# %%
political_stability = pd.read_excel(folder+'PoliticalStability.xlsx')
political_stability.head()
# Out:
#           pays  stabilite_politique
# 0       Taiwan                 0.86
# 1        China                -0.23
# 2        Macao                 1.43
# 3    Hong Kong                 0.83
# 4  Afghanistan                -2.80

# %%
political_stability.rename(columns={'pays':'pays_an'}, inplace=True)

# %%
A = political_stability['pays_an'].unique()
B = data['pays_an'].unique()
liste = []
for pays in B :
    if pays not in A : print(pays), liste.append(pays)

print(len(liste))
# Out:
# New Caledonia
# French Polynesia
# 2

# %%
data = data.merge(political_stability, how='left', on='pays_an')
data.head()
# Out:
#              pays  importation_volaille  nourriture  taux_dependance  \
# 0     Afghanistan                 29.00       55.00             0.51
# 1  Afrique du Sud                514.00    2,035.00             0.24
# 2         Albanie                 38.00       47.00             0.81
# 3         Algérie                  2.00      264.00             0.01
# 4       Allemagne                842.00    1,609.00             0.48
#
#    taux_autosuffisance  proportion_volaille_nourriture  \
# 0                 0.49                            0.00
# 1                 0.79                            0.06
# 2                 0.28                            0.01
# 3                 0.99                            0.01
# 4                 0.87                            0.02
#
#    proportion_animaux_nourriture  population  \
# 0                           0.03   36,296.11
# 1                           0.12   57,009.76
# 2                           0.05    2,884.17
# 3                           0.03   41,389.19
# 4                           0.10   82,658.41
#
#    accroissement_population_moyen_par_annee  \
# 0                                    862.74
# 1                                    674.99
# 2                                    -12.97
# 3                                    588.75
# 4                                     90.71
#
#    taux_accroissement_population_moyen  lpi                  pib  \
# 0                                 0.02 1.95    18,896,352,021.94
# 1                                 0.01 3.38   381,448,814,653.46
# 2                                -0.00 2.66    13,019,689,336.69
# 3                                 0.01 2.45   170,097,014,589.13
# 4                                 0.00 4.20 3,690,849,152,517.65
#
#    taux_droit_douane  quantite_conteneurs  cout (dollars)/tonne       pays_an  \
# 0               5.63         7,324,816.16                   NaN   Afghanistan
# 1               4.51         4,563,618.00              2,016.60  South Africa
# 2               1.06           118,270.00                   NaN       Albania
# 3               8.85         1,725,238.00              2,180.70       Algeria
# 4               2.09        15,169,595.00              1,459.50       Germany
#
#    taux_population_urbaine  stabilite_politique
# 0                     0.25                -2.80
# 1                     0.66                -0.28
# 2                     0.60                 0.38
# 3                     0.72                -0.92
# 4                     0.77                 0.59

# %%
data.to_excel(folder2+'global.xlsx')

# %%
data.drop(columns='pays_an', inplace=True)

# %%
# Changement d'unité, passage à la tonne
data['importation_volaille'] = data['importation_volaille']*1000
data['volaille_consommée'] = data['volaille_consommée']*1000

# # Changement d'unité
data['population'] = data['population']*1000
data['accroissement_population_moyen_par_annee'] = data['accroissement_population_moyen_par_annee']*1000

# %%
# calcul PIB/habitant
data['pib_par_habitant'] = data['pib']/data['population']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   pays                                      169 non-null    object
#  1   importation_volaille                      169 non-null    float64
#  2   nourriture                                169 non-null    float64
#  3   taux_dependance                           169 non-null    float64
#  4   taux_autosuffisance                       169 non-null    float64
#  5   proportion_volaille_nourriture            169 non-null    float64
#  6   proportion_animaux_nourriture             169 non-null    float64
#  7   population                                169 non-null    float64
#  8   accroissement_population_moyen_par_annee  169 non-null    float64
#  9   taux_accroissement_population_moyen       169 non-null    float64
#  10  lpi                                       141 non-null    float64
#  11  pib                                       165 non-null    float64
#  12  taux_droit_douane                         134 non-null    float64
#  13  quantite_conteneurs                       132 non-null    float64
#  14  cout (dollars)/tonne                      41 non-null     float64
#  15  taux_population_urbaine                   169 non-null    float64
#  16  stabilite_politique                       167 non-null    float64
# dtypes: float64(16), object(1)
# memory usage: 23.8+ KB

# %% [markdown]
# ### Début analyse

# %%
# proportion de valeurs nulles
(100*data.isna().sum()/data.shape[0]).sort_values(ascending=False)
# Out:
# cout_production_volaille                   75.74
# quantite_conteneurs_par_annee              21.89
# taux_droit_douane                          20.71
# lpi                                        16.57
# pib_par_habitant                            2.37
# pib                                         2.37
# stabilite_politique                         1.18
# importation_volaille                        0.00
# taux_population_urbaine                     0.00
# pays                                        0.00
# accroissement_population_moyen_par_annee    0.00
# population                                  0.00
# proportion_animaux_nourriture               0.00
# proportion_volaille_nourriture              0.00
# taux_autosuffisance                         0.00
# taux_dependance                             0.00
# volaille_consommée                          0.00
# taux_accroissement_population_moyen         0.00
# dtype: float64

# %%
data
# Out:
#                       pays  importation_volaille  volaille_consommée  \
# 0              Afghanistan             29,000.00           55,000.00
# 1           Afrique du Sud            514,000.00        2,035,000.00
# 2                  Albanie             38,000.00           47,000.00
# 3                  Algérie              2,000.00          264,000.00
# 4                Allemagne            842,000.00        1,609,000.00
# ..                     ...                   ...                 ...
# 164    Émirats arabes unis            433,000.00          412,000.00
# 165               Équateur                  0.00          324,000.00
# 166  États-Unis d'Amérique            123,000.00       18,100,000.00
# 167               Éthiopie              1,000.00           14,000.00
# 168           Îles Salomon              6,000.00            3,000.00
#
#      taux_dependance  taux_autosuffisance  proportion_volaille_nourriture  \
# 0               0.51                 0.49                            0.00
# 1               0.24                 0.79                            0.06
# 2               0.81                 0.28                            0.01
# 3               0.01                 0.99                            0.01
# 4               0.48                 0.87                            0.02
# ..               ...                  ...                             ...
# 164             1.05                 0.12                            0.07
# 165             0.00                 1.00                            0.03
# 166             0.01                 1.20                            0.06
# 167             0.07                 1.00                            0.00
# 168             2.00                 0.00                            0.01
#
#      proportion_animaux_nourriture     population  \
# 0                             0.03  36,296,113.00
# 1                             0.12  57,009,756.00
# 2                             0.05   2,884,169.00
# 3                             0.03  41,389,189.00
# 4                             0.10  82,658,409.00
# ..                             ...            ...
# 164                           0.13   9,487,203.00
# 165                           0.09  16,785,361.00
# 166                           0.14 325,084,756.00
# 167                           0.02 106,399,924.00
# 168                           0.06     636,039.00
#
#      accroissement_population_moyen_par_annee  \
# 0                                  862,735.16
# 1                                  674,990.00
# 2                                  -12,973.84
# 3                                  588,745.95
# 4                                   90,712.42
# ..                                        ...
# 164                                341,941.95
# 165                                231,749.21
# 166                              2,388,702.95
# 167                              2,263,137.37
# 168                                 12,641.95
#
#      taux_accroissement_population_moyen  lpi                   pib  \
# 0                                   0.02 1.95     18,896,352,021.94
# 1                                   0.01 3.38    381,448,814,653.46
# 2                                  -0.00 2.66     13,019,689,336.69
# 3                                   0.01 2.45    170,097,014,589.13
# 4                                   0.00 4.20  3,690,849,152,517.65
# ..                                   ...  ...                   ...
# 164                                 0.04 3.96    390,516,804,016.50
# 165                                 0.01 2.88    104,295,862,000.00
# 166                                 0.01 3.89 19,477,336,549,000.00
# 167                                 0.02  NaN     81,770,791,970.98
# 168                                 0.02 2.57      1,469,787,255.62
#
#      taux_droit_douane  quantite_conteneurs_par_annee  \
# 0                 5.63                   7,324,816.16
# 1                 4.51                   4,563,618.00
# 2                 1.06                     118,270.00
# 3                 8.85                   1,725,238.00
# 4                 2.09                  15,169,595.00
# ..                 ...                            ...
# 164               2.82                  19,089,706.00
# 165               6.81                   1,990,210.00
# 166               1.65                  50,202,917.00
# 167                NaN                            NaN
# 168              14.08                     180,838.40
#
#      cout_production_volaille  taux_population_urbaine  stabilite_politique  \
# 0                         NaN                     0.25                -2.80
# 1                    2,016.60                     0.66                -0.28
# 2                         NaN                     0.60                 0.38
# 3                    2,180.70                     0.72                -0.92
# 4                    1,459.50                     0.77                 0.59
# ..                        ...                      ...                  ...
# 164                       NaN                     0.85                 0.62
# 165                       NaN                     0.63                -0.07
# 166                       NaN                     0.82                 0.34
# 167                       NaN                     0.20                -1.68
# 168                       NaN                     0.22                 0.20
#
#      pib_par_habitant
# 0              520.62
# 1            6,690.94
# 2            4,514.19
# 3            4,109.70
# 4           44,651.83
# ..                ...
# 164         41,162.48
# 165          6,213.50
# 166         59,914.64
# 167            768.52
# 168          2,310.84
#
# [169 rows x 18 columns]

# %%
data.corr()
# Out:
#                                           importation_volaille  \
# importation_volaille                                      1.00
# volaille_consommée                                        0.26
# taux_dependance                                           0.24
# taux_autosuffisance                                       0.04
# proportion_volaille_nourriture                            0.13
# proportion_animaux_nourriture                             0.22
# population                                                0.15
# accroissement_population_moyen_par_annee                  0.04
# taux_accroissement_population_moyen                      -0.08
# lpi                                                       0.44
# pib                                                       0.30
# taux_droit_douane                                        -0.23
# quantite_conteneurs_par_annee                             0.28
# cout_production_volaille                                 -0.29
# taux_population_urbaine                                   0.36
# stabilite_politique                                       0.09
# pib_par_habitant                                          0.26
#
#                                           volaille_consommée  taux_dependance  \
# importation_volaille                                    0.26             0.24
# volaille_consommée                                      1.00            -0.19
# taux_dependance                                        -0.19             1.00
# taux_autosuffisance                                     0.17            -0.46
# proportion_volaille_nourriture                          0.09             0.13
# proportion_animaux_nourriture                           0.11             0.27
# population                                              0.66            -0.19
# accroissement_population_moyen_par_annee                0.44            -0.21
# taux_accroissement_population_moyen                    -0.09             0.02
# lpi                                                     0.26             0.06
# pib                                                     0.91            -0.13
# taux_droit_douane                                      -0.10            -0.03
# quantite_conteneurs_par_annee                           0.75            -0.08
# cout_production_volaille                               -0.21             0.42
# taux_population_urbaine                                 0.16             0.10
# stabilite_politique                                    -0.04             0.29
# pib_par_habitant                                        0.11             0.16
#
#                                           taux_autosuffisance  \
# importation_volaille                                     0.04
# volaille_consommée                                       0.17
# taux_dependance                                         -0.46
# taux_autosuffisance                                      1.00
# proportion_volaille_nourriture                          -0.21
# proportion_animaux_nourriture                           -0.16
# population                                               0.12
# accroissement_population_moyen_par_annee                 0.10
# taux_accroissement_population_moyen                     -0.28
# lpi                                                      0.39
# pib                                                      0.15
# taux_droit_douane                                       -0.28
# quantite_conteneurs_par_annee                            0.13
# cout_production_volaille                                -0.62
# taux_population_urbaine                                  0.16
# stabilite_politique                                     -0.05
# pib_par_habitant                                         0.10
#
#                                           proportion_volaille_nourriture  \
# importation_volaille                                                0.13
# volaille_consommée                                                  0.09
# taux_dependance                                                     0.13
# taux_autosuffisance                                                -0.21
# proportion_volaille_nourriture                                      1.00
# proportion_animaux_nourriture                                       0.75
# population                                                         -0.12
# accroissement_population_moyen_par_annee                           -0.16
# taux_accroissement_population_moyen                                -0.13
# lpi                                                                 0.19
# pib                                                                 0.04
# taux_droit_douane                                                   0.09
# quantite_conteneurs_par_annee                                      -0.05
# cout_production_volaille                                            0.32
# taux_population_urbaine                                             0.24
# stabilite_politique                                                 0.33
# pib_par_habitant                                                    0.20
#
#                                           proportion_animaux_nourriture  \
# importation_volaille                                               0.22
# volaille_consommée                                                 0.11
# taux_dependance                                                    0.27
# taux_autosuffisance                                               -0.16
# proportion_volaille_nourriture                                     0.75
# proportion_animaux_nourriture                                      1.00
# population                                                        -0.09
# accroissement_population_moyen_par_annee                          -0.19
# taux_accroissement_population_moyen                               -0.22
# lpi                                                                0.43
# pib                                                                0.11
# taux_droit_douane                                                 -0.05
# quantite_conteneurs_par_annee                                      0.08
# cout_production_volaille                                           0.23
# taux_population_urbaine                                            0.32
# stabilite_politique                                                0.53
# pib_par_habitant                                                   0.43
#
#                                           population  \
# importation_volaille                            0.15
# volaille_consommée                              0.66
# taux_dependance                                -0.19
# taux_autosuffisance                             0.12
# proportion_volaille_nourriture                 -0.12
# proportion_animaux_nourriture                  -0.09
# population                                      1.00
# accroissement_population_moyen_par_annee        0.91
# taux_accroissement_population_moyen            -0.02
# lpi                                             0.15
# pib                                             0.57
# taux_droit_douane                              -0.01
# quantite_conteneurs_par_annee                   0.74
# cout_production_volaille                       -0.15
# taux_population_urbaine                        -0.05
# stabilite_politique                            -0.14
# pib_par_habitant                               -0.05
#
#                                           accroissement_population_moyen_par_annee  \
# importation_volaille                                                          0.04
# volaille_consommée                                                            0.44
# taux_dependance                                                              -0.21
# taux_autosuffisance                                                           0.10
# proportion_volaille_nourriture                                               -0.16
# proportion_animaux_nourriture                                                -0.19
# population                                                                    0.91
# accroissement_population_moyen_par_annee                                      1.00
# taux_accroissement_population_moyen                                           0.12
# lpi                                                                           0.05
# pib                                                                           0.37
# taux_droit_douane                                                             0.07
# quantite_conteneurs_par_annee                                                 0.43
# cout_production_volaille                                                     -0.14
# taux_population_urbaine                                                      -0.14
# stabilite_politique                                                          -0.25
# pib_par_habitant                                                             -0.11
#
#                                           taux_accroissement_population_moyen  \
# importation_volaille                                                    -0.08
# volaille_consommée                                                      -0.09
# taux_dependance                                                          0.02
# taux_autosuffisance                                                     -0.28
# proportion_volaille_nourriture                                          -0.13
# proportion_animaux_nourriture                                           -0.22
# population                                                              -0.02
# accroissement_population_moyen_par_annee                                 0.12
# taux_accroissement_population_moyen                                      1.00
# lpi                                                                     -0.33
# pib                                                                     -0.11
# taux_droit_douane                                                        0.39
# quantite_conteneurs_par_annee                                           -0.07
# cout_production_volaille                                                 0.28
# taux_population_urbaine                                                 -0.22
# stabilite_politique                                                     -0.39
# pib_par_habitant                                                        -0.18
#
#                                            lpi   pib  taux_droit_douane  \
# importation_volaille                      0.44  0.30              -0.23
# volaille_consommée                        0.26  0.91              -0.10
# taux_dependance                           0.06 -0.13              -0.03
# taux_autosuffisance                       0.39  0.15              -0.28
# proportion_volaille_nourriture            0.19  0.04               0.09
# proportion_animaux_nourriture             0.43  0.11              -0.05
# population                                0.15  0.57              -0.01
# accroissement_population_moyen_par_annee  0.05  0.37               0.07
# taux_accroissement_population_moyen      -0.33 -0.11               0.39
# lpi                                       1.00  0.36              -0.56
# pib                                       0.36  1.00              -0.15
# taux_droit_douane                        -0.56 -0.15               1.00
# quantite_conteneurs_par_annee             0.27  0.68              -0.13
# cout_production_volaille                 -0.17 -0.22               0.31
# taux_population_urbaine                   0.53  0.17              -0.41
# stabilite_politique                       0.58  0.06              -0.30
# pib_par_habitant                          0.75  0.25              -0.40
#
#                                           quantite_conteneurs_par_annee  \
# importation_volaille                                               0.28
# volaille_consommée                                                 0.75
# taux_dependance                                                   -0.08
# taux_autosuffisance                                                0.13
# proportion_volaille_nourriture                                    -0.05
# proportion_animaux_nourriture                                      0.08
# population                                                         0.74
# accroissement_population_moyen_par_annee                           0.43
# taux_accroissement_population_moyen                               -0.07
# lpi                                                                0.27
# pib                                                                0.68
# taux_droit_douane                                                 -0.13
# quantite_conteneurs_par_annee                                      1.00
# cout_production_volaille                                          -0.16
# taux_population_urbaine                                            0.08
# stabilite_politique                                                0.00
# pib_par_habitant                                                   0.08
#
#                                           cout_production_volaille  \
# importation_volaille                                         -0.29
# volaille_consommée                                           -0.21
# taux_dependance                                               0.42
# taux_autosuffisance                                          -0.62
# proportion_volaille_nourriture                                0.32
# proportion_animaux_nourriture                                 0.23
# population                                                   -0.15
# accroissement_population_moyen_par_annee                     -0.14
# taux_accroissement_population_moyen                           0.28
# lpi                                                          -0.17
# pib                                                          -0.22
# taux_droit_douane                                             0.31
# quantite_conteneurs_par_annee                                -0.16
# cout_production_volaille                                      1.00
# taux_population_urbaine                                      -0.29
# stabilite_politique                                           0.14
# pib_par_habitant                                              0.14
#
#                                           taux_population_urbaine  \
# importation_volaille                                         0.36
# volaille_consommée                                           0.16
# taux_dependance                                              0.10
# taux_autosuffisance                                          0.16
# proportion_volaille_nourriture                               0.24
# proportion_animaux_nourriture                                0.32
# population                                                  -0.05
# accroissement_population_moyen_par_annee                    -0.14
# taux_accroissement_population_moyen                         -0.22
# lpi                                                          0.53
# pib                                                          0.17
# taux_droit_douane                                           -0.41
# quantite_conteneurs_par_annee                                0.08
# cout_production_volaille                                    -0.29
# taux_population_urbaine                                      1.00
# stabilite_politique                                          0.36
# pib_par_habitant                                             0.58
#
#                                           stabilite_politique  \
# importation_volaille                                     0.09
# volaille_consommée                                      -0.04
# taux_dependance                                          0.29
# taux_autosuffisance                                     -0.05
# proportion_volaille_nourriture                           0.33
# proportion_animaux_nourriture                            0.53
# population                                              -0.14
# accroissement_population_moyen_par_annee                -0.25
# taux_accroissement_population_moyen                     -0.39
# lpi                                                      0.58
# pib                                                      0.06
# taux_droit_douane                                       -0.30
# quantite_conteneurs_par_annee                            0.00
# cout_production_volaille                                 0.14
# taux_population_urbaine                                  0.36
# stabilite_politique                                      1.00
# pib_par_habitant                                         0.55
#
#                                           pib_par_habitant
# importation_volaille                                  0.26
# volaille_consommée                                    0.11
# taux_dependance                                       0.16
# taux_autosuffisance                                   0.10
# proportion_volaille_nourriture                        0.20
# proportion_animaux_nourriture                         0.43
# population                                           -0.05
# accroissement_population_moyen_par_annee             -0.11
# taux_accroissement_population_moyen                  -0.18
# lpi                                                   0.75
# pib                                                   0.25
# taux_droit_douane                                    -0.40
# quantite_conteneurs_par_annee                         0.08
# cout_production_volaille                              0.14
# taux_population_urbaine                               0.58
# stabilite_politique                                   0.55
# pib_par_habitant                                      1.00

# %%
plt.figure(figsize=(15,9))

sns.heatmap(data.corr(), annot=True)

plt.show()

# %%
plt.figure(figsize=(15,9))

sns.clustermap(data.corr())

plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   pays                                      169 non-null    object
#  1   importation_volaille                      169 non-null    float64
#  2   nourriture                                169 non-null    float64
#  3   taux_dependance                           169 non-null    float64
#  4   taux_autosuffisance                       169 non-null    float64
#  5   proportion_volaille_nourriture            169 non-null    float64
#  6   proportion_animaux_nourriture             169 non-null    float64
#  7   population                                169 non-null    float64
#  8   accroissement_population_moyen_par_annee  169 non-null    float64
#  9   taux_accroissement_population_moyen       169 non-null    float64
#  10  lpi                                       141 non-null    float64
#  11  pib                                       165 non-null    float64
#  12  taux_droit_douane                         134 non-null    float64
#  13  quantite_conteneurs                       132 non-null    float64
#  14  cout (dollars)/tonne                      41 non-null     float64
#  15  taux_population_urbaine                   169 non-null    float64
#  16  stabilite_politique                       167 non-null    float64
# dtypes: float64(16), object(1)
# memory usage: 23.8+ KB

# %%
data.columns = ['pays', 'importation_volaille', 'volaille_consommée', 'taux_dependance',
       'taux_autosuffisance', 'proportion_volaille_nourriture',
       'proportion_animaux_nourriture', 'population',
       'accroissement_population_moyen_par_annee',
       'taux_accroissement_population_moyen', 'lpi', 'pib',
       'taux_droit_douane', 'quantite_conteneurs_par_annee', 'cout_production_volaille',
       'taux_population_urbaine', 'stabilite_politique', 'pib_par_habitant']

# %%
data
# Out:
#                       pays  importation_volaille  volaille_consommée  \
# 0              Afghanistan             29,000.00           55,000.00
# 1           Afrique du Sud            514,000.00        2,035,000.00
# 2                  Albanie             38,000.00           47,000.00
# 3                  Algérie              2,000.00          264,000.00
# 4                Allemagne            842,000.00        1,609,000.00
# ..                     ...                   ...                 ...
# 164    Émirats arabes unis            433,000.00          412,000.00
# 165               Équateur                  0.00          324,000.00
# 166  États-Unis d'Amérique            123,000.00       18,100,000.00
# 167               Éthiopie              1,000.00           14,000.00
# 168           Îles Salomon              6,000.00            3,000.00
#
#      taux_dependance  taux_autosuffisance  proportion_volaille_nourriture  \
# 0               0.51                 0.49                            0.00
# 1               0.24                 0.79                            0.06
# 2               0.81                 0.28                            0.01
# 3               0.01                 0.99                            0.01
# 4               0.48                 0.87                            0.02
# ..               ...                  ...                             ...
# 164             1.05                 0.12                            0.07
# 165             0.00                 1.00                            0.03
# 166             0.01                 1.20                            0.06
# 167             0.07                 1.00                            0.00
# 168             2.00                 0.00                            0.01
#
#      proportion_animaux_nourriture     population  \
# 0                             0.03  36,296,113.00
# 1                             0.12  57,009,756.00
# 2                             0.05   2,884,169.00
# 3                             0.03  41,389,189.00
# 4                             0.10  82,658,409.00
# ..                             ...            ...
# 164                           0.13   9,487,203.00
# 165                           0.09  16,785,361.00
# 166                           0.14 325,084,756.00
# 167                           0.02 106,399,924.00
# 168                           0.06     636,039.00
#
#      accroissement_population_moyen_par_annee  \
# 0                                  862,735.16
# 1                                  674,990.00
# 2                                  -12,973.84
# 3                                  588,745.95
# 4                                   90,712.42
# ..                                        ...
# 164                                341,941.95
# 165                                231,749.21
# 166                              2,388,702.95
# 167                              2,263,137.37
# 168                                 12,641.95
#
#      taux_accroissement_population_moyen  lpi                   pib  \
# 0                                   0.02 1.95     18,896,352,021.94
# 1                                   0.01 3.38    381,448,814,653.46
# 2                                  -0.00 2.66     13,019,689,336.69
# 3                                   0.01 2.45    170,097,014,589.13
# 4                                   0.00 4.20  3,690,849,152,517.65
# ..                                   ...  ...                   ...
# 164                                 0.04 3.96    390,516,804,016.50
# 165                                 0.01 2.88    104,295,862,000.00
# 166                                 0.01 3.89 19,477,336,549,000.00
# 167                                 0.02  NaN     81,770,791,970.98
# 168                                 0.02 2.57      1,469,787,255.62
#
#      taux_droit_douane  quantite_conteneurs_par_annee  \
# 0                 5.63                   7,324,816.16
# 1                 4.51                   4,563,618.00
# 2                 1.06                     118,270.00
# 3                 8.85                   1,725,238.00
# 4                 2.09                  15,169,595.00
# ..                 ...                            ...
# 164               2.82                  19,089,706.00
# 165               6.81                   1,990,210.00
# 166               1.65                  50,202,917.00
# 167                NaN                            NaN
# 168              14.08                     180,838.40
#
#      cout_production_volaille  taux_population_urbaine  stabilite_politique  \
# 0                         NaN                     0.25                -2.80
# 1                    2,016.60                     0.66                -0.28
# 2                         NaN                     0.60                 0.38
# 3                    2,180.70                     0.72                -0.92
# 4                    1,459.50                     0.77                 0.59
# ..                        ...                      ...                  ...
# 164                       NaN                     0.85                 0.62
# 165                       NaN                     0.63                -0.07
# 166                       NaN                     0.82                 0.34
# 167                       NaN                     0.20                -1.68
# 168                       NaN                     0.22                 0.20
#
#      pib_par_habitant
# 0              520.62
# 1            6,690.94
# 2            4,514.19
# 3            4,109.70
# 4           44,651.83
# ..                ...
# 164         41,162.48
# 165          6,213.50
# 166         59,914.64
# 167            768.52
# 168          2,310.84
#
# [169 rows x 18 columns]
